# %% [markdown]
# # LDA에서 Author Topic Model

# %% [markdown]
# <img src="figs/atm_fig.png">

# %% [markdown]
# * LDA에서 저자정보(metadata)가 추가된 토픽모델.
# * 문서별 단어분포를 반영하던 파라미터에, 저자별 문서분포 정보까지 추가된 형태.

# %% [markdown]
# <img src="figs/atm_fig2.png">

# %%
import pandas as pd
import numpy as np
from pprint import pprint

import pickle

# %%
with open("data/cleaned_data.pk", "rb") as f:
    data = pickle.load(f)
    
data.reset_index(drop=True, inplace=True)
print(data.head())
print(data.info())
# Out:
#                Date User            Message
# 0  2017/01/01 20:32   무지  이거보면 왜 갓창정인지 알게된다
# 1  2017/01/01 21:40  어피치                창정헌
# 2  2017/01/01 22:19  어피치   라이언은 내일부터 연구실 출근
# 3  2017/01/01 22:20   무지          파티 하는거 아님
# 4  2017/01/01 22:39  프로도                헬파티
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162861 entries, 0 to 162860
# Data columns (total 3 columns):
# Date       162861 non-null object
# User       162861 non-null object
# Message    162861 non-null object
# dtypes: object(3)
# memory usage: 3.7+ MB
# None

# %%
users = set(data["User"])
users
# Out:
# {'네오', '라이언', '무지', '어피치', '튜브', '프로도'}

# %%
authors = data.groupby('User')
pprint(authors.groups)
print(type(authors.groups))
# Out:
# {'네오': Int64Index([   273,    274,    276,    277,    342,    374,    396,   3784,
#               3785,   3787,
#             ...
#             157425, 157427, 158059, 158060, 158062, 161067, 161068, 161074,
#             161075, 161080],
#            dtype='int64', length=324),
#  '라이언': Int64Index([     9,     14,     15,     18,     19,     24,     25,     26,
#                 30,     32,
#             ...
#             162840, 162843, 162844, 162845, 162846, 162849, 162850, 162852,
#             162854, 162860],
#            dtype='int64', length=39243),
#  '무지': Int64Index([     0,      3,      6,      8,     10,     11,     13,     16,
#                 17,     22,
#             ...
#             162815, 162816, 162820, 162822, 162830, 162834, 162836, 162839,
#             162841, 162842],
#            dtype='int64', length=47861),
#  '어피치': Int64Index([     1,      2,      5,      7,     12,     20,     21,     23,
#                 27,     28,
#             ...
#             162649, 162654, 162655, 162668, 162670, 162683, 162855, 162856,
#             162857, 162859],
#            dtype='int64', length=12705),
#  '튜브': Int64Index([   853,    854,    856,    861,    862,    863,    866,    867,
#                870,    871,
#             ...
#             162778, 162779, 162786, 162787, 162788, 162789, 162790, 162794,
#             162795, 162826],
#            dtype='int64', length=42258),
#  '프로도': Int64Index([     4,    204,    205,    242,    245,    246,    249,    251,
#                253,    255,
#             ...
#             162696, 162700, 162701, 162702, 162710, 162847, 162848, 162851,
#             162853, 162858],
#            dtype='int64', length=20470)}
# <class 'dict'>

# %%
author2doc = {}

for user, index in authors.groups.items():
    author2doc[user] = list(index)
    
print(author2doc)
# Out:
# {'네오': [273, 274, 276, 277, 342, 374, 396, 3784, 3785, 3787, 3791, 3793, 3799, 3801, 3803, 3805, 3808, 3809, 3811, 3813, 3816, 3819, 3820, 3823, 3826, 3848, 3849, 3850, 3851, 3855, 3857, 3862, 3870, 3873, 3874, 3889, 3890, 3892, 3897, 3901, 3905, 3911, 3929, 3934, 3936, 3937, 3938, 3943, 3947, 4418, 4419, 4427, 4429, 4436, 4437, 4438, 4440, 4444, 4445, 4451, 4452, 4454, 4458, 4461, 4462, 4464, 4472, 4474, 4480, 4482, 4484, 4490, 4491, 4493, 4495, 4498, 4500, 4501, 4502, 4504, 4506, 4508, 4512, 4515, 4518, 4520, 4521, 4527, 4532, 4536, 4541, 4543, 15741, 32226, 32227, 32231, 32233, 32234, 32236, 32253, 32256, 32260, 32261, 32264, 32267, 42185, 42188, 42189, 42192, 42197, 42208, 42286, 42289, 42290, 42291, 42293, 45199, 45202, 45208, 45209, 45227, 45228, 48740, 48741, 48742, 48743, 48748, 49663, 49665, 49668, 49669, 49671, 49673, 49675, 49677, 49694, 49697, 49699, 49701, 49702, 49705, 84101, 84102, 84107, 84108, 84111, 84114, 84118, 84120, 85304, 93097, 93098, 93100, 93101, 106745, 106833, 106834, 106835, 106836, 106848, 106849, 106851, 106854, 106857, 107477, 107478, 107481, 107482, 107485, 107490, 107491, 107492, 107495, 107633, 127860, 127864, 127866, 127871, 127872, 127882, 127884, 127887, 127893, 127896, 127898, 127907, 127911, 127914, 127925, 127927, 127934, 127935, 127941, 127945, 127948, 127960, 127962, 127968, 127974, 127976, 127983, 127992, 128000, 128011, 128024, 128026, 128035, 128040, 128051, 128053, 128060, 128064, 128068, 128073, 128077, 128080, 128081, 128089, 128091, 128092, 128097, 128098, 128099, 128100, 128104, 128106, 128109, 128111, 128113, 128117, 128121, 128123, 128127, 128130, 128133, 128136, 128138, 128139, 128143, 128144, 128145, 128149, 128150, 128153, 128157, 128159, 128160, 128164, 128166, 128167, 128174, 128176, 128180, 128184, 128188, 128189, 128196, 128197, 128202, 128206, 128211, 128212, 128213, 128215, 128217, 128219, 128222, 128225, 128227, 128232, 128234, 128236, 128239, 128244, 128247, 128248, 128249, 128250, 128252, 128254, 128255, 128261, 128262, 135779, 135780, 135785, 135787, 135793, 136902, 145578, 145582, 145585, 145586, 145588, 145593, 145594, 145602, 145612, 145613, 145614, 145616, 145619, 145621, 145622, 145624, 153790, 153792, 154227, 154253, 157413, 157417, 157419, 157420, 157424, 157425, 157427, 158059, 158060, 158062, 161067, 161068, 161074, 161075, 161080], '라이언': [9, 14, 15, 18, 19, 24, 25, 26, 30, 32, 35, 38, 40, 41, 43, 45, 46, 47, 49, 51, 52, 56, 58, 60, 62, 63, 66, 75, 76, 81, 82, 87, 92, 93, 100, 107, 147, 148, 149, 155, 156, 157, 161, 162, 163, 165, 166, 168, 169, 170, 171, 174, 175, 176, 178, 179, 181, 183, 185, 186, 189, 192, 193, 196, 197, 198, 199, 202, 203, 212, 234, 235, 238, 265, 266, 267, 270, 271, 286, 287, 290, 292, 319, 320, 323, 324, 325, 327, 329, 330, 333, 336, 337, 338, 340, 345, 346, 349, 350, 353, 355, 359, 362, 363, 364, 366, 367, 368, 369, 375, 378, 382, 383, 384, 385, 386, 387, 388, 395, 397, 399, 400, 401, 404, 405, 410, 416, 417, 422, 424, 427, 430, 431, 432, 437, 438, 439, 468, 479, 507, 508, 516, 517, 519, 520, 521, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 535, 536, 537, 538, 540, 541, 543, 544, 545, 546, 547, 549, 550, 553, 554, 559, 564, 569, 570, 573, 578, 619, 622, 623, 626, 627, 633, 636, 639, 642, 643, 651, 652, 654, 655, 656, 657, 658, 660, 661, 663, 664, 665, 666, 686, 690, 692, 693, 695, 696, 697, 700, 713, 722, 723, 730, 731, 737, 738, 743, 744, 747, 748, 749, 750, 808, 809, 810, 811, 812, 813, 814, 815, 817, 818, 819, 820, 823, 824, 826, 827, 828, 829, 830, 832, 833, 836, 838, 840, 844, 847, 849, 851, 852, 855, 857, 858, 859, 860, 864, 865, 868, 869, 872, 874, 876, 878, 879, 880, 881, 883, 884, 886, 887, 894, 895, 897, 899, 900, 903, 904, 905, 910, 911, 912, 913, 914, 915, 918, 920, 921, 923, 924, 927, 928, 933, 934, 935, 938, 941, 945, 946, 948, 949, 951, 953, 954, 955, 956, 958, 959, 960, 961, 963, 964, 965, 966, 967, 970, 971, 972, 974, 975, 977, 979, 980, 982, 983, 987, 989, 993, 994, 998, 1003, 1004, 1005, 1008, 1019, 1026 ...

# %%
tokenized_data = [msg.split() for msg in list(data["Message"])]
print(tokenized_data[:10])
# Out:
# [['이거보면', '왜', '갓창정인지', '알게된다'], ['창정헌'], ['라이언은', '내일부터', '연구실', '출근'], ['파티', '하는거', '아님'], ['헬파티'], ['헬파이어'], ['파이어에그'], ['리마리오'], ['프로도'], ['예스']]

# %%
from gensim.models import AuthorTopicModel
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger
from gensim import corpora
from tqdm import tqdm_notebook
from time import time

import os

# %%
# ATM에 사용할 Dictionary 만들기
if not os.path.exists('kakao(ATM)_dict'):
    dictionary = corpora.Dictionary(tokenized_data)
    dictionary.save('kakao(ATM)_dict')
    print(dictionary)
else:
    dictionary = Dictionary.load('kakao(ATM)_dict')

# ATM에 사용할 corpus 만들기
if not os.path.exists('kakao(ATM)_corpus'):
    corpus = [dictionary.doc2bow(doc) for doc in tokenized_data]
    corpora.BleiCorpus.serialize('kakao(ATM)_corpus', corpus)
else:
    corpus = bleicorpus.BleiCorpus('kakao(ATM)_corpus')

# %%
print('Number of authors: %d' % len(authors))
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of authors: 6
# Number of unique tokens: 114854
# Number of documents: 162861

# %%
# dictionary함수로 만든 사전에 있는 단어 보기
print(dictionary)
for idx in dictionary:
    print(dictionary[idx])
# Out:
# Dictionary(114854 unique tokens: ['갓창정인지', '알게된다', '왜', '이거보면', '창정헌']...)
# 갓창정인지
# 알게된다
# 왜
# 이거보면
# 창정헌
# 내일부터
# 라이언은
# 연구실
# 출근
# 아님
# 파티
# 하는거
# 헬파티
# 헬파이어
# 파이어에그
# 리마리오
# 프로도
# 예스
# 호우
# 팟팟헌
# 리마리오헌
# 느끼헌
# 안그래도
# 오늘힘듬
# 대단
# 허리
# 괘안
# 이정도는가뿐
# 즐거운
# 첫츌근
# 야옹
# 돈많이
# 벌어와유
# 보고싶다
# 프로도신
# 그래도
# 다행인듯
# 얼굴봐서
# 저번에
# 되었다
# 만날때가
# 이제
# 튜브를
# 기대하라
# 다음주
# 굿굿
# 2박3일
# 곤지암으로
# 담주에
# 스키타러감
# 데려가삼
# 스키담
# 하앜
# 라이언
# 여기
# 좋음
# 너의
# 떠나버린
# 세컨과
# 졸업하고
# 닮은
# 아이
# 잇음
# 목소리도
# 비슷
# 심지어
# 다름
# 이름이
# 하지만
# 연수아냐
# 신수인씨
# 신수인
# 10학번이랑
# 이름똑같넼
# 걔는
# 남자
# 물론
# Ma
# 굿
# 금결원
# 많음
# 이쁜사람
# 교육받는중이려나
# 4명임
# 여자
# 몇명
# 입사
# 25
# 1
# 6분의
# 간택될수있을것인가
# 과연
# 어피치는
# 되야함
# 미스코리아는
# 지노우
# 없어짐
# 팬더
# 무지
# 팬더버림
# 변하니
# 사랑이
# 어떻게
# 바람둥이임
# 나픈아이
# 저런
# 벌써
# 여럿울림
# 먹튀
# 당연
# 그건
# 기본임
# 이런마
# 노답
# 지하철
# 퇴근
# 모습으로
# 복귀예정
# 새로운
# 조만간
# 모으는줄
# 발견해서
# 사려고
# 엄청난
# 쿠션을
# 푼돈
# 중
# 최악
# 2호선
# 과소평가한듯
# 그동안
# 내가
# 2호선은
# 그자체임
# 시간대의
# 이프로도대마왕
# 진정한
# 그정도
# 되지
# 기운내삼
# 출근시간의
# 지옥그자체지
# 3개보내고
# 4번째탐
# 2명을
# 보며
# 힘내삼
# 끝나
# 언제
# 튜브
# 아심
# 12일넘어서
# 1월
# 만나자고함
# 데리러가는일은
# 없길
# 한강으로
# 빨리
# 슬픔
# 기다리셈
# 돈이
# 없음
# 알바
# 누가
# 사갈까봐
# 조마조마중
# 진심
# 백곰카페라도
# 너무
# 따뜻하다
# 복지가
# 연봉과
# 머스트
# 컴
# 제발가고싶다
# 담학기뒷통수
# rr
# 고고담
# 넘는
# 상상을
# 초봉이엇움
# 건설임
# 라이언의
# 목표는
# 왕국
# 많아야함
# 여사원이
# 가야함
# 그리고
# 나와
# 브라질을
# 없다
# 포기할수
# 2월
# 돈모아서
# 한번에
# 건설예정
# 이주해서
# 아마존담
# 초봉얼마임
# 얼마
# 예상
# 넘는다
# 안했던가
# 오천좀
# 그런줄
# 알앗눈데
# 더
# 따뜻햇음
# 좀
# 쩌는데
# 어피치
# 역시
# 갓헌
# 말햇던
# 면접때
# 안좋게
# 알고보니
# 임원이
# 서강대
# 출신이엇음
# 3명
# 밖에
# 없눈듯
# 전체에서
# 라이언도
# 석사따면
# 프리패스임
# 석사
# 혜택
# 군대가
# 차라리
# 혜택큼
# 갓투사
# 1호봉
# 2년이라
# 공군은
# 높음
# 육군은
# 쳐주고
# 이런
# 2호봉
# 겅군은
# 사기다
# 3호봉
# 장교는
# 계장부터
# 시작
# 장겨출신은
# 인정한다
# 여자는
# 낮게
# 군대안가서
# 샷
# 남녀평등
# 800차이
# 초봉
# 있었으면
# 좀만더
# 최고였을듯
# 여사원
# 많지
# 않은듯
# 현대보단
# 세컨보다
# 이쁨
# 그
# 던진건가
# 또
# 이프로도
# 이후로
# 잠잠하네
# 폰
# 잡아와
# 닮은아이
# 미친
# 개쩌네
# 6천얼마
# 한
# 최고
# 사랑스럽다
# 진짜
# 좀만
# 참으삼
# 오고있음
# 인형이
# 커밍쑨임
# 아름답지
# 원래
# 그래도칼퇴시켜주니
# 매우
# 좋네
# 개털리고옴
# 교수님한테
# 나는
# 5시퇴근이라
# 칼퇴는아님
# 성원이형
# 5시임
# 아
# 천국이네
# 논문써야되서
# 아이디어
# 안나와서
# 털림
# 내라고
# 너뮤
# 아이디어를
# 계속
# 그래서
# 갈구시는중
# 뭐라고
# 보통
# 성원이형은
# 함
# 그런식으로
# 접근하면안된다고
# bfs말고
# dfs로
# 하래
# 방식을
# 생각해야
# 심도있게
# 쭉
# 문제해결이된다고
# 데프콘도
# 다른
# 동근이는
# 박사형들한테
# 세미나에서
# 핵털림
# 박사형들도
# 스타일로
# 텀
# 오랫동안
# 참교육받으심
# 성원이형한테
# 갈구는군
# 성원이형이
# 은근히
# 잘
# 교수님들
# 다
# 모든
# 비슷할듯
# 석이형은
# 아니지
# 않나
# 인성이형이랑
# 개빡셈
# 인성이형
# 돼
# 인성이형이
# 갈구진
# 않잖아
# 개갈굼
# 알앗는데
# 착한줄
# 착하지않음
# 개빡세대
# 헐
# 아마
# 관심없을듯
# 근데석사생개많음
# 13두명
# 또들어간
# 이번에
# 누구
# 디비랩
# 디비랩인기개많음
# 신기
# 닥쳐봐
# 임구마언제봉인해제냐
# 곧
# 임구마
# 해제함
# 아니
# 머치
# 하우
# 만팔천원
# 웃
# 산다
# 이맛에
# 고마워요
# 다들
# 핳
# 드럽게
# 사놓고
# 욕먹음
# 집에선
# 핳핳
# 네오짱도
# 올라왓데
# 끝났데
# 면접
# 튜브도
# 유혹
# 카톡
# 거부함
# 알아서
# 온다함
# 딜이
# 라이언이랑
# 모종의
# 있는듯
# 설마
# 🔞
# 그러타
# 공유인듯
# 세컨
# 2명이라
# 원레
# 2명이
# 승격함
# 이엇던
# 트리플
# 1명씩
# 스와핑담
# 렌탈담
# 오늘도
# 난봉꾼임
# 오늘부터
# 3일간가족여행임
# 아쉽
# 너는
# 도시락
# 먹어
# 굳
# 어디꺼
# 석천이오빠꺼
# 혜리꺼
# 밥
# 사먹어
# 도시락이
# 머가
# 좋아
# 사실구라임
# 걍
# 귀찮아서
# 밥사먹기
# 샌드위치먹는다
# 서브웨이
# 개굿
# 그거없음
# 귀엽스
# 버려
# 한솥도시락
# 없어
# 튜브이랑
# 홍반
# 나중에
# 구마년소환점
# 꼬셔야함
# 너가
# 난
# 수험생이니
# 알아서꼬시도록
# 달려올거임
# 바로
# 야동주면
# 떠오른다
# 오바워치가
# 갓헌과
# 함께
# 넌
# 연습좀해
# 한조
# 시발
# 님들
# 12시
# 이번주
# 토요일
# 안양오셈
# 튜브만나러
# 면회
# 오키
# 모여라친구들이여
# 갈수도
# 늦게
# 토욜이네
# 끝난건가
# 오
# 튜브이
# 그날
# 까지
# 놀겠지
# 베이베
# 안재워줄거야
# 갈수
# 있을듯
# 저녁때까지
# 확실히
# 사랑
# 여전한
# 포에버임
# 멈추지않아
# 논스탑
# 저녁에
# 프로도타랑
# 5급
# hsk
# 날이라
# 넘어갈듯
# 보고
# 오전에
# 피곤하다
# 저녁몇시귀가할꺼냐
# 모르지
# 튜브삘에따라다름
# 난일단보류
# 모유
# 모유담
# 맛잇음
# 과사녀
# 나옴
# 모유가
# 뭐
# 왜안자
# 출근안하냐
# 합숙연슈옴
# 술
# 열라마심
# 공부방
# 출발하냐
# 프로도타는
# 집에옴
# 핸폰두고다님
# 너그럼
# 주말에못오겠네
# 술먹고주정
# 가지
# 귀가
# 내일
# 언제컴백하냐
# 그렇구만
# 숙취해소하고와라
# 저녁먹고
# 토욜
# 부부장님
# 사기임
# 마심
# 말하면서
# 슐만
# 망함
# 앉아서
# 자리
# 잘못
# 마스터가되는게
# 이참에
# 뻗은척하셈
# 적당히마쉬고
# 그래
# 너도
# 쉬어
# 나픈
# 팬도
# 그럼
# 전부오는건가
# 3시까진
# 갈겡
# 멀어가꼬
# 셤장소가
# 1시까지오래
# 일단
# 튜브씨가
# 1번가집합
# 1시에
# 임즈님이
# 맥날임
# 임즈님은
# 모름
# 아마그럴지도
# 명돈
# 임즈하면
# 명돈환
# 극혐
# 거기
# 세트
# 솬이
# 좋아함
# 그럼가야지
# 점심먹고오신더니
# 튜브님
# 나와함께미리점심하실분모집
# 맥날팸
# 모여라
# 얘들아
# 몇시에
# 와
# 일찍간다던데
# 일찍와서
# 나
# 바로감
# 운동뛰고
# 12까지올사람
# 손
# 프로도타
# 오바워치
# 할듯
# 12시턴
# 네오이도
# 얼른들모여
# 일찍오면
# 임즈
# 조은데
# 저녁엔
# 점심먹고온대
# 그래야
# 사주는데
# 점심
# 주고가삼
# 카드
# 그냥오라니까
# 사먹겠음
# 우리가
# 개굳
# 집에서먹고온개
# 다시한번
# 꼬셔보갰음
# 꼬시기
# 늦은
# 점심으로
# 12시점심
# 꼬심
# 와라
# 12시30
# 아뷰리털고
# 잇으삼
# 30이전에
# 가긴
# 할건데
# 모르니
# 혹시
# 먼저
# 바로갈게
# 있으면
# 점심먹고
# 빨리오셈
# 개춥네
# 하
# 개추움
# 따시게
# 오늘
# 입으셈
# 시험화이팅
# 네오이
# 대리시험
# 시헌잘봐라
# 아이온에잇을테니알아서오3
# 프로도아
# 아이온에
# 튜브이있다
# 만나라
# 만남
# 내려서감
# 감
# 나도
# 가자
# 먹고
# 오버워치
# 어렵네
# 중국어
# 내랴감
# 멈
# 쉬다
# 암튼
# 갈듯
# 두시반이면
# 출발했습니당
# 어디잇을거임
# 어디냐
# 전화좀
# 우리
# 이미아이온임
# 10분
# 이내로
# 아이온
# 화장실임
# 네오아
# 도착하면전화
# 가는중
# 춥네
# 아이온으로
# 컴컴
# 아빠옴
# 안옴
# 노래
# 녹음한거
# 업로드
# 노래방
# 안감
# 오늘은
# 근데
# 녹음응
# 안함
# 미리브탁하지
# 오늘즐거웠다제군들
# 꿀잼
# 몰려옴스
# 피로가
# 사진
# 복귀한데
# 합격하면
# 헿
# 빠른시일내에
# 이렇게또모이길
# 예스예스
# 목에
# 상처남
# 개
# 거슬리네
# 그녀의
# 손톱자국
# 목안
# 노래의
# 어제의
# 여파
# 어제
# 피맛나는느낌이었는데
# 따뜻한거많이먹고
# 닥치고자니까
# 좀나아짐
# 낫음
# 뭐가
# 안에
# 흑흑
# 목암
# 음
# 인연부름
# 모여서
# 오랜만에
# 튜브가
# 추억노래
# 특집함
# 임원
# 뷱극곰은
# 안키윰
# 북극곰이
# 키우는거일걸
# 팬더vs북극곰
# 닥
# 북극곰
# 님이
# 목안에
# 목지짐
# 염증이
# 있었음
# 구덩이
# 만들어서
# 약채움
# 지지고
# 조심해라
# 훅간다
# 노목무지
# 관리해야함
# 관리도
# 탈모
# 곧휴는
# 쉬야할때만
# 라이언처럼
# 자주사용
# 거절함
# 더블데이트
# 라이언이
# 가소로운
# 녀석
# 그렇잖아
# 더블데이트하면
# 하러가기
# 들고다니는걸로암
# 따로
# 원래개인텐트
# 무관
# 장소는
# 같이
# 거칠게
# 다니면
# 못다룸
# 인정
# 브라질
# 2월이
# 기회일듯
# 삼바삼바
# 달려
# 🏃🏃
# 데려와
# 윤아씨
# 챙겨서
# 텐트
# 🏪
# 갖고싶다
# 나왔던데
# 베라에
# 팬더케이크
# 대신
# 먹어줄게
# 걱정
# 🐼🐼🐼🐼🐼
# 사진이라도
# 맛은
# 무의미
# 나만의
# 비밀
# 미미
# 부넝슈워더
# 아이니준희
# 어디에
# 준희는
# 흑
# 문하영이
# 성정체성을
# 준희의
# 크다
# 흔든건
# 몰라
# 문하영과
# 있을지도
# 함께하고
# 임마
# 잘못이
# 꼬임에
# 너와
# 몇몇
# 아이들에
# 문전박대
# 뿐이야
# 수상함을
# 알고
# 했을
# 고백한거잖아
# 넘어가
# 양아치야
# 이
# 입니다
# 피해자
# 대보세여
# 증거를
# 비선실세
# 이준희의
# 들었다
# 자리에서
# 들어야햇단
# 말입니다
# 방에서
# 울부짖음을
# 라이브로
# 1대1로
# 결과를
# 아는데
# 너희들이다
# 뛰어들게
# 불바다로
# 한건
# 아니야
# 피해자야
# 너
# 다행으로
# 배에서
# 아셈
# 안던진걸
# 준희가
# 나임
# 뻔한거
# 살려준게
# 자살할
# 준희
# 다음날에도
# 만난
# 했네
# 멋지군
# 그럴줄
# 알았습니다
# 버릴수
# 없는
# 한조를
# 남자의
# 어디까지인가
# 한계는
# 없지
# 프로도이에게
# 한계따윈
# 프로도잡는
# 안듣는다고
# 알아봄
# 죽일때부터
# 개웃겼음
# 히이즈어어쌔신
# 그냥
# 단순
# 맘에
# 안듬
# 이유는
# 듣지않은
# 말을
# 자신의
# 댓가로
# 처결
# 어리둥절핼
# 노는게
# 우리끼리
# 제일재밌음
# 요새
# 튜브이가
# 콜하던데
# 주말에
# 한번볼까
# 내려가기전에
# 네오찡
# 주말에는
# 프리할거고
# 나도그러하고
# 너도그러하고
# 주말
# 일요일가능
# 괜찮긴한데
# 토요일도
# 7시반에
# 약속이있어서
# 토요일에
# 두탕해도되지만
# 바쁨
# 주말은
# 산행
# 회사에서
# 맞다
# 일요일엔
# 안되는구나
# 복귀
# 물어봤는데
# 붙으면
# 온대
# 이렁
# 롯월
# 일욜
# 호오
# 나도놀고싶다
# 2시간씩하련다
# 오버워치는
# 이호한조
# 와카테도쿠라이
# 건배사
# 추천
# 깐빠이
# 부서
# 이렇게
# 폭파가능
# 하면
# 하라는데로
# 건배사함
# 성원이형도
# 파워
# 배치받음
# 운영부
# 어떤일을함
# 운영부는
# 그대로
# 네트워크
# 등등
# 말
# 서버
# 운영임
# 개발은
# 이럴수가
# 좋은거
# 좋지
# 얼타는중
# 개발이좋지않음
# 세계임
# 모르겠는데
# 봤다
# 이름은
# 느껴졌다
# 덕력이
# 사방에서
# 개마심
# 슐
# 하셈
# 지금도
# 지하철은
# 헬인건가
# 그럴떈
# 보는거임
# 이름은을
# 치트키좀
# 라이언만
# 휴
# 사업
# 접음
# 복귀해
# 과장임
# 어린
# 제일
# 평범
# 공략
# 이미
# 평촌
# 오버워치중일듯
# 이런미친놈들
# 세상을
# 이미친
# 경쟁전
# 그저께
# 올림
# 이백점
# 눈
# 오는
# 세상이다
# 지배하는
# 프로도타가
# 눈사람
# 만들고
# 싶아
# 숙취
# 몸그렇게만들고
# 조루수준이네
# 체력
# 아저씨
# 팰뻔
# 후두려
# 새치기
# 짜증나네
# 그게
# 지하철의일상이지
# 매일본다
# 서울역에선
# 눈오는날은
# 믹스가
# 티오피가된다
# 깡패호험
# 닥쳐
# 너의이름은
# 보3
# 분꿀꿀하면
# 이따퇴근하고
# 범계역
# 안되겟다
# 코노와
# 4곡만
# 타키군
# 나이
# 토모에
# 미츠하
# 덕력
# 충만하다
# 기모찌이이
# 삼바같은
# 친구들
# 기미노
# 나마에와
# 명작이야
# 두번봄
# 오보에테
# Search
# 덕후
# 될지도
# 모르겠다능
# 이거
# 팬더쳐
# 미즈하
# 개꿀잰
# 내
# 생각에
# 이애기만
# 한다
# 한동안
# 뭐하고
# 지금
# 오버
# 롤
# 같은데
# 될거
# 해도
# 그런듯
# 나도그렇게생각함
# 금의환향을
# 본인은
# 원하는듯
# 봐야함
# 나오는건가
# 뉴가
# 좆밥임
# 평점이
# 평가못함
# 평점으로
# 여형이라는
# 영화
# 얘기가있음
# 하아
# 교수
# 2일까지
# 파이썬마스터해오래
# 성원
# 교수님
# 이상함
# 답
# 통수가
# 이미당했으니
# 여기서
# 뽕을뽑고간다
# 가야지
# 존나
# 커서
# 뽑힘
# 도망간자의
# 여유
# 창렬하다
# 어디야
# 가면
# 서식할듯
# 님들은
# 창렬형님들
# 편의점에
# 점심도
# 창렬하고
# 조지면됨
# 프로도이
# 코노
# 12시에
# 걸어와라
# 범계로
# 운동
# 노래연습
# 거기에
# 겁나
# 데이식스
# 목소리
# 비슷한애
# 있음
# 강습
# 받을거임
# 프로도타한테
# 재밌다
# 킹
# 기대만큼은
# 막
# 다운받아
# 보시길
# 승호햄
# 햄헌
# 비엔나헌
# 죽순무지
# 많은
# 파트너가있음
# 마
# 고고한척
# 악마가안에있음
# 색마임
# 단지
# 상대가
# 없을뿐
# 고2
# 그때
# 그렇다면
# 라인
# 지움
# 가름
# 배를
# 현자타임으로
# 황금거위의
# 안될놈은
# 안됨
# 즁딩
# 소개좀
# 부탁
# 공유는
# 독식
# 쉬바
# 다잊고
# 미즈하가
# 짱이다
# 미야미즈
# 입덕햇냐
# 미츠하아아
# 요츠하아아
# 망했다
# 안양외고
# 성추행
# 2대1도
# 경쟁률
# 똥학교됨
# 망한건가
# 없어서
# 이과
# 이과있을걸
# 비공식적으로
# 망한듯
# 비공식적이라
# 과고이런데는
# 넘기는데
# 십대일도
# 외고들
# 바래야할판
# 안없어지길
# 우리학교
# 외고는
# 그냥망함
# 아냥와이까오
# 우리의
# 않는
# 이상
# 재단이사장
# 취임하지
# 갈아엎지
# 이사장으로취임하면
# 학교
# 광수형
# 바꺼주셈
# 사서
# 학교좀
# rnt
# 프로도외고
# 호혐외고
# 이런이런
# 뭐하심
# 이럴때일수록
# 몸조리
# 집에서
# 부럽
# 나는연구실에서
# 공부하다
# 파이썬
# 인천감
# 만드는중
# 발표자료
# 임튜브은
# 밥먹고
# 유가네서
# 엌
# 유가넼
# 닭갈비볶음밥
# 닥치라우
# 병우
# 우병우헌
# 청와대헌
# 비선헌
# 헌
# 정어피치병우같은놈
# 경쟁전으로
# 오버워치나해
# 1960점임
# 배치고사끝냄
# 1차끝나고한번더달릴테니
# 2월말에
# 실력닦아놔라
# 잘한거임
# 중간정도
# 맘먹으면
# 플래까진좁밥이다
# 2500만들고와라
# 최소
# 넘음
# 이번시즌
# 배치고사
# 짐
# 같웅
# 염보성
# 염보성을알아
# 스타충이네
# 아는가
# 어케
# 스타신임
# 바름
# 이영호도
# 뭐임
# 종족
# 색꺄
# 혼종이다
# 혼헌
# 편의점도시락
# 그거
# 완전
# 창렬하지
# 낫베드
# 도시락은
# 퀄리티
# 편의점
# 안면도임
# 갓음
# 블리자드
# 시전하고
# 여기는
# 프로도신이
# 오줌
# 자제좀
# 배설
# 설사험
# 닮은애
# 데이식스에
# 신기방기
# 부름
# 비슷하게
# 구냥
# 담
# 마스터임
# 카마수트라
# Av배우
# 괜찮을듯
# 데뷔해도
# 가끔
# 일본가는게
# 찍고옴
# 다만
# 브라질에서만
# 판매함
# 입수해야할듯
# 하나
# 그럴듯
# 여러분
# 소식이있습니다
# 초대형
# 들은준비되셨나요
# 들을준비되셨나요
# 아는사람이
# 있을수도있지만
# 임튜브씨가
# 약대에합격하셨습니더
# 고대는예비번호래
# 붙고
# 차의과대학은
# 이제소환해
# 힘내자프로도아
# 사랑한다
# 친구야
# 그런의미로
# 임즈소환하고
# 방금
# 확인해서지금
# 미쳐잇는가봄
# 소환할게
# 좀이따전화하면
# 집근처에
# 3년을
# 기다렷으니
# 커피숍뭐있냐
# 공부어디서하냐
# 우리집
# 커피숍천지지
# 공부어디서함
# 독서실이지
# 카페는잘안감
# 독서실다니는데뭐하러감
# 오호
# 와이
# 생겨나서
# 우후죽순으로
# 커피숍도
# 한창유행탈때
# 20개넘음
# 300미터
# 가본커피숍만
# 근방으로
# 우리집에서
# 근데왜
# invited
# 앗
# 어서와
# 젠장
# 하이루
# 선수를빼았겼꾼
# 그의
# 드디어
# 컴백
# 잠깐
# 왜케
# 진동
# 바이브레이터
# 설정가야지
# 심하지
# 쑥스
# 그런것부터
# 붙자마자
# 준비하다니
# 되엇굼
# 허허
# Im
# back
# come
# 고대도
# 붙었으면
# 나서
# 내고
# 예치금
# 고대
# 발표라
# 드랍가믕
# 안되나
# 50만원
# 머리쓰네
# 이자식들
# 증발
# 50만원과
# 고대중
# 그래더
# 내야지
# 어느것을
# 이건가
# 택하겠습니까
# 고대지
# 당얀
# 무서운녀석들
# 50갚지뭐
# 알바해서
# 맘편해서
# 정말다행임
# 신기하네
# 핸드폰도
# 바꿔야지
# 얼마만이냐
# 갤3
# 하고
# 아이폰으로
# 잠만
# 궁해
# 합격하니
# 돈이라서
# 미안해짐
# 그게낫지
# 그치
# 돈좀쓰면어때
# 이녀석들
# 붙었는데
# 크으
# 꺄
# 거기얔
# 끌려갔네
# 신입연수
# 이하
# 아하
# 타임
# 펀
# 해피
# 개추우
# 대낮부터
# 어피치도
# 되더니
# 직장인이
# 클라스가
# 펀타임이라니
# Fun
# 수줍
# enjoy
# eat
# 하앍
# 튜브이도
# 페북
# 페북은
# 노노
# 어차피
# 되어있음
# 입학하면
# 하게
# 그때가서
# 하나하나
# 해가야지
# 가로지
# 무엇보다
# 개인정보
# 소중한곳에
# 잘쓰겠음
# ♡
# 인증
# 발표난
# 애들
# 잇는데
# 못생김
# 나만
# 합격한거
# 모르겟네
# 아닌가
# 냐일
# 해야함
# 행군
# 30
# 15겠지
# 30키로
# 졸잼각
# 군대야
# 직장이
# 국정원임
# 사실
# 뭔
# 행군을
# 여행갈수있게되었군
# 국내라도
# 졸잼일듯
# 부산쳐들어가지뭐
# 아니면
# 네오이가
# 안내해줄거임
# 간김에
# 샤홍도보고
# 흐흣
# 그것도
# 나름
# 재밌을지도
# 는
# 일본이
# 태국이나
# 개쩜
# feat
# 녀가
# 붙은걸
# 아나
# 알아야하는데
# 그뇬
# 년
# 둘
# 셋
# 넷
# 그뇬하고
# 작년
# 제작년
# 둘은
# 먹음
# 붙었을리가없음
# 특히
# 조용히
# 많이함
# 강남에서
# 공부중
# 성대
# 자퇴라니
# 개나이스
# 기다려왔따
# 이날만을
# 닿음
# 부모님과
# 연락
# 고기집
# 고기가지고되나
# 난감한게
# 고대붙음
# 애들은
# 붙엇나
# 연락해야되나
# 떨어졋다하면
# 한번
# 안아주고
# 끝
# 알면
# 한거
# 깔텐데
# 눈치
# 붙엇다는거
# 알게되겠지
# 잇어야겟네
# 붙엇으면
# 셧업해야함
# 아끼는
# 여동생임
# 붙어라
# 그후
# 💏
# 👉👌
# 4년된
# 남친
# Its
# you
# 박효신
# 그렇지
# 투나잇
# b
# 튜브이딸부자네
# 고통이지
# 휴지만
# 로션추천
# 신세계임
# 흠
# 아니다
# 로션보다
# 좀더
# 좋은게
# 알로에젤
# 이런거
# 이자식
# 푸슣
# 하자
# 무지랑
# 손잡고
# 브라질한번가야되는데
# 바다
# 바다래
# 뭔말
# 거의
# 공허하다는데
# 심해
# 깨달음
# 삼바의
# 열정을
# 받으러가야지
# 빨리고옴
# 슈발축하한다
# 임구마자식아
# 돈벌꺼냐
# 알바하면서
# 솬
# 얀습해
# 하는즁
# 꽉차니
# 좋구만
# 카톡방이
# 맞춰놔
# 이천점만
# her
# 여전히
# 팬더구나
# 포에버
# 낳으면
# 바꿀
# 의향있음
# 자식
# 보기좋구만
# 팬더시키
# 사람이
# 일관성이
# 있어야데
# 씻자
# 골드
# 만들어와
# 오버워치나
# 너랑
# 안씻어
# 재미없어
# 해
# 봣는데
# 영상
# 유투브
# 겐조
# 궁
# 돌더니
# 휙
# 5명
# 연속처치
# 겐지
# 용나가는거
# 칼휘두르는건
# 색마
# 프로도인
# 씻어
# 씻엇지
# 구석구석
# 사타구니
# 연습해서
# 옵치
# 발라주센
# 프로도이좀
# 안돼
# 게임
# 빠져들면
# 미침
# 놓음
# 정신줄
# 롤만큼
# 중독성은
# 눈아퍼서
# 오래못함
# 피방을
# 롤을
# 하지
# 햇지
# 이젠
# 해도되니
# 뭐하지
# 간만에
# 야동
# 간만은
# 씻은거
# 아닌거같은데
# 매일
# 약속
# 자신과의
# 1딸
# 1일
# 점잠
# 점점
# 같아지네
# 타락한거
# 그렇다는건
# 3
# 라이언임
# 내가없는사이
# 그런
# 별명이
# 조용한게
# 생겻네
# 하는중
# 한판
# 어마어마한
# 좁밥임
# 임
# 실화임
# 어떤
# 꿈
# 스토리
# 트루
# 꿈이
# 아니군
# 궁금하면
# 싸면
# 현실
# 안나오면
# 몽정
# 남자들의
# 톡방은
# 이렇지
# 돌려보센
# 팽이
# 현실이군
# 인셉션
# 쓰러질거임
# 임셉션
# 임션
# 엠연
# 롤하러
# 출근하는거
# 모이지
# 보고싶으면
# 평일에
# 가셈
# 서갇대로
# 기다림
# 꼭
# 중이라
# 미리
# 연락을
# 하고가야함
# 배려지
# 없네
# 하러간듯
# 휴지와
# 손이랑
# 정부인
# 뭔가
# 피곤하군
# 패스
# 연중무휴
# 3임
# 분발
# 강인하군
# 달려있음
# 쇠뭉둥이가
# 힘들군
# 클라스
# 턱걸이함
# 턱걸이
# 하면서
# 야레야레
# 오해야오해
# 턱걸이임
# 걸어두고
# 여자를
# 박는듯
# 올라가면서
# 턱걸이로
# 대단한
# 시스템
# 대단하군
# 사이
# 안보는
# 일석삼조시스템
# 기술이
# 늘엇구만
# 기술
# 힘
# 부족한게
# 가장중요한
# 없는게
# 다같이
# 파뤼하러가자
# 삼바
# 가야할곳
# 돈모아
# 이것은
# 가능한짤
# 강철의
# 봐야
# 연금술사를
# 이해가
# 누구임
# 과장님
# 맛잇겟다
# 족발
# 이대
# 전자
# 전기전자
# 나오셧구나
# 저분
# 25임
# 동생
# 해보이
# 맨
# 왼쪽
# 여
# 일찍
# 자자
# 나이가
# 나이인지라
# 아껴야데
# 예쁘시긴한데
# 소개팅은
# 약대
# 입학후
# 외모
# 저정도면
# 합격인데
# 고기
# 많이
# 소고기
# 채끝
# 녹음
# 입에서
# 육회로도
# 채끝은
# 크
# 운동도
# 오키오키
# 굉장히
# 잉여스럽군
# 그런거지뭐
# 대항할
# 마헌에게
# 수
# 있다
# 부탁한다
# 봐본사람
# 요즘
# 텝스
# 거임
# 등장할
# 시간즘
# 1시간
# 후
# 1시
# 30전후로
# 등장함
# 가뿐히
# 호혐은
# 그럼됨
# 성욕을
# 억제하기위해
# 뛰어야함
# 그정도로
# 열심히
# 하네
# 반까지
# 없는데
# 해본적이
# 돌면서
# 와서
# 중공
# 카톡함
# 미쳣네
# 도는
# 중공을
# 맡긴다
# 상상에
# 쩌네
# 방어
# 낼
# 출근아님
# 연수중임
# 안면도
# 4명이야
# 동기가
# 포함
# 합치면
# 경제
# 법무
# 전산
# 행정
# 4명
# 여자가
# 저
# 수트빨
# 지림
# 여자4
# 여기임
# 그리며
# 연수중이구만
# 저걸
# 심리치료중이군
# 존잘
# 군인이구만
# 다시
# 느낀건데
# 응응
# 그에게
# 바톤터치를
# 오기에
# 프로도이가
# 하겠다
# 답이
# 문과는
# 서울대
# 굿밤
# 아항
# 나에게
# 잠재워줘
# 프로도타를
# 닥치라고
# 할게
# 없을때
# 깝쳣구만
# 많이도
# 굴에서
# 왕이엇다
# 이리가
# 호랑이
# 가슴이
# 아파요
# 괜찮네
# 저여자분
# 이날씨에뛰면
# 뒤지기딱좋음
# 쥭을듯
# 행군하면
# 가장
# 추운데
# 얼어죽는건가
# 동파헌
# 엄청
# 고생이
# 많네
# 어피치가
# 아이온임
# 예정
# 유가네
# 점심에
# 집임
# 쉬자
# 자고
# 잠도
# 그치만
# 위드
# 훔
# 같이잇지
# 아빠
# 엄마
# 하고싶은것들
# 해야지
# 오후
# 행군은
# 그런가보네
# 출발지
# 살아돌아와
# 고생이많구만
# 가리고
# 뎅겨
# 얼굴
# 솬이는
# 아이온와라
# 점심까지
# 오면
# 그럼나도감
# 닥텨
# 공부해
# 아직도
# 저거네
# 프사
# 1차끝나고달리게
# 오버워치연습좀해놔
# 딕텨
# 연습할까
# 연습해놔
# 내생각에더
# 도
# 잘함
# 롤보다는덜함
# 빠지긴할텐데
# 훅
# 질린다
# 한달내로
# 이방
# 일타다
# 렙이
# 백이다
# 질려서
# 워낙
# 익히는데시간오래걸릴수도
# 임구마가
# 호구라
# 두시까지
# 들어와
# 삼일전에
# 어제보니까
# 했더라
# 마지막으로
# 배치돌린다햇자나
# 이색꺄
# 내리
# 막판3판
# 위도우로
# 팟지찍고끝냈다
# 연습하고와라
# 한조같은놈
# 라인하르트
# 넘
# 딱임
# 한조가
# 한조도
# 멋잇는데
# 보이는데
# 프사가
# 허전해
# 드림
# 보자
# 사진좀
# 콜렉션있음
# 쓰셈
# 원하는거
# 낰
# 고구마
# 뭐냐
# 임구마임
# 맨위의거
# 생각보다
# 잘생겻네
# 뭐지
# 임팩트
# 그정도는
# 아니고
# 재밋구만
# 건데
# 셀카
# 엠디엔피에서
# 저거
# 찍엇던
# 돋네
# 추억
# 다운
# 포켓몬고
# 일어낫네
# 라이언군
# 바쁜하루라
# 피곤햇겟구만
# 갓구만
# 자러
# 자지
# 안자지
# 자지마
# 말아
# 보지마
# 맞군
# 딴사람
# 뽀오지이
# 히앍
# 야외화장실
# 누구냐
# 나다
# 뀨
# 색마둘
# 드셧는가
# 점심은
# 2시반에먹을예정
# 맛잇게
# 밥도
# 돌아가며먹어야
# 제맛
# 다양하게
# 달자
# 강의중
# 뭘
# 피방와
# 없쪄
# 현금
# 시간
# 잇긴잇구만
# 충전된
# 개이득
# 커먼
# 13분남음
# 확인한거
# 피방갓엇으니
# 시간이
# 같이만나서
# 하지뭐
# 설낳이네
# 낳
# 오타
# 설날
# 졸귀
# 갓더
# 골드찍고싶다
# 너희와
# 어울리기
# 위해
# 한다만은
# 약대가서도
# 잇으니
# 할수도
# 연습은
# 보지
# 갓헌이
# 무섭게
# 추격중
# 열심히함
# 은근
# 근성남
# 혹우
# 노력파헌
# 파헌
# 아놔
# 맥은
# 북미서버밖에
# 안되네
# 나랑
# 롤하고
# 싶으면
# 북미서버에서
# 해야할듯
# 가능
# 밤이나
# 평일
# 10일날
# 노트북을
# 뺄때
# 신촌방을
# 가져올건데
# 연구실에
# 내뒷자리에
# 모니터
# 연결해서
# 거기를
# 사용할건데
# 윈도우로
# 게임할까
# 그전에
# 만나자
# 언제볼가
# 기다려
# 그때는
# 만날때를
# 온라인에서
# 얘기하는것이니
# 집에서는
# 못하지
# 안
# 된다고해도
# 꾸져
# 컴터가
# 모니터도
# 어제부로
# 합격한
# 돌변
# 양아치로
# 바뀜
# 부모님의
# 자유로움
# 태도가
# 만나고
# 친구도
# 고생했는데
# 그러라고
# 하심
# 놀아야지
# 놀아라
# 다해서
# 최선을
# 친구여
# 3년동안
# 못논거
# 압축해서
# 존나노셈
# 존나놀아야
# 후회가없다
# 15
# 213
# 플래
# 오티
# cc가자
# cc하는법
# 알려줘
# 내가전문가인데
# 특강해줘
# cc는
# 학과
# 차의과대학
# 다른학과는
# cc
# 별로
# 안좋아
# 깨지면
# 몇명인데
# 사람
# 60
# 사회가
# 좁대
# 30명이면
# 결혼각이네
# 사귀면
# 26
# 전체는몇명
# 40되겟다
# 스게
# 멀어서
# 학교가
# 왔다갔다하면서
# 평소에
# 반이라고
# 연애하긴
# 힘들거라
# 되어야할듯
# 주말커플이
# 영등포에서
# 차대까지
# 1시간컷
# 신촌에서
# 자취
# 30분
# 영등포까지
# 아니고…
# 영등포역쪽이면
# 스쿨버스
# 1년반
# 과외했는데
# 영등포역쪽에서
# 1시간걸림
# 스쿨타고
# 괜찬지
# 않음
# 1호선
# 얘기하는거
# 영등포
# 1시간이면
# 30분45분
# 잡아야하니
# 3시간통학
# 그러니
# 긱사지
# 긱사
# 달려야지
# 무조건
# 신청함
# 아빠랑
# 얘기햇지
# 크으으으
# 기간
# 신청
# 아밈
# 아직
# 1900점
# 찍엇다
# 님
# 함께한다
# 영등포까지만
# 케어해드림
# 스쿨버스라니
# 돌아갈때
# 빡치긴하겠지만
# 뭐아니면
# 자고가
# 돌아가면되지
# 아침에
# 타고
# 그런거라면
# 만약
# 생으로
# 서강대이대연대홍대
# 자
# 슬슬
# 정진희
# 남친이
# 생각해보자
# 소개팅을
# 약대임
# 차대
# 불러
# 조건을
# 뒤져서
# 문제는
# 없을듯
# 찾아서
# 씨한테
# 안진우
# 갠톡으로
# 보내도되고
# 손무지씨가
# 소개팅
# 전문가라
# 사달라고
# 선배님
# 개웃기넼
# 얘기해놧대
# 크으으
# 인맥
# 꾸벅
# 말좀
# 바라는거
# 1주정도
# 걸림
# 스캔하는데
# 워워
# 글래머
# 글래머가
# 주위에있었으면
# 남미
# 내가get
# 했을거라
# 골반보단
# 스고이
# 골반
# 분들이
# 주변에
# 기달
# 가슴만
# 사람은
# 있지만
# 큰
# 좋지않아
# 최대한
# 진정하게
# 친구
# 이쁘고
# 착한애
# 넓은
# 씀풍씀풍
# 500일이네
# 담주면
# 오오
# 531
# 우리는
# 30몇일
# 차이난다고
# 0일
# 했던것
# 까야하나
# 멀티
# 멀티는기본임
# 많이나옴
# 유닛이
# 더블커맨드
# 선구자
# 두개임
# 앞마당만
# 가슴
# 커맨드
# 앞마당은
# 근처에
# 본진
# 지어야함
# 순간에
# 하나는
# 멀리지어야
# 안보이는
# 그녀를
# 보내고
# 후회중
# 파괴가
# 수원
# 그분
# 추천좀
# 까먹음
# 아디
# 그러면
# 자료를
# 저장되어있는
# 넘겨
# 튜브이에게
# 그걸
# 자료
# 들고다녀
# 폰에
# 컴터에서
# 채팅방이
# 갠톡에
# 다임
# 준게
# 지웠는데
# 갠톡도
# 나가서
# 보안을
# 걸릴까봐
# 여친한테
# 찾응수
# 내말이
# 걸리면
# 사망이라
# 폭탄임
# 당연히없고
# 폰에는
# 허흑
# 백업을해뒀어야하는데
# 솬보면
# 찾아는보겠음
# 분
# 쩌는
# 조됨
# 개쌤
# 80c였나
# 야동급
# 야동이야
# 리얼
# 개인적으로
# 가지고
# 있던거
# 무지가
# 소개받은거군
# 라이언한테
# 풀었으면
# 터짐
# 푸슛
# 뛰어갔을수도
# 수원으로
# 여인이네
# 지나간
# 그런분이
# 수원에
# 있었지
# 안전한거
# 하나있었다
# 이분이었음
# 거봐
# 미친다니까
# 저건
# 아무것도아님
# 01야
# 저게
# 01
# 가진것에
# 왜냐면
# 살아움직이는걸
# 동영상도
# 있었어
# 봐야한다
# 봄
# 개지림
# 라이언이라
# 버틴거임
# 잇는겨
# 노트북에
# 바라며
# 있기를
# 무지의
# 주더라
# 과정에서
# 그런거지
# 졸업프로젝트의
# 결과물임
# 맞아
# 결과지
# 데이터
# 수집의
# 인터넷
# 채팅
# 거기에거
# 여자을
# 나의
# 유려한
# 화술로
# 지리네
# 훗
# 수집햇구만
# 현자타임때
# 무서운거
# 이래서
# 현타가
# 나처럼
# 현재의
# 그러치
# 무의미하더이다
# 지금보면
# 지리지만
# 그당시엔
# 부질없었음
# 현타라
# 부질없네
# 밤에
# 봐야지
# 한번더
# 하려면
# 채팅앱을
# 삼사십분은
# 눈빠짐
# 수고햇네
# 고2라
# 영상들
# 움직이는
# 찾아봐바
# 찾아온다고해서
# 지운걱도
# 쫄아서
# 원조교제
# 돈
# 안줄거
# 못진다
# 아이의
# 인생은
# 책임
# 몇개
# 받았다
# 영상은
# 궁금하네
# 남은거
# 원함
# 지릴텐데
# 커몬
# 못올림
# 여기에
# 그정도임
# 갠톡
# 갠톡이지
# 당황
# 첨에
# 뻥인줄알았지만
# 볼게
# 화장실에서
# 그의말은
# 진짜였어
# 공부법
# 완벽한
# 보셈
# 이라는책
# 개꿀팁임
# 데스크톱엔
# 80읽었는데
# 놋북은
# 몰겠다
# 사서읽으셈
# 좋은책임
# 놋묵
# 공부하는데
# 도움이될듯
# 앞으로
# 놋북
# 저거나봐
# 놋북에
# 있는지
# 집가면
# 확인해보겠음
# 놋북이야
# 님들이
# 기대치를
# 에베레스트까지
# 올려놓고
# 기대치에
# 모자라지
# 데스크톱은
# 가물가물
# 받음
# 삼십개
# 캬
# 그중
# 육덕의
# 표본
# 얼굴은
# 내기준은
# 밑임
# 얼굴이
# 밑까지임
# 개이쁘네
# 밑또한
# 영상이
# 가슴보다
# 밑
# 한편으론
# 2가
# 고
# 가는군
# 길로
# 잘못된
# 고2땐
# 상상만핶는제
# 실천을
# 아이는
# 상상인데
# 나돈데
# 저아이는
# 훅흑
# 힘내자
# 계신다
# 정부인은
# 농염해지눈둣
# 나날히
# 발전중
# 스킬이
# 세짐
# 힘이
# 쪼이는
# 우린
# 참
# 지극히
# 더럽군
# 남자군
# 쌔면
# 정부인이
# 실제로
# 할때
# 안좋음
# 그만해야겠다
# 강한
# 악력에
# 적응이되면
# 않지
# 쪼이지
# 못주면
# 상대방이
# 힘을
# 아무느낌없어서
# 로션이나
# 젤을
# 허공
# 사용해야
# 슥슥
# 휙휙
# 들어왔데
# 자위기구
# 수입으로
# 정식
# 도전
# 곧이네
# 생일
# 만들겟다
# 여친을
# 사주시면
# 테스트
# 해보겠음
# 대표로
# 후기좀
# 후기
# 리얼하게
# 소리도
# 해드림
# 없을때도
# 예쓰
# 성드립이
# 난무
# 카톡방에
# 햇는가
# 너업을땬
# 이분이
# 지켜줌
# 클린한
# 톡방
# 매의
# 텐가
# 감시하심
# 눈빛으로
# 매서운
# 클린햇음
# 친구가
# 써봤는데
# 못쓰겠다고하던데
# 그거쓰면
# 너무쩔어서
# 아무느낌없을것같다고
# 명기시리즈가
# 개된대
# 을
# 자제
# 할까
# 자제하면
# 좋지만
# 지루되나
# 자제할수없으니
# 조루됨
# 급하게
# 야동을
# 발사하면
# 넘게
# 1시간씩
# 야동안보고
# 하는연습하면
# 공신
# 강성태
# 거기에서
# 나와서
# 샘이
# 성교육
# 해보고싶군
# 보려다말았는데
# 나쁜거
# 단
# 자위는
# 유익하다고하던데
# 달리면
# 빠르게
# 부담없이
# 오래
# 천천히이이
# 올라올때
# 참아보고
# 내몸을
# 느끼며
# 안된다고
# 조루
# 해서
# 맞아맞아
# 실제로할때도
# 치면
# 못달리므로
# 미친듯이
# 팔리니깐
# 끝내는데
# 후딱하고
# 자취를해야지
# 조루돼
# 조루된다고해서
# 실제로는
# 상대방의
# 저력에따라
# 달라짐
# 성감대를
# 자극하면서
# 하게되면
# 못이김
# 레벨이다르지
# 허리가
# 휘고
# 부들부들
# 프로포폴급
# 현자타임옴
# 개졸림
# 젖문가
# 전문가
# 문가
# 금방
# 끝내면
# 재미가
# 치는
# 개오래함
# 금방할꺼면
# 왜함
# 결혼을해야
# 해볼텐데
# 크흠
# 노래연습해
# 갓지
# 어제도
# gjf
# 학교앞
# 4곡
# 동네도
# 생김
# 천원
# 만족스
# 데이식스를
# 들어야함
# 들어볼까
# 목소리가
# 똑닮음
# 누군지암
# 들어보면
# 곡제목은
# 들어볼게
# 갠적으론
# 간다
# 겨울이
# 두곡이
# 최근꺼
# 난또
# 그러는줄
# 듣냐고
# 노래가
# 트렌디함
# 그렇군
# Who
# are
# 노래좋음
# 샘킴꺼
# 임원노래도
# 더원
# 신곡나옴
# 컴백함
# 안양에서
# 저번주에
# 나레이션하는거보니
# 예전같지
# 예전이
# 쩔엇나
# 전에
# 집가기
# 두곡
# 부르고
# 살길
# 연습만이
# 고쳐야
# 고음시에
# 전문가한테
# 상담
# 받아보고싶은데
# 보컬트레이닝
# 대학가면
# 달려볼까
# 고고
# 대학원가면
# 9학점밖에안들어서
# 다음학기에도
# 시간괜찮음
# 일주일에
# 한번받는걸로
# 합세
# 귀찮을터이니
# 두번은
# 왔다갔다하기
# 그렇게
# 가수데뷔를
# 다떄려치고
# 하는데
# 가자고
# 플라이투더스카이
# 씨오브러브
# 해주셈
# 등록할
# 부자임
# 거지임
# 학기중에
# 되어야
# 신청해서
# 조교를
# 보단
# 부자라기
# 생길터인데
# 쓸돈이
# 각각
# 부르자
# 날짜
# 잡아
# 설끝나면
# 됨
# 대흥역을
# 허
# 라이언을
# 보좌하러
# 보
# 보좌
# 보내줘야할듯
# 영상을
# 그게답이네
# 지웟다는데
# 있데
# 봐야알아
# 시큐리티때문에
# 지웠을수도있음
# 고문
# 아니길
# 희망
# 엑스비디오
# 가서
# 답일수도
# 한편보는게
# 안보지
# 요즘은
# 희망일수도
# 파일봉
# 고문희망이길
# 파일봉은머임
# 강자
# 웹하드
# 웹하드는
# 거기서
# 거기지
# 정확해
# 이분야는
# 최고임
# 라이언갓
# 김라이언
# 낼와
# 대흥서
# 밥이나
# 고생많앗구먼
# 퇴근언제함
# 슐마심
# 실감날때구만
# 2병
# 거리네
# 휘청
# 나가기
# 정신
# 제정신이네
# 카톡은
# 집가
# 1리터
# 달린다
# 포카리
# 가거
# 싶어도
# 못감
# 부장
# 조져
# 부장을
# 조져야됨
# 결제원주
# 건배사와
# 원샷
# 25명
# 13잔
# 1조
# 2인
# 술문화는
# 여전하군
# 안마시면
# 그렇진
# 마시게됨
# 마시다보먄
# 설날에시간되시는분
# 답쳐
# 독서실문닫아서
# 다같이공부할사람모집중
# 일번가서
# 공부
# 공부어느정도하고나서
# 하실분
# 2명모이면간다
# 닥쳡
# 내려갈듯하여
# 이번에는
# 전
# 많을걸
# 안여는곳
# 일번가도
# 뽀올
# 독서실은
# 돈아깝
# 이럴땐
# 아이온이지
# 프로도이네
# 가정방문
# 걱정되는게
# 오티때
# 추라
# 춤
# 춤대신
# 추면됨
# 노래부른다하셈
# 나의사랑아
# 잘있나요
# 들리십니까
# 제
# 하늘에
# 닿을때까지예
# 들리나요
# 아시나요
# 기선제압하셈
# 들
# 뭐해
# 춤수업해줘
# 강의좀
# 정도만
# 쓸어버리는데
# 니장점을살리셈
# 장점
# 후훗
# 참고로
# 여친아님
# 가
# 이걸윤아가본다면
# 뛰어가
# 자취하는
# 후배인데
# 우리집근처긴한데
# 모른척해드림
# 윤아씨한테는
# 기회는
# 찬스다
# 야식으로
# 달리셈
# 그리하여
# 달렷다
# 라이언이는
# 쉬지않고
# 지금까지
# 라이언이다
# 과사
# 창고에도
# 흔적이
# 집
# 으하
# 미스
# 자리선정
# 옆
# 뗫다가
# 사이에
# 팀장
# 소주소주소주소주소주
# 마셔도되
# 라고
# 하시지만
# 수고햇구만
# 맨날
# 술이네
# 술자판
# 술이야
# 늘
# 슐이야
# 끼고
# 옆에
# 긋
# 일정은
# 도착
# 역삼
# 좋겟지만
# 해방
# 정직원운
# 아니네
# 출퇴근이
# 확실하지
# 교육
# 5시는
# 무조간
# 그에
# 해당하는
# 들어오니
# 2000더
# 받움
# 윤영뷰라
# 돈이네
# 근무
# 뛰는
# 시기가
# 야간
# 잇어서
# 너에겐
# 돈임
# 돈돈돈돈돈
# 군대는
# 지나도
# 쥐뿔
# 거긴
# 쩔자너
# 문화는
# 나은듯
# 케이티가
# 운동한
# 이유가
# 위해서
# 조지기
# 술마실때
# 깝치면
# 너한테
# 조짐
# 개조져
# 2명은
# 안양주민
# 남자면
# 조지고
# 여자면
# 닥치고
# 프로도이면
# 춥다
# 나머지면
# 12
# 수원은
# 영하
# 밖인가
# 보군
# 십사도
# 우리동네
# 집이다만은
# 아이온갈때
# 따시게입어
# 금욜에
# 코노나
# 워우워우워우
# 후어어어어어
# 뭐야
# 너도와
# 안내려간다면
# 갈게
# 오지마
# 컴온
# 전날
# 뷰르고
# 잇오
# 하루동안
# 없는사이
# 자주
# 볼때
# 하는걸
# 집에
# 노래방기계를
# 사둠
# 초고수
# 기계
# 자체
# 냄
# 반주소리를
# 입으로
# 개고스
# 도라도로떠나라
# 할거없으면
# 도라도
# 엘도라도
# 25찍고와
# 뛰게
# 찍어
# 하루면
# 임스턴연습하고와
# 임스턴좋음
# 메타에서
# 좋아짐
# 받아야함
# 솬이한테
# 연습해
# 강도
# 너가연습해서
# 키워놔
# 물오름
# 올렸다
# 육백점
# 천삼백에서
# 뒹굴
# 헬스
# 도깨비하고
# 웃지말고
# 낭만닥터김사부
# 보는중
# 임깨비
# 끝나면
# 보려규
# 뿌리깊은나무
# 전에햇던
# 시크릿가든
# 봣엄
# 길라임
# 임즈원
# 박근혜
# 차병원
# 문제없느나
# 약대는
# 들어간거야
# 문제없음
# 클린함
# 서강대도
# 그런느낌임
# 다니는
# 이화여대
# 느낌
# 화날걸
# 화나
# 못하고
# 있어
# 헣
# 중독인듯
# 그느낌
# 군대때
# 느꼇엇지
# 이름에걸맞게
# 정어피치는
# 봄계
# 루시우연습해놔
# 미친소리하지말고
# 로데오도
# 토욜엔
# 밥아
# 숨긴거
# 실력을
# 쮸밤
# 그것보다못한실력을
# 숨기고있어
# 실력이
# 1차끝나고
# 오버워치만할거니까
# 이틀동안
# 밥들이
# 개잘함
# 트레이서
# 남는거
# 하허
# 맞춰주기위해
# 밸런스를
# 팀의
# 암거나
# 못햇음
# 얼마나
# 개못햇음
# 간단히
# 말하면
# 기억이
# 안남
# 했는지
# 수준
# 헥토파스칼킥
# 케어하느라
# 바빴음
# 수준이면
# 솔져
# No
# answer
# 솔져나
# 파라
# 개고수라니깐
# 2000도
# 안되는데
# 트레이서할꺼면
# 개고수일리가
# 40찍고와
# 레벨
# 트레이서로만
# 무지겐지가
# 호지
# 진지
# 돌아
# 말하는
# 성우
# 예쁘더라
# 취향임
# 아주머니던데
# 보이스
# 피싱이네
# 프로도급
# 슈밤
# 노리다니
# 아주머님을
# 이네
# 같군
# 고딩노리는
# 이프로도과
# 내놔
# 범죄자소굴인가
# 너만
# 응
# 불러서
# 죽돌이
# 할때가
# 버티셈
# 엊그제
# 이거보고
# 참어
# 현타
# 모닝딸굿
# 헛
# 뭐함
# 고추에
# 니
# 부조화걸기전에닥쳐라
# 그걸로
# 닥텨라
# 죽이기전에
# 부르고싶네
# 천년의
# 놔를위해써
# 눈물도
# 야햇던
# 촴와
# 갔다와
# 나홀로일번가
# 다녀와
# 잘갂잔아
# 혼자
# 5000원에무한인데
# 보드까페
# 평일에가면
# 혼자연습
# 학교앞으로
# 불럿엇는데
# 쩔엇엇음
# 나스스로
# 만족
# 안해서
# 끝내지
# 순간을
# 즐기고
# 찍
# 아하악
# 귀여운
# 녀석들
# 금단의영역
# 상남자
# 개멋있네
# 맨아
# 맨아래
# 사진보니
# 개많이
# 나았네
# 아토피
# 부럽다
# 꿀피부
# 지금은
# 허니무지
# 살을찌워야뎀
# 그런거
# 기름기가
# 몸에
# 피부존나터
# 기름기
# 얻음
# 살은찔수있는데
# 배만
# 운동하면서
# 찌우셈
# 그래야함
# 살이쪄야
# 유분이
# 살이
# 잇어야
# 결국운동을해야하는데
# 웨이트해야되는데
# 줄여야될듯
# 늘리고싶음
# 나두
# 이것때매
# 받아서
# 스트레스
# 고민도
# 헤어질까말까
# 기다리다
# 빡치면
# 헤어지고
# 가능한
# 사람으로만나야지
# 그래야지
# 없애
# 인간임
# 교체
# 성인이
# 예수
# 넴
# 즐감하셈
# 심심한것같아서
# 좋은거많음
# 권한이
# 없대
# 로그인
# 영상좀
# 회원가입
# 집가서
# 부탁햄
# 제발점
# 없을수도이씅
# 70이상
# 없을확률이
# 하흑
# 봅시다
# 사진으로만
# 후후
# 호구프로도
# 혹우혹우혹우
# 잉여롭군
# 영화한편
# 마션
# 마솬
# 악보보고함
# 듣고와
# 한번만
# 건강하자
# 받자
# 복
# 새
# 아자아자
# 올해
# 뭐여
# 야
# 한판이라도땡길라면일찍와
# 마블퓨처파이트신캐나왔더라
# 라이언껄로
# 집일
# 그대그대그대
# 지금들어봤는데
# 별론데
# 거부한다
# 뎀잇
# 8시엔
# 스벅열겟지
# 스벅에잇겠다
# 안양
# 1번가
# 집감
# 사줬었던그곳
# 놀다가
# 오후에좀
# 하고가야지
# 상황보고
# 거라도
# 들고감
# 읽을
# 사람너무많거나
# 집근처스벅갈수더
# 롸절
# 닥공
# 오전엔
# 쮸르밤
# 쭈밯
# 쮸발
# 호구야
# 잠수즁
# 호구라서
# 호구
# 달려가마
# 임즈야미안하다
# 어디
# 괜찬
# 깜놀
# 찬찬히와
# 가져와
# 캐리할
# 빈털털이로
# 털털맞고싶음
# 헤헤
# 나간다
# 10시엔
# 더늦게나와
# 어피치데리고와
# 데려와야지
# 같은
# 평촌인데
# 수원이고
# 아이온에있어라
# 나가면
# 카톡안되니까
# 나가
# 몇시쯤
# 도착인데
# 출발함
# 30분이면
# 출발해야겟네
# 도착햇는데
# 없으면
# 와이파이
# 집이군
# 하는거볼때
# 40분임
# 볶아먹자
# 점심엔
# 그때처럼
# 군대식
# 발악하면
# 뭘쪼개이년아
# 간짬뽕
# 닥쳐이년아
# 스벅은
# 잘갔다왔냐
# 이따가게
# 이년이
# 옷
# 입엇다
# 프로도이꼬
# 뺏어드센
# 스벅두잔
# 이디야세잔
# 줌
# 내꺼하나
# 챙길게
# 뺏으셈
# 살고싶으면
# 두번
# 안말한다
# 죽고싶어
# 출발해
# 야디
# 여는데
# 잇것지
# 벌기
# 분들
# 빼면
# 싫으신
# 어피치개깡패넼
# 난폭해짐
# 주의좀
# 순화시켜드림
# 참교육좀
# 프로도이부터
# 출발안함
# 버스가
# 설이라
# 절
# 안양1번가인데
# 아이온이다
# 대가리부터박아라
# 머리뽑아버린다
# 꽂아버린다
# 으로
# 클린
# 놀때말해
# 애들만남
# 들어오
# 지노
# 당하는중
# 참교육
# 겜함
# 아침부터
# 선점
# 점심먹고해
# 아이디
# 빨리와
# 빌려달래
# 롤안해
# 밑힌넘들아
# 롱
# 올따까지만
# 하는거임
# 서두르도록
# 강습좀
# 받아
# 오바와치
# 암걸릴뻔
# 호구들임
# 쓰레기임
# 겜은
# 이겨야
# 재밌는데
# 너무못함
# 트레
# 딴거
# 말고
# 친겨
# 튜브임
# 못함
# 하삼
# 좢밥들임
# 4시에
# 들감
# 무지야
# 이론
# 볍신
# 하나만
# 기브깁
# 나머지하나
# 잃어버림
# 이새끼
# Hohun1012
# dambang0326
# 이걸껄
# 해보셈
# 프로도볍신
# 1이야
# 보면서
# 폭풍눈물중이었는데
# 휴바르
# 흐규흐규
# 징호
# 아이디좀
# 삭제됬을걸
# 살면서
# 삼십판도
# 옴
# 니네
# 다어디가곸
# 아이디는
# 3개안쓰냨
# 내아이디
# 한판쌔리겠음
# 지금은뭐함
# 옵워
# 빠대중
# 30뷴만
# 20분
# 3개줬잖아
# 롤아이디
# 스타1으로
# 뭐안됨
# 바르고
# 롤은
# 솬이만
# 1승1패
# 오버워치즁
# 관전중
# 다됨
# 코노옴
# 가던
# 저번부터
# 내다보고잇지
# 밖을
# 구대그대그대
# 암
# 담배
# 마셔서
# 열라
# 피방에서
# 나감
# 목
# 아이온시설너무후진듯
# 겨우
# 이겼네
# 바라보기중
# 아이온컴터
# 업글좀
# 해야겠더라
# 바라보기
# 독주
# 흐어어어어
# 뷰름
# 트레이닝
# 임효환
# 김치찌개
# 먹으려하는중
# 프로도이랑
# 부대찌개
# 부대찌게
# 먹는중
# 바닥
# 보이게
# 개잘먹음
# 존잘러
# 상남자헌
# 냄비채먹으려는거
# 저거지금
# 지금도만남
# 1일인듯
# 둘이
# 헤어짐
# 사귄날에
# 공부함
# 낼부터
# 이럴거같아
# 개열심히
# 붙을거임
# 들어감
# 오후에
# 찌개먹는거보니
# 붙을듯
# 합격각임
# 자세부터가
# 냄비
# 씹어먹을기세
# 씹어먹음
# 공부를
# 씹어먹을듯
# 입술도
# 숨겨왔던
# 해커스
# 텝스는
# 왜필요
# 심심
# 강남
# 범계
# 대려다줌
# 대충
# 데려다줌
# 강남해커스가
# 대학가보다
# 나음
# 그럴수도
# 벤치에
# 본관앞에
# 사람구경
# 앉아
# 그벤치
# 꾸르잼
# 벤치
# 해볶짬먹고
# 구경하고
# 동영썜시간에
# 잠
# 개꿀
# 무릎팍보여줄떄
# 일어남
# 봉투에
# 준
# 필요없지만
# 간직
# 고이
# 오우
# 잘돌려줄생각으로
# 고거채로
# 들고뎅김
# 항상
# 준비해여지
# 이쁜애보면
# 힐거면
# 여친
# 잘지냄
# 더블넥서스체재
# 가보고픔
# 스타
# 어피치랑
# 2대1
# 비등하다가
# 프로도도
# 졋음
# 2대1좁밥
# 텝스는왜함
# 당장
# 안하고
# 공브할때
# 피트
# 공브
# 공부하는
# 미트
# 사람들이
# 미트이제
# 800목표로
# 하길래
# 없어지지않음
# 모르던
# 뉴걸들과
# 수강하길
# 해피해피한
# 나오나
# 몇점
# 한벙
# 개비싸
# 보려고
# 셤이
# 실제
# 햇는데
# 얼만데
# 4만
# HSK거의
# 십마넌이여
# 그거보단
# 팔구만정도
# 4만원도
# 비싸
# 고민중
# 볼까
# 240만
# 넘기면
# 접을텐데
# 중독됫근
# 2월에
# 본건
# 최근에
# 있는데
# 추가시험이
# 1월에도
# 보긴함
# 기출문제로
# 추가가
# 고득점이
# 되게
# 잘나온디야
# 삘이
# 210
# 느낌인데
# 전후가
# 230정도만
# 같다면
# 할거
# 재도전하지
# 볼려고
# 정보처리기사
# 밥임
# 2주면
# 필기는
# 하루밤
# 하루
# 4회짜리만
# 기출
# 붙음
# 풀고가도
# 책
# 필요
# 따
# 땀
# 싼거
# 저렴한거
# 찍말고
# 찟
# 찍찍
# 프슛
# 천장에
# 쏘셈
# 하지마
# 환쏘공
# 환쏘물
# 우웁
# 으아앙
# 푸우우우우우우
# 물
# 쏘아올린
# 환이가
# 찹찹
# 끈적끈적
# 나이트임
# 기사
# 신촌
# 파고다
# 고다
# 종로
# 들을떄
# 섭
# 이쁜
# 있었는데
# 조교가
# 빡공할떄라
# 마니해서
# 질문
# 친해졌거든
# 설렛는데
# 하루는
# 그분이랑
# 집가는데
# 데릴러오더라고
# 남친있는건
# 알았음
# 걸어가는데
# 빠이
# 앞에서
# 길에서
# 엉덩이
# 조교
# 주무름
# 짧지만
# 사랑했다
# 빵댕이
# 길가인데
# 주물임
# 치는게
# 툭
# 뒤질라고
# 가만히있음
# 널
# 사랑해서
# 잠깐이나마
# 행복했다
# 흐
# 연애함
# 그건또
# 전문이지
# 잘하는데
# 사랑하고
# 너여서
# 허험
# 맘이
# 아프다
# 장면이
# 주무르던
# 눈에
# 박혀있다
# 내생각엔
# 나보고
# 남친분이
# 건드리진
# 뜻인듯
# 말란
# 그녀와의
# 끝냄
# 사랑을
# 낫지
# 사랑하지
# 몰래
# 사귀고
# 알앗지
# 사겼음
# 문젠
# 상대방도
# 시작하고
# 끝낸다
# 잇엇음
# 곧추세움
# 갠차너
# 붙엇음
# 괜차늠
# 올거
# 트럭몰고
# 계시임
# 신의
# 이건
# 말햇듯
# 인적데이터베이스에서라면
# 걘
# 암것도
# 생각하면
# 아무것도
# 그럴땐
# off
# 콩깍지
# 고화질
# 올라옴
# 그거보면
# 못잠
# 개피곤
# 그거볼떈
# 던지고
# 폰도
# 영화에만
# 집중해야함
# 마치
# 부넝슈워더미미
# 효과
# 샤오미
# 샤오위
# 샤오미는
# 전자제품회사
# 분먕
# 샤오위라고
# 남주
# 생각햇는데
# 샤오미로침
# 주걸륜
# 배역
# 배우말고
# 이름
# 배터리는
# 샤오미지
# 안나네
# 허흠
# 미츠하와
# 타키군은
# 남는다
# 오래동안
# 샹륜
# 타키쿤
# 써잇음
# 이라고
# 장담한데
# 저거봐
# 본사람은
# 저럼
# 장담한다
# 맨날저러고다닐듯
# 옵치하는데
# 취향을
# 잘알자
# 아디가
# 어떤애
# 순정
# 이름은인데
# 10명이
# 이런거좋아함
# 이럼
# 보내줄까
# 보면
# 잠꺰
# 파일있는대
# 야함
# 너의이름은이고
# 이름만
# 틀면
# 끝내줌
# 아비가일
# 스토야
# 생기네
# 흥미
# 이름은은
# 궁금
# 강력함
# 오키타
# 안리
# 슉슉
# 본다
# 뒤에
# 밤에보는걸
# 사람잇어도
# 돌출
# 강려크해서
# 여운이
# 조낸
# 뭐니
# 끙끙앓아야함
# 공포
# 아련
# 장르가
# 로맨스
# 판타지
# 누가봐도
# 일본틱함
# 남주이름은
# 타키
# 오허
# 호
# 일본애니가
# 삼백만이나
# 대단한거임
# 센과
# 치프로도의
# 행방불명보다
# 잘나감
# 진짜개쩜
# 날라감
# 집중해서
# 피곤한데
# 아무것도하지않고
# 두시간달려
# 영화관에서봐야
# 끝남
# 된다
# 사라짐
# 피곤
# 냉수나
# 녹차
# 한사발하고
# 못자므
# 집중모드
# 잘수있음
# 꿈에서
# 꿈속에서
# 미츠하를
# 찾게됨
# 아련하구만
# 내사랑
# 영화관가면
# 프로도이같은
# 보러옴
# 세네번씩
# 재밌다능
# 돌아오기전까지플래찍어놔
# 당연히
# 봤을듯
# 뭘봄
# 볼만함
# 몇번봄
# 3번
# 2번
# 스트리밍으로
# 한번하면
# 기본인
# 세번은
# 3연
# 5연
# 윽
# 탁탁탁탁
# 성욕억재
# 애닝
# 흐윽
# 객개궁금
# 갓헌의
# 떨어지게할정도임
# 성욕억제제임
# vs
# 콩나물
# 승자는
# 성개방국가라는
# 편견이사라짐
# 쉬었다는
# 풍문이있음
# 윤아랑같이봤는데
# 그렇다구
# 봐야겟음
# 씻고나서
# 구석구석씻고
# 경건하게
# 벗은채로
# 안녕
# 잠시만
# 상태에서
# 순수한
# By
# 임수
# 달리고오삼
# 검색중
# 찾음
# 내일로
# 스킵
# 반드시
# 선택
# 좋은
# 바르느라
# 쀼발럼
# 까다로움
# 여주
# 미츠하데스까
# 외치게
# 노래방땨매나고개피곤
# 일찍자야쓰것가
# 4주후에보자
# 이혼조정신청
# 대추
# 대치
# 골리앗
# 드랍가서
# 탱크하고
# 올
# 갓헌은
# 머고름
# 6개에
# 드랍쉽
# 탱
# 거렷음
# 몸빵해준거
# 모두
# 테테테
# 어피치와
# 입구쪼이고
# 못차림
# 정신을
# 쪼이니깐
# 쪼여주면
# 없군
# 하앍대다가
# 헌쏘물
# gg
# 날려
# 바로프로도
# 침
# 2대1근데
# 다음판
# 발름
# 프로도이날
# 신기한거
# 이기는게
# 호험이
# 그러다가
# 발림
# 어피치한테
# 겐지로
# 설침
# 교육좀
# 프로도인그냥
# 던져놔야됨
# 크게
# 부담없고
# 정크랫이
# 좋은듯
# 쟈
# 갓헌이면
# 할수있음
# 익힘
# 정크랫도
# 정크는
# 시프트
# 쓰고
# 터트리기
# 탱뺴곤
# 한방에
# 킬함
# 고거가
# 꿀
# 아주
# 궁도
# 굴러가다가
# 바스티온이
# 쏴서
# 가야되서
# 어렵
# 예측샷으로
# 평타가
# 0킬
# 많이탐
# 맵성향
# 어려워서
# 타겟팅이
# 정크랫으로
# 쏘아주면
# 게이지
# 차더라
# 레스트인데스
# 감으로
# 그떄의
# 돌아오셈
# 허흡
# 굉장해서
# 뎀지도
# 정크랫
# 좋긴하지
# 타이어
# 유툽에
# 정크랫장인들
# 플레이보면
# 궁으로
# 검색하면
# 눈쟁이
# 장인있음
# 정크
# 검색해봐야지
# 올라운더긴한데
# 특출나게
# 천년의사랑
# 무리임
# 할수잇음
# 1년
# 프로젝트
# 군대때는
# 혼자하기
# 힘들엇엇는데
# 이따
# 1000원
# 자세야
# 노래에
# 빠져들고
# 잇구망
# 코치
# 튜브가서
# 목이
# 아프네
# 침삼키면
# 현재
# 미츠야를
# 보러가겟음
# 다냐오센
# 빼고
# 안쉼
# 사기수준
# 콘서트해서그럼
# 1번
# 솔플후
# 쉼
# 그랫지
# 상처날지도
# 나를
# 참아
# 동안에
# 들엇니
# 천년이가도
# 너를
# 잊을
# 때문에
# 사랑했기
# 가버림
# 목도
# 회복환
# 다시섬
# 말하는거였음
# 남자는
# 빨라야지
# 회복이
# 둘다
# 좀잇다
# 쳐들어갈까
# 아닐듯
# 안양인들은
# 강남서
# 잘보고오시오
# 넵
# 가는김에
# 괜찬은보면
# 헌팅
# 피슉
# 괴물아
# 모닝하는
# 똥
# 딸
# 이무기헌
# 튜브이오늘
# 강남감
# 예압
# 끝나고
# 올라갈까
# 못잇겟네
# 봐유
# 셤이나
# 넹
# 강남에서뭐함
# 2
# 2잔
# 2편
# 공짜
# 공짜추가
# 금액
# 내면
# 너희라면
# 다른걸로
# 매달
# 선택할겨
# 스벅
# 아메리카노
# 중에서
# 두편
# 나좀
# 데리고가
# VVip혜택인데
# 유쁠
# 수험생이엇어서
# 햇엇거든
# 2번이
# 유용할라나
# 나같으면
# 고민되네
# 1번이
# 더쓸모있을듯
# 여친생겨도
# 영화는
# 그런가
# 잘안보게됨
# 바빠서
# 무지처럼
# 영화좋아하면모를까
# 커피
# 다른거
# 마실수
# 개인의
# 취향차이임
# 영화보다
# 무지는
# 커피보다
# 글쿤
# 정햇다
# 너로
# 커핀데
# 표내놔
# 가질래
# 아이디로
# 로그인한다음
# 슈바
# 한거임
# 개읏기네
# 타이밍이
# 앵무새
# 쥑임
# 가린거
# 눈만
# 없나
# 살아잇남
# 아롱이
# 쥬금
# 이게
# 시절임
# 말출
# 임구임구
# 전역후
# 2일후
# 기억함
# 정확히
# 1021
# 2012년
# 찍은거임
# 자다가
# 군대
# 동기
# 모르지만
# 몇일
# 제대햏는데
# 못생겻다면서
# 증명해보라고
# 프사찍어줌
# 개웃엇지
# 서로
# 개웃걋음
# 군대에서도
# 서로의
# 씹창이라고
# 지냇지
# 하며
# 저사람
# 호구임
# 혹우프로도
# 존잘남이네
# 모아두고
# 안지우고
# 잇네
# 은밀한
# 찍음
# 본인
# 강한남자
# 강담
# 왜찍음
# 왜찍엇음
# 올렸었음
# 저장함
# 보여줄라고
# 저장해옴
# 앨범에
# 대박이네
# 강함이
# 뭔지
# 길쭉하네
# 다리는
# 그가
# 보여주었다
# 보았다
# 아마존을
# 수북하군
# 매생이국
# 본의
# 아니게
# 안구테러인듯
# 최강자가
# 강함은
# 부드러운법
# Po매생이wer
# 매생이
# 무섭군
# 올리면
# 가겟네
# 죽을때까지
# 왔다
# 쩔었는데
# 피자몰애서
# 가을정도였는데
# 걸치고왔는데
# 후드하나
# 넘처
# 자신감이
# V
# 내림
# 절반을
# 지퍼를
# 찌찌아슬할뻔
# 보자마자
# 인사보다
# 근육
# 쩔지
# 올려줌
# 지퍼
# 올릴걸
# 찍고
# 해볶짬
# 집인데
# 크흑
# 라이언네
# 캉놤
# 예전사진앨범보다
# 흠칫함
# 된줄알았는데
# 만료
# 놀람
# 되길래
# 저장이
# 감상하셈
# 나체담
# 꿈을
# 꿧는데
# 자느라
# 잠시
# 공방에서
# 카트라이더
# 햇어
# 몇시임
# 5시
# 가볍게
# 맞을듯
# 게임한판
# 아냐아냐
# 칼바람
# 미루고
# 자꾸
# 설정은
# 머리자름
# 집중하셈
# 도깨비
# 랑
# 비슷하네
# 그러리가
# 다봄
# 개이쁨
# 사기
# 분으로
# 가슴은
# 만져봐야함
# 주물주물
# 만져보는것도
# 울면서
# 안적고
# 하윽
# 사랑해
# 적음
# 개자식
# 멍청이임
# 해피엔딩이니
# 개예쁨
# 선배도
# 예쁨
# 그분이
# 리얼임
# 막힘
# 차가
# 망햇네
# 대설특보임
# 발린듯
# 사당
# 잇으려나
# 지옥철타면됨
# 매일탐
# 아니메
# 지옥철
# 다행이군
# 럭키한
# 15분
# 강남까지
# 걸려야할텐데
# 버스탐
# 사당에서
# 다행히
# 도착할듯
# 빨리와서
# 시간내에
# 강남가는중
# 보러
# 텝스모의고사
# 서초
# 누구만남
# 안만나
# 안맞네
# 텝스만남
# 시간여유
# 응가
# 잇겟지
# 할
# 응가타임
# 후두둑
# 설사환
# 김에
# 나가는
# 낮에
# 블리자드라
# 구해
# 자취는
# 주변
# 첨이라서
# 조언
# 살거
# 포천까지
# 들어가거나
# 가게
# 문닫힘
# 도꼬오
# 도꾜
# 오보에떼
# 글씨
# 손에
# 적은
# 한글
# 해석중
# 곳
# 라이언에게도
# 물어보고
# 물어보면
# 물어봐서
# 사람있으면
# 선배들
# 시세나
# 연락닿는
# 편한
# 학교다니기
# 곳도
# 발품파는게
# 사는
# 직접
# 집은
# 최고인듯
# 네오
# 깨진다는거
# 긱사가
# 낫나
# 긱사랑
# 시설은
# 월세
# 저렴하지
# 긱사살면서
# 동기있으면
# 정보도
# 주워듣고
# 지금당장
# 구할라면
# 집을
# 들어갓다가
# 시세를
# 2학기
# 막상
# 부터
# 좋은방이
# 집구하는건
# 1학년
# 다니고
# 물어봐도
# 부동산가서
# 시세
# 알려줄듯
# 생활
# 처음이라서
# 자취하고
# 그쪽
# 추천인데
# 주변에서도
# 학교근처
# 왜냐믄
# 웅웅
# 금욜날
# 신청이라서
# 선배는
# 알게된
# 없는거지
# 그래야겟다
# 해봐야지
# 모르신대
# 잇긴한데
# 듣는게
# 선배한테
# 어떤지
# 주변시세랑
# 최고이긴
# 한데
# 괜찬데
# 긱사는
# 근처라
# 방들
# 비싸지
# 않을까
# 포천이라도
# 시설
# 양호하다면
# 고마워
# 맘
# 바뀌면
# 자취로
# 라이언과
# 어쩌라고
# 자취라이프는
# 그런방법이
# 노놉
# 비효율적이지
# 거기가
# 삼을라고했는데
# 아지트로
# 이거또한
# 무스비
# 끈이론
# 티팬티
# 입는거
# 극치
# 시함의
# 긱사에
# 이불
# 침대만
# 책상도있을걸
# 긱사마다
# 책상은
# 침대랑
# 이불은
# 몇인실이야
# 1실도
# 잇고
# 1도잇고
# 4인
# 어때
# 코골면
# 긱사와
# 자취의
# 장점은
# 높은
# 잇을듯
# 코골이
# 확률로
# 가깝고
# 싸고
# 비싸고
# 조금멀고
# 세세하네
# 그지같거나
# 대신에
# 룸메이트가
# 통금이있거나
# 동거
# 라이언과의
# 정기적으로모여야하니
# 귀찮은것이있지만
# 프리하지
# 1인1실이라면
# 다해야한다는것과
# 모든걸
# 자취의단점은
# 좀비싸고
# 기숙사면
# 약대끼리
# 우선
# 보증금이있다면
# 예를들어
# 마련도
# 보증금
# 쉽진않지
# 룸메이트는
# 상승함
# 편할확률
# 같아서
# 높아
# 스케줄도
# 안불편할
# 확률이
# 긱사살아보고
# 자취하는것도
# 좋고
# 괜찮고
# 여러명이
# 자취를
# 하는것도
# 생가면
# 여자친구가
# 200배좋음
# 자취가
# 살다가
# 4년살건데
# 하도록
# 해야겟다
# 맘대로
# 술존나먹다가
# 그렇다가짤릴수도있지만
# 안들어가고
# 너의자유지
# 인원체크하지
# 그럴수
# 달라
# 잇어
# 통금은
# 긱사마다다름
# 다있음
# 물어봐야겟다
# 긱사를
# 선호하고
# 여자애들이
# 남자들이
# 선호함
# 종합대
# 통금
# 고시텔같은건
# 많이없을것같고
# 포천이라
# 긱사게네
# 하숙자취
# 없을걸
# 의대
# 그렇다고듣긴함
# 선배가
# 우리보단
# 짱임
# 모르니까
# 포천에대해선
# 진리임
# 기숙사신청언
# 모여살진
# 않을듯
# 약대생만
# 그럴걸
# 살듯
# 섞여
# 핵노답인데
# 그러함
# 성대는
# 따로살듯
# 섞임
# 성대약대랑
# 일반대랑
# 큰차이없으니
# 가능하겠지먼
# 근처야
# 병원이
# 캠퍼스
# 포천
# 네오이전문임
# 몰겟네
# 뭔말인지
# 저말
# 캠퍼스가
# 포천에
# 수업은
# 포천에서
# 하구
# 엘에이
# 판교
# 갈고옴
# 배터리
# 엘에이개굿
# 낼모레
# 맞는지
# 물어보는게
# 쓰는거
# 약대끼리만
# 전화에서
# 좋을듯
# 학교에
# 선배라니
# 그분한테
# 제일좋을듯
# 물어봄
# 물어봣고
# 같기도하고
# 실례일것
# 전화해서
# 확실하니깐
# 무얼
# 생각하는거지
# 이친구
# 우리나이정도되면
# 다그런거지
# 31일날
# 고대에서
# 다햏는데
# 온다면
# 준비를
# 합격전화가
# 좋을까
# 리얼나이스지
# 행복튜브
# 다가진
# 제발그랬으면
# 좋겠다
# 고대가면
# 진짜좋을텐데
# 가길
# 고대를
# 고대한다
# 가되길
# 고대가서
# 전문
# 노래는
# 임효환의
# 잇어야되
# 코치가
# 노래도
# 지
# 마스터
# 지그
# 파이썬공부하는중
# 85함
# 거의마스터직전
# 효환
# 2곡
# 없으니
# 지도마
# 우리지도교수님
# 정성원
# 조심히
# 지금은어디
# 발라드랴
# 도서관
# 성대역
# 앞에
# 아프던데
# 해봄
# 레벨이
# 시도할
# 있는
# 딱
# 레벨은
# 소주한잔
# 정도임
# 응급실보다
# 나비야
# 죄
# 3개
# 순서좀
# 하이피치가
# 높은순서면
# 순서임
# 어려운순서는
# 자체가
# 그마아아알
# 부르던
# 동균이형
# 그리워어어어
# 니모습이
# 죄가
# 아니나
# 은
# 그나마
# 쉽지
# 충분히됨
# 루그는
# 그녀가
# 부정행위는
# 컨닝은
# 했지만
# 명곡
# 끝사랑
# 소화햇다면
# 가능했던
# 거
# 소절이라
# 2인팟
# 한소절만힘듬
# 좋던디
# 무지우
# 원석임
# 제련안된
# 원석이지
# 딱딱해
# 딱딱함
# 소프트힘
# 쏟고온거
# 쏟음
# 넓고
# 마니하면
# 연습
# 음역대도
# 잘부를듯
# 주말마다
# 다니면서
# 데리고
# 하드트레이닝
# 내가대신
# 올웨이즈
# 하나보균
# 개오래됨
# 안한지
# 하고싶음
# 조르기
# 안통함
# 졸업
# 보기로함
# 화요일에
# 어디감
# 스페인갔다가
# 어제돌아옴
# 물어보게
# 다음주에
# 연수가나봄
# 되길바래
# 방문
# 버랴
# 수면제
# 반란
# 세컨의
# 몽둥이가
# 폭주
# 하려
# 될것인가
# 쓰려져서
# 기젉
# 기절
# 단발하고
# 이뻐짐
# 윤아씨도
# 이쁘잔슴
# 애매함
# 스타일
# 윤아이쁘지
# 세컨이
# 괜찮은데
# 어떨땐
# 모르는
# 애임
# 그저
# 끌려다닐뿐
# 무스비에
# 어피치알자
# 어피치많이봄
# 2년감
# 그래픽스
# 랩실
# 복학2년동안
# 석사뜀
# 친철하심
# 여러모로
# 친절하지
# 말로는
# 착하대
# 나이는
# 동갑
# 동기임
# 노리는
# 위협할
# 정부인을
# 소개시켜줄려고했는데
# 어쩔수
# 없었다
# 내치듯이
# 준희를
# 매정하진않았으
# 짊어지고가야함
# 평생
# 바빴을뿐
# 과
# 인해
# 전공으로
# 상황
# 추론
# 매정하게
# 무지임
# 준희한테더
# 구주영
# 애초에
# 정을떈거
# 그분은
# 행동이
# 매정햇음
# 구주영한텐
# 미안하다
# 준희보다
# 갈때
# 학원같이
# 길정애
# 커커윽
# 추억추억
# 설연고와
# 위슬런
# 김밥천국
# 정원이의
# 길정앸
# 드립너무하넼
# 마법의
# 볶음밥
# 튜브이는
# 이지
# 10줄
# 김밥
# 솬이의
# 모르시네
# 신지여
# 지연이
# 구임
# 뭐하고사는지
# 아시는분
# 기정이랑
# 엠티가서
# 햇대
# 엠티가서했대
# 개오랜만
# 들음
# 빅매한테
# 성인
# 사귄거아님
# 기정이가
# 망해서
# 우울한걸
# 재수
# 사귐
# 수능
# 재수망했을때
# 엠틱
# 대화로
# 몸의
# 적절한
# 조치
# 푸는
# 그엠티가
# 엠티가
# 착하네
# 받은듯
# 해피해피하군
# 천사가따로없군
# 기정이는
# 뭐하고사나
# 소식
# 안외애들
# 개궁금함
# 그럴수도있음
# 우리반도
# 잘모름
# 들을수있음
# 모임
# 여자애들
# 가능성이
# 그럴
# 큰듯
# 나가라고좀
# 부모님보고
# 부모님들도
# 잘안만남
# 맨처음부터
# 인연이다
# 질긴
# 몇명만나던거라
# 계
# 인천부모님들은
# 마미도
# 울
# 인천부천끼리
# 만나다가
# 여긴
# 와해됨
# 우승
# 페더러
# 운다
# 흐귷규
# 그런의미에서
# 봤는데
# 손주희
# 누군지
# 영어과아님
# 난이미
# 켜져있긴함
# 8빈
# 중어과
# 기억남
# 같은반
# 10시에
# 신기하게
# 약간
# 교포삘나게
# 맞음
# 사람들
# 처다봄
# 한곡남음
# 겜돌이
# 천천히
# 오셈
# 나파이썬
# 강의듣고있으면됨
# 어듐의강의
# 폭풍눈물
# 백인덕
# 바로옆임
# 코노하고
# 피방
# 무료임
# 강요해서
# 들으라고
# 명강의까진
# 아닌데
# 실속은
# 짧아서
# 다시봐야겟다
# 자바나
# 죠져
# 모르는가
# 스프링
# 아무도
# 할줄
# 죠져줘
# 들어는봤지만
# 할줄모름
# 그래주면
# 매우감사
# 이거다
# 떠나
# 아이온에서
# 딴곳으로
# 옮겨야할떄임
# 프로도이집
# 비어잇엇다는데
# 나이트
# 가던곳
# 리드좀
# 전문가니까
# 가면됨
# 따라만
# 존문가
# 기다리는중
# 오버워치좀
# 하던데
# 은은하게
# 자주하더라
# 최근접속
# 안가봄
# 한번밖에
# 잘암
# 한번밖에안가봄
# 튜브이와
# 결과가다름
# 더고수임
# 이미들어와있음
# 3분만기둘
# 다음에
# 특강좀
# 순수덩어리들이라
# 두분만
# 따라감
# 믿고
# 솬즈
# 별별별별
# 끄
# 애쉬
# 페이커담
# 재미있었음
# 아쉬운
# 판도있었지만
# 승률
# 50이엇는뎅
# 그니까아쉽
# 재밋음
# 하니
# 누구내
# 어피치찡
# 쏘우1
# 생각함
# 스토리가
# 쏘우
# 좋다고
# 배고프네
# 7까지
# 1잔
# 우유나
# 해야겠군
# 군대에서
# 쏘우환
# 3밖에안봄
# 나는쏘우2랑
# 2랑
# 7만
# 공중에
# 뜸
# 짜임새
# 1편에
# 나오는군
# 의사가
# 나중에도
# 배고파
# 고든
# 박사님
# 닥터
# 라면
# 불륜의
# 전설
# 먿을때만
# 뷰다찌개
# 우유
# 봐바
# 잔인한거
# 제외하고
# 그맛으로
# 게
# 끌리는데
# 쫄깃한
# 보는거아님
# 아쉽군
# 내일이
# 마지막이다
# 연휴
# 슬프군
# 부인도
# 개큼
# 시함
# 미시임
# 뒤지잖습
# 보여줌
# 안타까운죽음
# 그랫음
# 슴가큰사람
# 매너가아닌데
# 죽이는건
# 기본이
# 안되어있는
# 영화임
# 그러네
# 오점
# 나중
# 부인
# 직쏘
# 형사
# 호프만
# 담당하지
# 메인
# 역할을
# 긴
# 스토리군
# 야참
# 쫄깃
# 잘안먹는데
# 먹으면
# 치킨
# 피자나
# 먹으려면
# 피치가
# 갈색이어도
# 구두
# 어피치야
# 첫정장
# 단정한거
# 맞나
# 브라운이어도
# 그리
# 빨강
# 파랑
# 이런것만
# 검은색이
# 넘나
# 입는
# 정장
# 갈색도
# 신더라
# 남색검은색갈색이
# 기본이지
# 깔끔하게
# 신으면됨
# 예쁜거
# 단정
# 괜히
# 만나니까
# 걱정되서
# 땡스땡스
# 입어도
# 후드티
# 유급
# 가라구
# 편안하게
# 어피치처럼
# 내리고가삼
# 더쉼
# 그러는
# 소리임
# 편안해지라고
# 머
# 편한거야
# 안입는게
# 짱이지
# 농담임
# 사진도
# 안입은
# 위에
# 입원할듯
# 정신과로
# 검정구두
# 청색에
# 굳이
# 마삼
# 보진
# 올라가서
# 남색
# 진한
# 그자리에서
# 입원
# 비추
# 회색정장
# 갈색이나
# 검은색하려구
# 맞췃어
# 정장은
# 단정한걸로
# 무난
# 검색이
# 뭐든
# 괜춘함
# 듯
# 상갓집갈떄도
# 다용도
# 가까이
# 거만색이라
# 검은
# 멀리서
# 색인데
# 서
# 쓰던
# 예과때
# 투톤인걸로
# 아아
# 삼
# 새로
# 검색
# 뿌옇게
# 만나면
# 뭐가좋음
# 나오던데
# 나온다더라
# 투톤많이
# 맞춤
# 작년에
# 실습이라
# 다녀야해서
# 입고
# 멋짐
# 가운과
# 오래걸림
# 가운안에
# 여기까지
# 오는데
# 안입으면
# 바바리맨
# 가운
# 벗기고
# 간지네
# 동기들이
# 의사
# 환자의
# 문진해줄듯
# 경계를
# 허무네
# 나올듯
# 신문에
# 시키라고
# 입학
# 제대로
# 정신과
# 의대생
# 들어갔다고하더만
# 성대로
# 맞어
# 똑똑하긴
# 한가봄
# 그렇다더라
# 의대로
# 이게바로
# 그러게
# 될놈될
# 그사람은
# 손해본게
# 학교옮긴게
# 그니까
# 정의는
# 받아줫지
# 성적되니까
# 자체에
# 정시
# 인성이
# 또다시
# 거르는게
# 없으니까
# 터지면
# 머리가
# 좋으면
# 성대의대
# 이미지
# 되나봄
# 어떠케든
# 수능보고
# 접수하면
# 컴퓨터가
# 합격시켜줌
# 법의
# 심판이
# 필요하다
# 공부실력하나는
# 아역시
# 수능이
# 2월달에
# 생활하고
# 싶었는데
# 여유롭게
# 교수새끼가
# 던져서
# 안타깝네
# 동거해라
# 만들자
# 좋은데
# 그떈
# 빠져
# 여친금방만들면
# 양보하고
# 센스있게
# 상부상조
# 나가고
# 그날은
# 집가는날이지
# 문득
# 집가고싶을떄
# 가는거야
# 짜샤
# 엄마아빠
# 오늘이
# 보러가는날이구나
# 하면될듯
# 보러가고
# 누구는
# 될수도
# 아빠가
# 웃겻음
# 하이라이트는
# 매생이국아님
# 그게뭐임
# 본인이
# 올려주셈
# 못받음
# 차마
# 제발
# 검색하고
# 올라가면
# 위로
# 형
# 예쁘군
# 현주방에
# 아름다움
# 지릴뻔
# 업데이트해드림
# 최신판으로
# 왁싱좀
# 담엔
# 얼굴도
# 치워주셈
# 그건좀
# 만인의
# 막기위해선
# 정신적피해를
# 스티커가
# 필요함
# 이것도
# 쏴주셈
# 반신욕중이
# 담에
# 반신욕하게되면
# 하나씩
# 요염하게
# 샤워하는데
# 괜춘
# 이왕이면
# 시백으로
# 거울보고
# 전신샷
# 화장실
# 스티커부탁
# 만화판
# 지금보고있는데
# 약간다른게
# 영화랑
# 색다른
# 책도있던데
# 지르삼
# 그것까진
# 명장면은
# 이영화의
# 가슴만지는거다
# 미츠하정도면
# 최고의순간이지
# 전우들
# 고둔박사
# 가족이랑
# 말해줘
# 만나는지만
# 고든인데
# 고둔
# 누군가했네
# 안만남
# 모르는구나
# 끝까지
# 어케알음
# 띁임
# 설명해줌
# 궁금해서
# 만나는지가
# 봐야됨
# 봐야댐
# 짘짜로
# 이제부터임
# 시작임
# 이제부터
# 끝장면을
# 안봣다면
# 본게
# 쏘우1을
# 본겨
# 쏘우와
# 왕좌의게임
# 인생작들
# 임튜브의
# 왕좌의게임은
# 14편은
# 본듯
# 세번
# 세번보고
# 시즌14는
# 5는
# 시즌
# 6는
# 보삼
# 인생작임
# 대너리스가
# 어머니
# 용의
# 웨스트로스로
# 진격함
# 용엄마
# 나올떄가
# 벗고
# 좋았는데
# 게임오버
# 닫음
# 문
# 7편에서
# 거든이
# 발
# 지지는거도
# 부하되서
# 직소
# 7폄
# 가족이랑은
# 가족은
# 풰이크임
# 새드앤딩
# 고든은
# 직소는
# 규칙에
# 통과한
# 살려줌
# 규칙이라
# 직소의
# 수술해줌
# 양반임
# 걘걍
# 정신나감
# 죽여버림
# 통과해도
# 2시작
# 레알
# 반전잇음
# 쏘우는
# 들어잇음
# 열쇠
# 3탄까지는
# 잼게봄
# 나중도
# 고문환
# 빼는사람있음
# 뭐엿지
# 첫장면이
# 그거임
# 티비켜지고
# 눈안에
# 열쇠넣어놨어
# 데스마스크가
# 쓰고있는건데
# 눈알빼서
# 열쇠찾으면
# 열수있어
# 잘해봐
# 결국
# 죽음
# 23모두
# 사망
# 눈에대고
# 면도칼
# 사망한듯
# 데스
# 으아아아아아아
# 하다가
# 쏘우2
# 1도
# 2도
# 반전은
# 기억이안남
# 반전
# 중학생때본거라
# 2005년
# 작이네
# 들어야지
# 들어야됨
# 쏘우2는
# 탈출할텐데
# 경찰이
# 에릭메튜스씨
# 경찰
# 그자가
# 핵심임
# 못잘듯
# 볼
# 3까진
# 다시볼까
# 나지않
# 하나도
# 드문드문
# 여유있는
# 정주행
# 다보고
# 요약좀
# 고문씬뺴면
# 압축해볼듯
# 그게메인인데
# 요약해드림
# 보고나서
# 너무길어서
# 안읽음
# 낼까지휴일이니까
# 디비쳐잘것
# 호런이
# 닥헌
# 닥헌닥헌
# 닥현
# 롤이나해
# 멘탈이
# 안좋은모양이군
# 초딩한테
# 베리굿
# 조현
# 완감
# 3달린다
# 안알려주고
# 점수는
# 들어가래
# 텝스정규반
# 배치고사라
# 뒤짐
# 다이
# 딸인가
# 아빠의
# 걔도
# 심장
# 정지하면
# 죽잖어
# 아니구나
# 뒤지나
# 아만다도
# 어디서
# 끊기네
# 링크티비
# 3이
# 웹하드에는
# 쟤는
# 쟤
# 아만다
# 여자친구고
# 구글에
# 블로그
# 튜브타
# 감사
# 전편
# 금결원이
# 좋아하는
# 공인성적
# 뭐있음
# 영어
# 미패스임
# 토익만
# 미패스라면
# 점수
# 780인가
# 전산기준
# 광탕
# 미달이라
# 창훈이는
# 780
# 탈
# 밥이네
# 높을수록
# 없고
# 좋은건
# 1차면접이
# 시험이랑
# 핵심
# 뭐나옴
# 시험엔
# 전공
# 전반적으로
# 논술형임
# 되네
# 쓰라고함
# 종이주고
# ncs
# 기반
# 적성검사
# 안햇는데
# 준비
# 할만함
# 되는군
# 정도면
# 토익
# 몰랏음
# 보는지도
# 900정도면
# 적당하겠지
# 935
# 935까지
# 문과애들이
# 비슷한
# 900은
# 학원없이
# 밥이라
# 학원안가도될듯
# 1권
# 토마토
# 개털리겠지
# 이라고생각하고
# 석사하다가
# 각보고
# 학원다니든지
# 밥만
# 아니면되
# 토익은
# 내가지금
# 밥이라그럼
# 고득점
# 곳에서도
# 공대는
# 어느
# 요구하지
# 780은
# 밥이지만
# 안람
# 주라고도
# 900목표로
# 불안해서
# 이왕하는거
# 사라지니
# 지금해도
# 3학기끝나고
# 처음
# 출근이다
# 군
# 떨리는
# 두근두근
# 운영부라고했나
# 인생계획
# 재밌네
# 짜니까
# 안잡혀가겟군
# 직쏘한테
# 잡혀가면
# 아부리
# 털지
# 프로도타급
# 공조
# 잼따
# 나을수도
# 더킹보다
# 정주행중
# 안땡기네
# 이거만듬
# 이때까지
# 역시인생계획짜는게
# 말자
# 살지
# 참고
# 남자엿군
# 참는
# 참으면
# 힘듬
# 적당히
# 릴리즈해야함
# 릴리즈
# Release
# 너와할수없다
# 릴리즈를
# Ok
# 해줄수는없다
# 그경지까지는
# 가지못했어
# 나도야
# 그경지에
# 도달하지
# 못햇지
# 잡아주고
# 받아주고
# 캐치볼얘기한거임
# 공이
# 더럽지
# 캐치볼하면
# 전문가지
# 에일리언
# 프로도인걍
# 중복
# 종북
# 간나헌
# 아이린
# 닥쳐헌
# 얼
# 잘생기신듯
# 역시야구로통하나
# 야한호험
# 다시공부하러감
# 뿌웅
# 보고싶네
# 티스
# 뽀사주게
# 주먹왕
# 허헙
# 난데
# 핵주먹하면
# 핵주먹
# 화곡동
# 정자동
# 핵발사
# 그게나
# 억시
# 동네
# 왕
# 정자
# 스펌
# Sperm
# 꼬물꼬물
# 파파밧
# 게틀링건
# 게틀링
# 기관총
# 점사
# 쩜사
# 파팟
# 팟
# 삼점사
# 솔져임
# 하고싶은듯
# 정크랫은
# 하고싶네
# 오바워치는
# 이기몀
# 빡침
# 지면
# 하니깐
# 정크랫하고싶음
# 잘하면
# 버릴게
# 쏴도
# 죽임
# 수비에서
# 고수들만
# 공정크는
# 몰려잇을때
# 쏘니
# 누군가
# 맞아서
# 딜량은
# 짱
# 때리기만해도
# 방패
# 차니까
# 세탁용으로
# 스탯
# 갑자기
# 하고싶다
# 눈아파
# 아닌듯
# 할겜은
# 공조나봐
# 간지
# 현빈형
# 그럴까
# 다운받앗는데
# 거같음
# 음성환
# 술마심
# 빠져서
# 오티라는거
# 마시지
# 마신듯
# 인생
# 땅바닥이
# 시킴
# 장기자랑
# 내리락
# 느낌을
# 받을정도로
# 오르락
# 하는
# 떨리네
# 장기자랑은
# 너래하셈
# 먼산
# 긴장
# 되고
# 설렘
# 서강대는
# 안시킴
# 언저리마다
# 버스에서
# 이동하는
# 술마실땐
# 액면가가
# 있어서
# 어려워할듯
# 못대함
# 함부로
# 겨수님이라
# 새로오신
# 생각할지도
# 이자슥
# 이럴때
# 안올림
# 이엇는데
# 타이밍
# 빼야겟다
# 갠타너
# 술권하는
# 시댄
# 지나써
# 카리스마
# 개멋잇네
# 줘팰꺼같은
# 뉴클리어런치
# 뉴클리어
# 푸슈우우우
# 콰가가과곽
# 수정
# 착상
# 응애응애
# 주니어
# 같기도함
# 사진은
# 잘나온거
# 임구마랑은
# 저사진
# 딴
# 말기
# 보여주지
# 사람한텐
# 쪽팔림
# 임구마는
# 절대안됨
# 매생이도
# 것이
# 매생이는
# 아니도다
# 크지
# 파장은
# 1초동안
# 거리
# 이동한
# 물리환
# 물쏘환
# 찍환
# 천장
# 청소좀
# 종유석
# 방
# 상태
# 유석
# 백발백중
# 그곳에
# 지붕뚫고
# 하이킥
# 잘파네
# 장인
# 파네
# 눈쟁
# 쩜
# 투두두두두둑
# 장인임
# 다이아는
# 따라해도
# 반마
# 개잘하네
# 저렇게
# 하는거구나
# E활용
# SHIFT와
# 1시즌
# 저분에
# 정크만으로
# 10위
# 세계
# 머라해서
# 하도
# 이거저거
# 하다보니
# 즐겜하심
# 정크가
# 애매
# 공격에서
# 맞추기가
# 조합
# 공격에서도
# 잘하던데
# 이사람
# 머라함
# 하지말라고
# 정크탓하고
# 잡으면
# 정크만
# 프로급임
# 글쿠만
# 그리거
# 브리핑의
# 교과서
# 머리위에서
# 터뜨림
# 떨어지면서
# 점령지에
# 스킬을
# 버리는게
# 업음
# 밤샘코딩
# 달려야겠네
# 과제
# 내줌
# 성원이가
# 됬다
# 22까지
# 및
# 파이썬마스터
# 개조및
# 기존코드
# 실험
# 얼마안남음
# 쉬셈
# 개잘핵
# 싫어하는팀을
# 좋아하게
# 해보자
# 주제엿음
# 위대함
# 정크의
# 91년생
# 갈등은
# 길하다
# 성과
# 이성
# 주의해도
# 직장이나
# 쟈는즁
# 쳐들어가도
# 아지트
# 2주반
# 등록하러
# 신촌감
# 4시
# 강남가는데
# 전까지
# 프리함
# 열두시까지
# 식사
# 코르노
# 고우고우
# 포르노
# 폴노
# 라이언에게
# 자는중일듯
# Cum
# 이야아아압
# 얍
# 받아야하나
# 귀찮네
# 발라버려
# 받아야된다는데
# 실전반은
# 바를수
# 궨트
# 클베
# 카드게임
# 핫한
# 지너
# 지르노
# 지루노
# 점심만
# 맛잇는곳
# 야호
# 쓰리썸
# 내일인데
# 이라는
# 안붙엿구나
# 아름답다
# 미안하오
# 끝났는데
# Her
# 미안
# 안붙엿네
# 저기
# 등록해야하는데
# 결과
# 쉬움
# 난이도는
# 파고다가
# 이뻐
# 데스크
# 삼층
# 이쁜조교
# 아까봄
# 정예지
# 나없아도
# 행복하니
# 동일하군
# 맥심
# 이름과
# 커버걸
# 정예진
# 이분
# 쩔음
# 가슴많이
# 볼라구
# 오래산데
# 525만원이구먼
# 등록금이
# 입학금
# 생각보단
# 싸네
# 700일줄
# 고대는
# 낫
# 옛
# 콜
# 정도에
# 기대해
# 않고
# 가네
# 실전반이
# 위잖어
# 젤
# 욜
# 문제만
# 푸는곳이라
# 이론은
# 듣는다네
# 정규반
# 현쥬
# 세계로
# 승태형의
# 안내함
# 다님
# 김동영은
# 진리
# 한승태
# 이월
# 주셈
# 필기자료
# 인수인계
# 박영선
# 한승태가
# 듣지
# 7
# 들으라거
# 파트
# 박영선이어야만
# 주말반이라
# 대안이
# 마땅한
# 해볶짬도
# 그거구만
# 들엇던
# 인수인계할라고
# 먹을라고
# 햇지만
# 주말반임
# 닫혀서
# 문이
# 안다님
# 학원은
# 배치고사만
# 잼썼음
# 가래
# 텝스시험
# 할라고
# 자신감
# 하락할텐데
# 예쁘잖슴
# 이뻐서들
# 사랑입니다
# 해커스는
# 그녀들
# 수많은
# 내맘에
# 잠깐이지만
# 품었다
# 실전반에서
# 구해야겠다
# 해보고시픔
# 감히
# 예지를
# 모습이
# 원피스에
# 잡히던
# 않느다
# 잊혀지지
# 퐈이아
# 남자놈
# 인성
# 쓰레기
# 쓰뤡
# 주물중이었음
# 밥먹음
# 찌아
# 후이
# 귀가중
# 졸춥
# 집이엇지
# 상에서
# 컴퓨터
# 사진의
# 어케해여
# 용량을
# 줄이려면
# 188kb를
# 50kb
# 이하로
# 읶음
# 줄일수
# 깔아야됨
# 프로그램을
# 변환
# 알뷰
# 이런걸로
# 알러뷰
# 가능할듯
# 간단하게
# 인터넷으로도
# 알뷰가
# 알씨
# 이얍
# 여색에미친것들
# 끝내주지
# 이거로
# 사진없어졌네
# 정신차리도록
# 사진이
# 안올라가
# 접수하려는데
# 문제이지
# 짱나네
# 찌찌
# 크롬에서
# 소지자의
# 위엄
# 컬렉션
# 그사진임
# 같았음
# 그럴거
# 저거만한
# 사진이니깐
# 증명
# 임구마나
# 무리
# 사진계의
# 혁명인데
# 싸우자
# 덤뵤
# 꼬붕
# 고프군
# 배
# 먹지
# 마이클베이식
# 엔딩
# 흘
# 터져야
# 부산행이랑
# 섞엇
# 네
# 죽일순
# 공조보셈
# 완료
# 접수
# 기다리면
# 조금만
# 링크
# 스트리밍
# 티비에
# 존자르
# 현빈
# 헌빈
# 우체국에서
# 카톡옴
# 배달
# 오네
# 완료햇다고
# 카톡도
# 택배
# 뭐삼
# 보냇는데
# 택배를
# 보냇다고
# 톡옴
# 친절하셔라
# 돈받음
# 4권중
# 절반
# 팜
# 보냄
# 전라북도
# 전주에
# 나머진
# 안팔림
# 올려봐야지
# 사이트에
# 약대가자
# 여친구힌다고
# 모집글도
# 홍콩가자
# 홍콩
# 올려보셈
# 점심드심
# 드심
# 누구야
# 저짤개웃기네
# 막장
# 새드엔딩
# 깊숙히
# 바세린
# 가져감
# 무지에
# 특별히
# 손가락
# 콘돔도
# 가져가지
# 사둔건데
# 쓰려고
# 이벤트때
# 미리써보지뭐
# 손은
# 두개야
# 프로도이만
# 아플거야
# 처음엔
# 괜찮아질거야
# 해보고
# 연습중
# 여러가지
# 테크닉
# 무엇에
# 본인걸로
# 얘기
# 재밌는거
# 못봄
# 페북이라
# 해야되네
# 이스북
# 페이스북
# 페이지인데
# 레드홀릭스
# 내용많음
# 재밌는
# 멕시코인이
# 슈발
# 해킹시도
# 접속
# 원본을
# 변태는
# 많은데
# 여기도
# 유해
# 말어
# 잡혀가지만
# 내핸드폰으로는
# 잘들어가지던데
# 안되고
# 컴터로는
# 폰은
# 왜이래
# 스벌
# 릴렉스
# 우리에겐
# 핫스팟쉴드
# 핫스팟
# 지스팟
# 백신깔았거나
# 와이파이로
# 접속중
# 안되룻도
# 해당됨
# 키니
# 잘되네
# 집념굿
# 왜켜
# 핫스팟을
# 끊었다는
# 와이파이를
# 얘기인것같군
# 켜고
# 피씨카톡임
# ip
# 얘기하는건가
# 우회하는거
# 우회
# 그거안해도될텐데
# 학교와이파이
# 환경이면
# 환경에서
# 느려짐
# 잘못쓰다
# 보안으로
# 잡혀갈지도
# 너무오래만
# 안하면됨
# 트래픽같은거
# 같은곳에서
# 교내정보통신원
# 꺼야겟군
# 그정도까진아님
# 적고
# 트래픽이
# 꺼
# 괜찮
# 폰이면
# 우회접속해서
# 피씨로
# 같은거
# 다운로드
# 받으면
# 되는거지
# 노노노
# 그런걸로
# 할수도있으니
# 해킹
# 폰임
# 피씨는
# 위험하지만
# 폰정도면
# 이럴줄알고
# 모아뒀겠지
# 모아두다니
# 여인들
# 왼손
# 휴지
# 선호
# 일본거
# 일본게
# 짱인듯
# 동양이라
# 기르모르찌르
# 저번주인가에
# 갔어
# 런치로
# 로운샤브를
# 사줘
# 머글라고했는데
# 샤브
# 더먹고싶다고
# 이소영씨가
# 더블소고기로
# 만오처넌짜리
# 주문을
# 했디
# 그러고
# 먹기
# 시작하는데
# 고기가
# 비해
# 홍대에
# 퀄리티가
# 강남에
# 런치
# 만원인데
# 샤브샤브
# 쩌는곳
# 유난인거
# 먹었지
# 아닥하고
# 먹고나서
# 몇분남았지
# 이러고
# 계산서를
# 주문서에
# 더블한우소고기
# 샤브라고
# 나온거
# 그때야
# 아뿔사
# 한우
# GG
# 불렀지
# 알바생을
# 잘못된던가해서
# 주문이
# 훅시나
# 기달리래
# 자초지종말하더니
# 안오는거
# 오분이
# 그러더니
# 아저찌가
# 오더니
# 고기는
# 드셨냐고
# 묻더라고
# 손님
# 기다리래
# 잘먹었다고
# 잠깐만
# 하니까
# 하러감
# 기다리니까
# 알바생이
# 오분
# 주문받은
# 죄송하다고
# 나간게
# 맞다고
# 한우로
# 저희쪽
# 착오라
# 가시라고
# 계산하고
# 덕분에
# 돈범
# 야채에
# 있더라
# 쭈꾸미도
# 손님될뻔
# 진상
# 돈내나
# 걔가
# 매꿀걸
# 맛있더라
# 이득봄
# 팔처넌
# 만원에
# 우리도
# 먹을수
# 배터지고
# 가까
# 로운이나
# 개강하지
# 학원
# 로운
# 멋있네
# 써야겠다
# 아들이름으로
# 오래못먹음
# 1시간가능
# 뚜까맞지않으려면
# 목요일날
# 앵겨야함
# 필사적으로
# 충분함
# 벌걸킹
# 기꾸스시
# 어떰
# 맛있는
# 초밥집임
# 무지가보
# 가격대봄
# 자비좀
# 기꾸
# 7000
# 런치세트
# 라니깐
# 기꾸는
# 추천하네
# 9000
# 기꾸세트는
# 어디임
# 13000
# 모듬세트는
# 대흥임
# 이꾸
# 이꾸스시
# 색마야
# 먹자
# 기꾸스시가는길에
# 듣자
# 설명좀
# 미분당도
# 부탄츄도
# 있고
# 있으니
# 자리꽉차면
# 2개
# 더있음
# 미분당
# 유가네도있음
# 길에
# 부탄츄
# 미분당은
# 뭐고
# 부탄츄는
# 들어오라는
# 뜻이네
# 쌀국수집
# 체인점임
# 일본라멘집
# 체인점은
# 유라이언
# 중간에거를
# 먹고픈뎅
# 유가네에서
# 줘야됨
# 지분
# 중간거가뭐야
# 그거나
# 미스터츄
# 웨이팅없는곳으로
# 만납시다
# 열두시에
# 받습니다
# 사드리고
# 잇으신분
# 사주셈
# 갈까
# 결정
# 도지네
# 장애
# 필욥
# 현금이
# 일본
# 태국
# 한국
# 골라바
# 셋중
# 유가네군
# 한국이면
# 거유가네
# 없냐
# 갈거
# 이왕
# 큰데로
# 거유
# 시하군
# 시하지
# 유가네의
# 인위적인맛
# 유르가르네
# 프랑스어인줄
# 고르고르고로
# 유르가르네르
# 밥만먹고
# 시마이해야하지만
# 맞은편에
# 코노가있지
# 구웃
# 낼테니
# 플리즈
# 혀른그음
# 혀
# 츠릅
# 낼름
# 츄릅
# 현금게이냐
# 현금귀신
# 놀아보자
# 신나게
# 루시우
# 빗발친다
# 정의가
# 하늘에서
# 목포를
# 포착했다
# 짜릴할거야
# 쫌
# 석양이
# 진다
# 맥크리
# 류오
# 와가
# 쿠라에
# 테키오
# 우오오오옹
# 똥쮸
# 뿌쒸짜오
# 쉬이이이
# 나왔는데
# 새앨범
# 허각
# 기대보단
# 기대는
# 님네
# 허각은
# 노래실력
# 별론듯
# 노래실력이야
# 열배정도
# 갠춘
# 많다
# 부를
# 우리에게
# 옵치입문하냐
# 서든실력반만
# 레스트인데스야
# 힘내염
# 피곸하군
# 잣는데도
# 셈
# 허퍼
# 참참
# 쵭촵
# 촵촵
# 굴먹고싶다
# 굴
# 귤
# Oyster
# 쮸꾸르미
# 보끔
# 쭈꾸미
# 밥에
# 비벼서
# 슥삭
# 쭈꾸미구이
# 회
# 볶음
# 직화
# 쮸뀨미
# 쭈꾸미삼겹살
# 고생했다
# 차대가
# 차차차
# 다함께
# 호추
# 저녁
# 끓임
# 비빔면
# 맛남
# 전문인데
# 귀찮다
# 설거지
# 대위기
# 저녁먹네
# 1일1식하는데
# 대충먹은듯
# 점심을
# 다이어트
# 귀차니즘
# 어마어마함
# 한끼가
# 오유
# 간장양념세트에
# 호식이두마리치킨
# 먹는
# 밥한공기도
# 양
# 설거지하러감
# 백
# 기모띠
# 앙
# 오덕환
# 메르띠
# 연습좀함
# 쏘면
# 젠야타
# 차는거
# 같은편
# 그렇다는데
# 상대편인거
# 두개인데
# 젠야타는
# 부조화
# 조화랑
# 울팀
# 조화는
# 힐링
# 부조화는
# 적팀한테
# 추가뎀지
# 40프로인가
# 구슬을
# 더들어가
# 뎀지가
# 받은
# 부조화의
# 계산됨
# 딜량으로
# 궁게이지도
# 영향을
# 즉
# 찬다고
# 한듯
# 상대편
# 안좋가고
# 안좋다고
# 싫어햇음
# 팀이
# 구슬
# 떄문일지도
# 조화의
# 눈쟁이가
# 파라잡고
# 위도우잡고
# 다함
# 솔져잡고
# 정크로
# 파라잡는건
# 신임
# 날라다니는걸
# 잡냐
# 예측샷능력이
# 양반이
# 에임이
# 비하면
# 에스카나
# 이런애들에
# 조밥
# 타이무
# 파인
# 장인이
# 버니
# 이펙트나
# 장인은
# 쩔스
# 번
# 방송국
# 인벤
# 이펙트갑
# 하나만보면
# 하나무라
# 리장타워
# 만날래
# 아이헨발드
# 34프로밖에
# 명중률이
# 핵보다
# 후달린다던데
# 이만한게
# 허헌이네
# 빈
# 과제해야지
# 과자
# 일일
# 쿼스트
# 뽑아줘야
# 그래야건강하지
# 운동도하고
# 녀석둘
# 슈다스런
# 팁좀
# 허리운동
# 데드
# 어땟음
# 첫
# 20분에
# 퇴근하라
# 못햇다
# 3번째
# 가라고
# 잘햇어
# 봐야하는데
# 부서는
# 갓으면
# 찍혓다
# 1빠얏움
# 갓으먄
# 부서전체에서
# 명절다음이라
# 바쁜데
# 매너남
# 갓헌이었으면
# 집갈듯
# 11시출근
# 2시퇴근임
# 갓럼이면
# 싸이코는
# 잇으면
# 함부러
# 니트
# 일부러
# 입음
# 꽉
# 붙는
# 뻠삥
# 다리
# 만지고
# 만짐
# 팀장등
# 등
# 생겼다
# 운동하게
# 데드로
# 되겟네
# 바르면
# 기선
# 제압
# 내리셈
# 한방임
# 푹푹
# 에임
# 좁밥이니까
# 하고옴
# 도라도에서만날까
# 안그럼
# 에임즈
# 에이즈
# 11
# 십대떡으로발라줘
# 팬더처럼
# 누구에게나
# 져드림
# 1대
# 1할일
# 임즈한테도져줘
# 안해
# 이랑
# 접때
# 졌어
# 임즈한테졌냐
# 옵치접어라
# 골드찍으면
# 접는다
# 때리지
# 않아
# 친구는
# 좁밥아
# 프
# 맵부터외워라
# 임즈는
# 봐주는거
# 티낫다
# 안다
# 길해메는거보고
# 두명이서
# 암걸릴듯
# 고맙다
# 떄리라고
# 비벼줬자너
# 봐준거지
# 에임필요없는캐릭먼저연습해
# 프로도이랑은
# 임스턴이라던지
# 못떄림
# 한번을
# 니잘못이지
# 통수맞음
# 잘도망뎅기는거
# 나가신다
# 폭탄
# 한판더
# 붙어야지
# 붙자
# 1차전까지
# 50렙찍어놔
# 튜브은
# 내생각하면서
# 연습해라
# 멘티
# 14000일꺼다
# 최고뎀지가
# 잡으면됨
# 개못하네
# 이분은
# 만사천이
# 빠대에서
# 정크장인
# 장난임
# 눈쟁인
# 랭커고
# 4만임
# 3만은찍지
# 경쟁전하면
# 고추커
# 위너
# 필요없음
# 딜을
# 잘넣겟네
# 랭커가
# 무슨
# 쓸모냐
# 공부할테니
# 딜도
# 잘넣고
# 공부도
# 잘하고
# 위도우연습좀
# 위도우좁밥아
# 갔다
# 그는
# 다시간다
# 옵치야머
# 3개정도만
# 할줄알면됨
# 키우삼
# 다뤄야지
# 모든캐를
# 생각중임
# 근디
# 루슈는
# 오래하면
# 방법만
# 익혀두고
# 마지막까지
# 픽하지마
# 힐러
# 누구하지
# 루슈로
# 어쩔수없으면
# 때매
# 짱나서
# 어디가도
# 환영받음
# 라인해봐야지
# 귀여움
# 라인은
# S라인
# 떙큐임
# 해주면
# 라인메신져
# 봇라인
# 탑라인
# 라인을
# 잡으셈
# 힙라인
# 주물
# 벽
# 휘두르기
# 궁극기가
# 돌진
# 맞지
# 돌진이
# 스킬
# 망치
# 대지분쇄
# 못해도
# 캐가
# 환영받는
# 루슈
# 힐켜놓고
# 환영
# 궁극기만
# 잘해주면되고
# 두개
# 해야겟네
# 떙큐
# 있어주면
# 스스로
# 힐
# 라인아나
# 조합이
# 궁극기
# 뽕맞은
# 빠따가
# 고추
# 그거할줄
# 해드린거
# 옽
# 정크혀
# 무시해
# 애들말은
# 솔저
# 잡대
# 눈쟁이라
# 그분이니
# 눈쟁이랑
# 차세진이
# 잘하는듯
# 세진이는
# 쓰렉이라
# 늠
# 서든하는거보면
# 이해도가
# 겜
# 센스는
# 겜이
# 안되
# 적응이
# 누굴
# 몰겟음
# 쏴야할지
# 정신없음
# 헷갈릴떈
# 힐러먼저
# 누군질
# 힐러가
# 영상보면
# 판단이
# 떄리는지도
# 배우니까
# 어떠케
# 복잡한
# 상황에서
# 다릉꼐
# 생김새가
# 보다보면
# 인식가능혀
# 프로도얼굴
# 이러는거
# 처럼
# 몽골족이
# 아니어도
# 4키로
# 밖에서도
# 보임
# 보면늠
# 데굴데굴
# 펑
# 못하겠음
# 평타떄매
# 님은
# 디바
# 고인됨
# 경쟁전에선
# 마니함
# 아나나
# 그것들에
# 대해서도
# 봐야겟굼
# 잼써
# 많아서
# 아나가
# 상황판단도
# 에임도
# 좋은애가
# 좋은캐임
# 돰
# 익히면
# 보고옴
# 로드호그도
# 다녀오삼
# 로드호그는
# 에버모어
# 해봣는데
# 어려워
# 궁극기는
# 연필깍더라
# 투타타타타타타
# 감동
# 눈쟁이vs차세진
# 본거같은데
# 차세진도
# 원챔프임
# 벤치프레스
# 안들린다
# 너므
# 쉬엇어
# 못버티네
# 밀수
# 잇다눈데
# 팔이
# 목표가
# 헐크임
# 존시나
# 한참멀었네
# 260임
# 스쿼트
# 300
# 갈길이
# 멀다
# 몇임
# 동양인
# 핸디캡
# 150
# 3번이
# 골반부상이후
# 한계
# 밑힌
# 일점오배네
# 그거해서뭐해
# 데드는
# 들린
# 바르는거지
# 바르는중
# 존시나처럼
# 꽂아야함
# 엎어매서
# 방금과외끝남
# 80kg
# 80하던데
# 80은하지않을까
# 67키로
# 들고뛸수있음
# 들고뜀
# 만나서
# 만나기
# 힘들듯
# 들고는
# 못뛸듯
# 운동해
# 100이엇나
# 그것만해도
# 얘기구먼
# 30키로는
# 될걸
# 미군들이
# 실전에서
# 써야한다고
# 강철
# 곧휴라
# 존나시킴
# carry
# fireman
# 다시해
# 허리디스크라
# 일주일에새번씩
# 들수
# 무게
# 잇는
# 측정좀
# 나보다
# 임튜브이
# 힘쌜듯
# 역사지
# 타고난
# 마임
# ♡♡
# 보고와
# 학교체육관에서
# 해볼게
# 어피치학교체육관
# 를
# 몇키로까지있음
# 야외
# 220까지
# 가능할걸
# 10개
# 20키로
# 60도
# 떼길
# 못하는
# 전우들은
# 6080까지
# 도전해봄
# 금요일날해보겠음
# 내일까지
# 시킨거해야함
# 손봐야할듯
# 출동각
# 집어던져주셈
# 뷸러
# 재밋군
# 목표를
# 포착햇다
# 영상보며
# 배움을
# 얻는중
# 2층에
# 날라간
# 두방에
# 쉬프트써서
# 후에
# 감각이
# 그거로
# 탁월함
# 님도
# 만큼하면
# 파면
# 겜센스는
# 금방하지
# 평균수준은
# 롤할듯해서
# 피방가면
# 그럴거면
# 잊으셈
# 에압
# 고만고만스
# 운동그만하고
# 조루랑같이여자정복좀
# 준비중
# 트럭으로
# 가면댐
# 몇시까지
# 일찍가면
# 잇어도
# 열드시
# 2분
# 십초부터
# 가성비좋은
# 뭔겜
# 욕하기
# 중국인
# 하이즈
# 리액션
# 중국인들
# 싫어함
# 타이완
# 남바완
# 남바투
# 재팬
# 남바포
# 차이나
# 열폭하는거지
# 싫은가봐
# 타이완이
# 중화사상
# 넘버
# 원
# 코리아
# 넘버원이랑
# 이즈
# 티베트
# 프리
# 강력하데
# 두개가
# 그르쿤
# 공부안해도
# 쩐더마
# 먹힐
# 배움
# 욕은
# 쩐더
# 웃었다
# 저거덕분에
# 즐겁데
# 배우더니
# 중국인덕에
# 웃네
# 배운욕은
# 일찍오지마셈
# 그녀와
# 그리고진짜미안한데
# 내일점심
# 윤아랑먹어야할것같음
# 알지
# 사랑한다전우들❤
# 괜차나
# 파바밧
# 위한
# 이프로도을
# 추천선물에
# 츄팝츄스
# 화이팅
# 갖고와
# 사탕
# 라브
# 빨리가라구
# 집인디
# 하는거였음
# 몇시
# 몇시에서
# 수업임
# 열두시
# 열시에서
# 불쾌
# 응아못햐서
# 방금햇는데
# 부글부글잼
# 안에서
# 파티난듯
# 두번이나
# 시원
# 두번이라니
# 안됬는데
# 열시도
# 환쏘X
# 환쏘똥
# 부럽게
# 안할듯
# 보겠구먼
# 천국을
# 버티면
# 마법쓸수
# 다녀와서
# 마나를
# 모을수
# 마나
# 복통은
# 들끓는거임
# 마나가
# 써Q
# Q
# 강해졌다
# 돌격해
# 말이군
# 야할수도
# 도서관이야
# 카페
# 독서실이다
# 수업중아님
# 집중
# 까오
# 쉬에셩
# 슬
# 워
# 이치엔
# 데스네
# 언어구사군
# 저질스런
# 세법연습좀
# 정크랫연습이나해
# 헨타이프로도
# 나만큼만
# 더도덜도말고
# 키워놔라
# 실전반
# 빵뎅이네
# 쳐웃네
# 닥치라
# 전해줘
# 지각함
# 굽신굽신으로
# 들어옴
# 이번달
# 뒤를
# 주물햇다면
# 영
# 앞을
# 별로임
# 환불할까
# 물이
# 흐려
# 가야하나
# 해커스나
# 빠른퇴각
# 고민
# 퇴각하쟈
# 듣기는
# 안들을거긴한데
# 듣기
# 못가르침
# 쌤
# 장철권급
# 이해
# 진돗개는
# 수업을
# 잇자너
# 소영씨가
# 학원뎅겨서
# 공부안할듯
# 공부쟁이라
# 내비둬야함
# 스테이
# 마자
# 두개를
# 앞
# 주물주뭏
# 사람을
# 아냐
# 몸도
# 가슴까지임
# 기준
# 밑엔
# 안봄
# 하체
# 살짝
# 튼실한게
# 마른거보다
# 쪄야됨
# 디륵디륵
# 쪼임은
# 알수가
# 여자볼때
# 외모로
# 판단할수
# 장교
# 형아
# 키작은
# 몸집작은여자래
# 스타일은
# 자기
# 만질게
# 푸짐한여자
# 뱃살
# 떨어져도
# 몸이
# 후덕하면
# 거려도
# 덜렁덜렁
# 팔살
# 매력잇음
# 미친소리하지말고제발연습좀
# 미쳐
# 사람취향인데
# 쳐
# 후덕환
# 미안❤
# 밥먹고싶음
# 윤아띠랑
# 바꿧네
# 그러또우
# 겨울에
# 어울리는
# 윈터팬더
# 다하고
# 상담도
# 진단고사도
# 푼거고
# 탐
# 어젯밤오늘아침
# 연타는너무힘들다
# 재밌게놀다가시와요
# 이연발담
# 따당
# 이디야
# 신도림
# 다음차
# 신도림까지라서
# 열차는
# 끝이
# 당산
# 먼
# 시마이했다
# 하앍정
# 이쁘냐
# 한강
# 역임
# 하앐정
# 러브
# 윗
# 휄인
# 가는
# 신촌역을
# 향해
# 이번역은
# 내리실
# 문은
# 오른쪽이래
# 업지만
# 유가유가
# 유가르
# 나오삼
# 사번
# 출구로
# 맛난데
# 아는곳
# 잇는가
# 고르고르
# 대기중
# 위에서
# 출구
# 잘놀고있음
# 개피곤하다
# 범계코노좀
# 우가대기중
# 그대가
# 분다
# 중임
# 뭐먹음
# 국물
# 쩔어
# 개맛있음
# 가슴을
# 사랑은
# 시킨다
# 거녹음해서좀
# 올려봐
# 좁밥들아
# 사가시
# 파트2도
# 인연중
# 빠이함
# 대선
# 반기문띠
# 불출마하네
# 나니
# 이제와서
# 사이즈가
# 안나오나봄
# 선택하셨네
# 현명한
# 문재인만
# 신났네
# 이재명
# 되면좋겠지만
# 그럴리가없겠지
# 민다
# 허경영
# 헌팅하러감
# 독침들고감
# 엽총
# 강력한
# 그만의
# 무기
# 몽둥이
# 남자라면
# 강남은
# 늘어나는
# 자유자제로
# 그의것
# 몽둥이지
# 빠짐
# 스테미나
# 쓰면
# 쫙쫙
# 쓰리샷
# 커피마심
# 밤새야되는데
# 됬네
# 만져주면
# 살아남
# 윤아띠
# 헬프
# 패션
# 입고나옴
# 얼굴좀
# 용감
# 용덤
# 어디서삼
# 코트
# topten
# 3개있는데
# 코드
# Farenheit
# Sieg
# Topten
# 기억이안난다
# 아무거나
# 어디더라
# hum
# tate
# 프사바꿈
# 경고임
# 대한
# 세컨에
# 강력함을
# 자랑
# 정부인의
# 담쏘물
# 세컨은
# 금요일에
# 구구
# 금욜에도
# 바뀌는거
# 그녀들의
# 암투
# 치열한
# 고민을
# 되는데
# 행복한
# 밑에는
# 화가나기
# ghkfmf
# 풀려면
# 화를
# 그것밖에없겠지
# 밤샌다메
# 이만
# 자제점
# 이미연구실에서
# 코딩중
# 스타벅스
# 투샷달림
# 두번달리고
# 어제밤
# 오늘아침
# 풀
# 버티다가
# 커피로
# 투샷
# 보고와서
# 피아노공연
# 투샷으로
# 새벽버텨야함
# 지옥의행군이다
# 라이언아
# 되어줘
# 튜브쨩
# 허헛
# 도와주셈
# 도와주는건가
# 안시키는게
# 이럴떈
# 우린아직청춘임
# 무너져선
# 이정도로
# 가격이
# 창렬임
# 다른대가
# 몰라서
# 얼만질
# 등록금
# 매꾸나
# 부족한건
# 1실
# 70만원
# 식대가
# 비싼거냐
# 같은딩
# 저정도인가
# 한학기라
# 개비싸네
# 여자꼬시는거
# 머리터져서온건데
# 뭐래
# 세법하다
# 호르몬장난에불과함
# 깨달음이부족함
# 마인드가
# 젠야타네
# 기계네
# 시각적
# 환상에사로잡히지마라
# 야동보면
# 여자의몸은
# 지방과단백질의
# 혼합물에불과하다
# 묵직해지지
# 밑이
# 그거는
# 자르면됨
# 성욕에서벗어나야
# 자유를
# 진정
# 찾을수있다
# 잘라보고
# 후기점
# 100
# 한달당
# 한학기
# dk
# 개싼대
# 생각해보니
# 포함이면
# 한학기면
# 갠찮지
# 가시져
# 남자답게
# 특실
# 해룡학사
# 200
# 상남자환
# 200도
# 개싼건데
# 성대가
# 삼성이
# 빵빵해구나
# 지원이
# 우리학교는
# 120
# 1실이
# 1실은
# 각하의
# 이대는
# 차대임
# 저기차대임
# 자르고옴
# 70이라매
# 셤끝나고자르게
# 밥빼고
# 얼른
# 70아냐
# 학기에
# 78
# 그렇겟지
# 존나싸네
# 78이면
# 적당한
# 더비사찜
# 신관은
# 19만원쯤이잖아
# 한달에
# 차대는
# 그정도면
# 다닐수있겠따
# 벌어서
# 존나씨
# 차대도
# 160인분
# 60임
# 괜차는거지
# 식비
# 포함이니
# 아무래도
# 땅값이
# 큰몫을
# 하는듯
# 마포랑
# 신촌은
# 비싸서
# 가격
# 창렬인줄
# 싸니까
# 포천은
# 수원도
# 삼성하드캐리가
# 수원보단
# 크겠지만
# 업승
# 50쯤하는걸로
# 알고있음
# 연대도
# 신현희와김루트
# 오빠야
# 이노래
# 꼭들어보셈
# 알고있었지
# 재작년부터
# 걔네랑
# 뜨나봄
# 솜사탕
# 얘네가
# 찍어뒀는데
# 참꺠와
# 솜사탕도
# 참깨와
# 여친이
# 좋아해서
# 몇개암
# 라이언집
# 김나영
# 꺼내본다
# 연습해와
# 내꺼본다
# 노래개구
# 꽤
# 있었네
# 끌려간다
# 동문회
# 술먹으러
# 너희들은
# 무사하길
# 바래
# 변태닥쳐
# 멘탈삭제됨
# 조루밤새서
# 교수님이
# 안부름
# 미팅하자고해놓고
# 바쁘대
# 데잇흐
# 윤이띠와
# 윤아
# 학교안옴
# 코딩하다보니
# 재밌긴한데
# 고생했구려
# 굴먹고
# 보충
# 골반이
# 나앗는데
# 설친듯
# 완전히
# 그니까적당히깝
# 제길
# 호험타
# 노답이네
# 결혼
# 발표
# 가는길
# 세컨에서
# 퍼스트로
# 왜불러
# 불러봐야지
# 한번쯤
# 습관성
# 오천원
# 주삼
# 감사히
# 받겠음
# 사랑으로
# 대드리면
# 될듯
# 두어번
# 신촌와
# 주꼐
# 받을걸
# 그러쿤
# 밥사줘
# 있으니까
# 챙겨드림
# 지갑에
# 지폐
# 궁해서
# 각종
# 빠져나갈
# 600은
# 나간듯
# 피방끊으삼
# 안가자녀
# 하스스톤
# 프로가되자
# 강남가서
# 밥드심
# 옷사고
# 긱사에서하는걸로
# 요릉담
# 더자
# 커몬요
# 임마헌
# sg호너비
# 해바라기
# 노래를
# 모르겟어
# 교육비가
# 소득공제
# 큐트한녀석
# 가상계좌로
# 세법상
# 이런경우
# 잘못된거임
# 설명해라
# 세법
# 법
# 세르법
# 폰을
# 시급한것은
# 아니니
# 모닝
# 도와주고
# 세법헌
# 강의해줫다
# 정크랫연습좀
# 보기만
# 3배는
# 보는게
# 실력향상에
# 효율적이다
# 2개씩골라서
# 딜탱힐
# 보는김에
# 정주행해라
# 야동마니본다고
# 잘하는건
# 해야늘지
# 명언이다
# 빡친다
# 남자냐
# 삼십명이되는데
# 스터디조만
# 환불각
# 보람이없다
# 빡공계시인듯
# 왜이리잠잠해
# 이뻐졌네
# 사진점
# 간직할거임
# 푸슉
# 그렇지않아요
# 지켜줌스
# 그렇지도않지
# 홧팅
# 카사전직
# 카사딘
# 공허
# 충
# 결과는
# 기대하란뜻
# 노력중이고
# 연수감
# CTO
# LG
# 되심
# 진지하게
# 고민중이었는데
# 정부인상승시킬까
# 가셔서
# 연수를
# 고민하고
# 세컨을
# 장난인건가
# 반반인가
# 그만큼
# 뜻아님
# 매력적이란
# 그런가보구먼
# 윤아띠가
# 무슨선택을
# 지지한다
# 하던
# 복합적인것이있지
# 연애
# 도의적
# 응징한다
# 잘못은
# 뀨우
# 가면되나
# 사다놔
# 위다
# 아래
# 침대
# 2층침대임
# 더블이
# 싱글
# 더블임
# 자취방은
# 두명
# 자기에
# 탄력잇더군
# 매트릭스가
# 더러운것만
# 최고의
# 침대임
# 밤
# 과외
# 개인속성과외
# 주고싶어도
# 광명임
# 원한다면
# 줄수야있꼬
# 소개시켜줄수있지만
# 광명
# 개오바
# 모를까
# 수원이면
# 포천이면
# 과외해도
# 서울에서
# 안할것같고
# 자체를
# 포천은…
# 북부쪽
# 서울
# 강북
# 셔틀버스가
# 신촌도
# 영등포구청오면
# 강북해야지
# 강북뛰어야지
# 셔틀애
# 셔틀말고는
# 교통수단
# 가까움
# 어디가
# 개멀텐데
# 태릉
# 존나끝이넼
# 7호선
# 맨끝
# 교통수단을
# 잘은
# 지하철없지않음
# 버스
# 온니
# 산골
# 강북쪽
# 과외들어오면
# 38선
# 위인가
# 양구
# 예전엔
# 들어오면
# 그부근임
# 여자친구
# 주거나
# 버렸는데
# 님드림
# 혹시나
# 나줘
# 지역보고
# 과외가
# 마지막임
# 대학원입학하기전에
# 정리할거야
# 7년했으면
# 많이했다
# 과외머신임
# 군대에서도하고
# 휴학때도하고
# 두가지의
# 머신
# 대학원가서는
# 안한
# 삼천원
# 안타깝게도
# 불가능하고
# 연구실컴터는
# 북미밖에안돼
# iMac
# 이라서
# 다음주가
# 지나면
# 게이밍노트북이
# 연구실로
# 오기때문에
# 노트북으로
# 그걸로했는데
# 성능개좋음
# 160
# 3년전
# 가격이지만
# 존나좋음
# 자취방에
# 티비연결해서
# 쓰고잇엇음
# 구매해야하나
# 노트북
# 사야지
# 살앗는데
# 없이도
# 게임할거아니면
# 그램
# 추천한다
# 가벼운게
# 컴퓨터는
# 있어야되잖아
# 가능할텐데
# 그램으로
# 못할걸
# 오래는
# 그램은
# 새로나온
# 좋아서
# 될건데
# 울트라북
# 가벼우려면
# 얇고
# 발열때매
# 게임은
# 무거운거
# 사야겟군
# 내꺼가
# 기가바이트
# 껀데
# 가볍네
# 가볍고
# 고성능이라
# 배터리가
# 조루임
# 들고다니면서
# 쓰기는
# 은근불편
# 닮지
# 주인좀
# 정자머신
# 저사양이라
# 내장그래픽만으로
# 충분하긴
# 할텐데
# 업데이트
# 인터페이스
# 하고나서는
# 느려지나봄
# 조금
# 긱사에서
# 쓸거면
# 무겁지만
# 성능괜찮은걸로
# 사도좋지만
# 노트북은
# 가격대는
# 50
# 천차만별
# 만약에
# 사고싶으면
# 개인상담해드림
# 손진호
# 계심
# 사도됨
# 중고나라에서
# 소모품이라
# 전자제품은
# 아예
# 안뜯은거
# 사셈
# 새걸로
# 감가상각
# 매우싼거지
# 전자제품이
# 중고가가
# 애플꺼빼고
# 애플은
# 시장형성을
# 20만
# 먹으려고
# 하기때문에
# 안만들고
# 오래쓸수있게
# 잘만들고
# 안떨어짐
# 아이폰7
# 50만원임
# 아이폰6
# 중고가
# 낫겟군
# 새걸사는게
# 갤럭시는
# 갤럭시7
# 나오고
# 30이하
# 갤럭시6
# 새로운게
# 팔고
# 가치가
# 별로없음
# 오래되면
# 쭉쭉떨어짐
# 내꺼
# 너꺼는
# 노답임
# 공짜폰일듯
# 팔때
# 5만원받음
# 최상급으로
# 2만원받으면
# 감사할듯
# 결과나옴
# 약대니까
# 좋지않음
# 차병원도
# 약국
# 잘되서
# 빌딩하나
# 해먹으면
# 좋으륻
# 모여
# 무지꼬셔서
# 사업시켜서
# 빌딩
# 사게
# 입점시켜달라고
# 쫄라야지
# 안하니까
# 프로도은
# 기질이있음
# 사업가의
# 프로도이는
# 회계해야지
# 씨파
# 넘이군
# 시켜드림
# 회계사
# 1층에
# 병원하나
# 위에는
# 어피치의
# 헬스장
# 피시방
# 맨위에
# 팬트하우스
# 네오병원
# 팬트하우스엣
# 펜트하우스에
# 역시임즈
# 팬티하우스
# 어디냐고
# 호한
# 가야겟다
# 금요일
# 땡기고
# 이라
# 기념
# 워우워어
# 가난한사랑
# 난이도
# 어렵지
# 은인
# 다른곡들과
# 비교좀
# 비교부탁
# 상대적인
# 몇곡만
# 예시좀
# 너릉보내고
# 웅급실
# 가시까지
# 너를보내고가
# 쉬운편
# 응급실
# 가시
# 중상
# 상급
# 건드는건
# 나비야는
# 맛이
# 하동균아니면
# 안건드림
# 낮아보임
# 루그가
# 버즈나
# 가난한사랑이
# 보고싶다보다
# 어렵던데
# 가난한사랑은
# 높아서
# 마지막
# 하이가
# 소주한잔은
# 까다럽스
# 꾸준히
# 보고싶다가
# 지속되는건
# 막판만
# 무난하잔스
# 소주한잔도
# 앞엔
# 목적이니
# 완창이
# 음역대
# 넓음
# 접떄보니까
# 활용법
# 후자가
# 보고싶다보단
# 슬픔활용법이나
# 어려운듯
# 그마아아아아아아안
# 가난스
# 노실분찾아요
# 과외끝나고
# 이제집가는데
# 할수있으면
# 당신을
# 더크로스는
# 아님스
# 위하여
# 이노래좋음
# 누구누구올수있음
# 4시에가긴해야함
# 가족끼리
# 저녁먹어야해서
# 9시부터
# 아침
# 풀타임
# 달릴
# 임튜브구해요
# 5인분이요
# 임튜브
# 추천해준거
# 기억난다
# 가입순간부터
# 멜론
# 노래보는중
# 많이들은
# 월별
# 추억살리기
# 추억도
# 고등학교때
# 3명이지
# 그녀는
# 2명인가
# 존나들었는데
# 신촌서
# 접떄
# 먼키랑
# 보스
# 많이했지
# 산
# 옷좀
# 입고와봐
# 검사
# 범계와
# 멀어
# 놀아줌
# 범계가면
# 서비스
# 해줄듯
# 돈걱정은
# 하지말고컴온
# 내가있다
# 파라다이스로
# 간듯
# 환쏘물하러
# 3분이면
# 기다려주자
# 끝날텐데
# 2009년
# 마지막이네
# 이노래가
# 2009년이면
# 애기떄네
# 술못마실때
# 못마심
# 저야
# 캐리해주시면
# 피방비좀
# 닥치고와
# 3만있어
# 1011
# 아침9시
# 땡스
# 가고싶었는데
# 고민이다
# 마음이
# 아파서
# 모르겠음
# 버려놔서
# 잡지
# 가방에
# 챙김
# 득템
# Already
# 와우
# 부지런솬
# 부솬
# 10시
# 노력해봄
# 누구우구
# 네오뺴고
# 다올걸
# Where
# 기본옵션임
# 공부해랴지
# 헌이는
# 가라고하자
# 나야
# 괜찮으려나
# 쮸바라
# 권유만
# 해놓고
# 매달리진
# 쭈르밤
# 귀여운녀석
# 큐티환
# 힝
# 히힝
# 귀요미임
# 귀요미임튜브
# 귀요미해야지
# 귀한
# 자식들인데
# 귀요미
# 귀요미하셈
# 리그
# 왔는데
# 류제홍
# 지렸음
# 세계에서
# 1인자
# 저격
# 피지컬론
# 현시점
# 페이커수준
# 플레이햇길래
# 컨트롤이
# 좁은
# 틈사이로
# 수면총쏴서
# 궁쓰는애들
# 맞추고
# 힐러인데
# 답답한지
# 떄려잡음
# 적으로
# 저격으로
# 수류탄
# 평타
# 34세트
# 다시보기
# 봐보삼
# 올라오면
# 쥐림
# 뭐라
# 쳐야함
# 대회가
# 머라고
# 유투브에서
# 온겜넷
# 채널에서
# apex
# 시즌2
# 팀이름은
# blue
# lw
# 루나틱하이
# 했음
# 재밋어짐
# 큰일낫음
# 이프로도은
# 오면뒤진다오지마
# 쭈밤
# 만나
# 어디에서
# 일번가
# 석기정
# 거기좋지
# 해주는거
# 파란색깔
# 뽕
# 하이라이트임
# 범계면가는데
# 일번가는안됨
# 경쟁전한판때려서
# 기꺼이가마
# 싫고
# 코노는
# 피방도
# 한두시간만
# 수고햇다
# 푹
# 놀거야
# 일번가에서
# 잘들놀거라
# 다시두고다닐테니
# 핸드폰
# 나중에부러도소용없다
# 집에두고다닌다고
# 안불러
# 인강때매잡시
# 들고다닌거임
# 1차끝자고보세
# 승리해서
# 1차금방임
# 후다닥하고
# 붙어와라
# 존나멋지게
# 세수
# 후적후적
# 지금일어났네
# 10시반까지감
# 출발
# 굿모닝
# 발기찬
# 열두시까진
# 되셈
# 륮제홍이
# 성대력
# 역
# 버스타러가는길
# 풕미
# 롸잇데얼
# 고하드
# 킵고잉
# 할덜
# 더러웟지만
# 재밋엇다
# 찍인줄
# 빨리와형
# 어피치형
# 비오려는듯
# 날씨가
# 메이요우
# 우산
# vos
# 큰일이다
# 노래좋네
# 씻
# 정말
# 갘아서
# 이러다
# 죽을거
# 개빠르넼
# 시한부
# beautiful
# life
# 사랑이란걸
# 알아가
# 이제야
# 느껴가요
# 행복이란걸
# 예
# 사랑해요
# 사야해서
# 옷이랑
# 운동좀
# 에매한데
# 맥날
# 앞지나감
# 울어
# 네가
# 미워서
# 니가미워서
# 브이오에스
# 땨문에
# 생활이
# 좋은날
# 유
# 유는
# 언제나
# 위듀
# 곁엔
# 위듀우
# 들으면
# 알거같아
# 그노래도
# 50분에출발
# 30분걸림
# 하고잇을게
# 로
# 처치
# 플레이어
# 지리내
# 하이라이트
# 임쟁이
# 정크랫중독남
# 시작이다
# 팟지받는순간
# 메르시중
# 코노하러옴
# 아이온가는중
# 되나
# 즐거웠다전우들❤
# 마이엔젤도
# 육십칠점인데
# 사십오점
# 쮸바르
# 점수따기개힘듬
# 목나감
# 다른거연습해가야지
# 개발림
# 삿어
# 얼마주고
# 172040
# 십일마넌
# 19주거삼
# 복지카드
# 지금도옵치중
# 나집에서들어갈까
# 아뒤중
# 너걸로
# 재접
# 옵치가능
# 아디좀
# 빌려줘
# 뭐엿더라
# 이메일
# 어피치꺼로
# 갓감
# 삭데
# 아뒤
# 강탈
# 임즈환씨는
# 자기껄로
# 하눈즁
# 삭제
# 레벨높아서
# 안한대
# 고로너걸
# 나한테줘여함
# 무지가양아치임
# rkddnnet
# over1248
# 손무지가
# 아이디강탈해서
# 겨우들어가는중
# 5분후들어감
# 약탈자무지
# 구매함
# 시디
# 동생이
# 임즈환도
# 걔네둘은
# 안양이고
# 두명은
# 아이온인건가
# 가족외식
# 때매옴
# 11시까지
# 달릴듯
# 몇시간
# 두시간쯤
# 저들어감
# 안들어가짐
# 결제한거라
# 계정당
# 동생거를
# 훔쳐와야함
# 10분내로
# 기둘
# 기대
# 안와
# 아까
# 얘기했잖습
# 결제하는거라
# 계정으로
# 기다릴게염
# 어피치걸로는
# 접속이안됨
# 기대껄로해야함
# 훔치는중
# 3분내로
# 접속가능
# 비번받는중
# 완료하고
# 제군들
# 즐거웠다
# 명돈감
# 점심때는
# 갔을수도
# 저녁은
# 홍콩반점
# 왓어
# 아지금
# 저녁먹음
# 퐁반
# 짜장면에
# 짬뽕에
# 탕수육
# 곱
# 짬뽕
# 짜장
# 베리굿초이스
# 삼차
# 엇
# 한시간
# 가자가자
# 대기모드
# 에서전환중
# 무지를
# 빡겜
# 실행
# 홈으로
# 신전으로
# 아누비스
# 잘가요무지
# 접속완료
# 가달
# 지남
# 내걸로접속
# 해도됨
# 한시간남음
# 아뒤점
# 무지리턴즈
# 엘리베이터
# 수호
# 아이디줘
# 3층
# 누름
# 충전할거
# 잇지나
# 굿구
# 땡큐
# 아이디돔
# 컴터
# 키는중
# 잘가게친구여
# 충분히있다네
# 너무걱정말게
# 버스타게
# 65번
# 디바궁만
# 아니엇으면
# 막앗는데
# 한시간만한거
# 정도
# 추가
# 하신거
# 할만큼
# 아까워
# 그렇게성장하는거지
# 막은건데
# 당해서
# 밀림
# 차
# 잘하셈
# 아쉽다
# 마지막에
# 배치고사의
# 극적인
# 할수있었는데
# 까비
# 터뜨려서
# 잡앗는데
# 아쉽아쉽
# 겐지나
# 리퍼도
# 연습해야겠어
# 짜증
# 들어가서
# 진영을
# 깨는걸
# 할줄알아야할듯
# 짜증나
# 33
# 배우삼
# 후아유랑
# 되는곳에서
# 액기스
# 감을
# 잡앗으니
# 감잡음
# 쉽고
# 딜하나
# 탱하나
# 할수
# 경쟁전에서
# 같고
# 먹을거
# 바가지
# 욕
# 해도되는데
# 자알해야해
# 욕먹을거
# 딜에선
# 리퍼나
# 입문하삼
# 리퍼
# 솔져는
# 인기쟁이라
# 픽이
# 프로들은
# 림
# 정크랫같지
# 날라가고
# 싶네
# 아파트
# 포탄
# 신내린듯
# 물아일체
# 쏠쏠하지
# 타이어를보면
# 굴릴듯
# 계산하고있을듯
# 몇인궁
# 점프해서
# 터뜨리면
# 이제기본기는
# 하나보네
# 찍었던데
# 다이아임
# 원래실력은
# 셤끝나고증명하지
# 한판졌드만
# 3만딜넣고짐
# 두판밖에
# 어짜피
# 의미없음
# 4만딜로캐리하지
# 담번엔
# 날
# 뛰어넘어라
# 허접아
# 너몇인제
# 2020
# 까주삼
# 플래는찍고
# 넘어드림
# 안할거
# 유종의미
# 멱살캐리해야지
# 떨어질게
# 무서워서
# 늘었음
# 마니
# 떨구면
# 사람아님
# 뭐야이건
# 라이언꺼로
# 받아볼라고
# 라이언꺼
# 브론즈
# 쳐박기
# 즐겜하려나본데
# 한조로
# 봐서
# 몇점나오나
# 볼라고
# 내생각에
# 1400점대에서
# 1승
# 9패해서
# 시작했는데
# 배치그닥의미없음
# 낮아서
# 티어가
# 4판밖에못함
# 배치중에
# 제대로된겜
# 영향
# 나머지는
# 던지는놈들
# 아군이든
# 적이든
# 투성이
# 1400서
# 2300인데
# 시작했자너
# 전시즌
# 올리기
# 100판은
# 자기실력대로
# 최소돌려야할듯
# 티어갈라면
# 5승5패에서
# 1960나왔음
# 2300점까지는
# 가보겠음
# 참고는하셈
# 배치에서
# 핵쟁이만나지말길바란다
# 2번만남
# 허락없이
# 받아놔야겠다
# 배치좀
# 구해요
# 텝스셤
# 오후나
# 요
# 고사실
# 남자네
# 왓는데
# 칙칙하네
# 오늘은못할듯
# 교수님미팅이라
# 렙업좀
# 해놔
# 혼자가서
# 20
# 5만
# 더까면될듯
# 다했으면
# 디바좀연습해
# 임즈환
# 라인하면됨스
# 갠지
# 건드릴레벨이아님
# 겐지는
# 라인이어렵긴한데
# 돼지연습해
# 오피임
# 희대의
# 어피치뭐하냐
# 초심으로돌아가
# 로드호그연습해라
# 초심
# 초르심
# 개추워
# 전혀
# 운동하고
# 거기도
# 비와
# 추워진다던데
# 바이브
# 비가
# 오는날엔
# 비스트
# 그리워해
# 왕의길로가라
# 싫은데
# 신전이
# 호우허언
# 올래
# 유에프씨바야뎀스
# 앟
# 찬성
# 정찬성
# 야스야스
# 두경기
# 더보면
# 두경기만
# 정찬성경기함
# 비가오는날엔
# 찾아와아
# 성원이를
# 조져야
# 라이언이가
# 리장타워로
# 후다닥
# 미팅
# 밝히네
# 성원이
# 14000딜
# 넘으면
# 덤벼라
# 16000인데
# 뭘로찍엇는지모르겟다
# 최고딜이
# 꿇어드리지
# 이거넘기면
# 솬인
# 힐도
# 10000이상찍으면인정해드림
# 아나로
# 효현이는
# 너보다
# 넣은거
# 딜
# 잘하지
# 빠뜨렷군
# 주어를
# 이가
# 들어가면
# 넣엇는지
# 확인할수
# 프로필에서
# 통계가보삼
# 최고킬수는
# 그런거도
# 나옴스
# 종류별로
# 분석가능
# 첨한건데
# 영상보고
# 첨으로
# 잼씀
# 5시간내에내기록뚫으면됨
# 모스트
# 정크다
# 깬거
# 저거3개빼고다함
# 최근에는
# 그럴리없음
# 16000되지
# 않앗냐
# 딜량을
# 23킬
# 햇을때
# 확인
# 인증샷올려봐
# 23킬햇을때
# 에서
# 같앗는데
# 경쟁전함께할
# 영광을드리지
# 사양함
# 프로도이랑하면
# 23킬하고
# 꼴랑
# 만육천이나옴
# 키보드배팅해서
# 정크랫이니깐
# 가능하지
# 좀이따가
# 모바일로는
# 전적확인안되남
# 확인해볼게
# 인증샷올려
# 맞아주나
# 애들이
# 저렙존이라
# 쉽게인정하는군
# 같이하면
# 아이디랑
# 팬더는
# 허접인데
# 입버워치
# 만나는듯
# 사람들을
# 피지컬이
# 렙이높아서
# 자꾸언밸런스됨
# 오빠와치
# 올리고와
# 점수나
# 발라줘
# 10대떡으로
# 연습하라우
# 이노무시키
# 경쟁전선
# 캐리해봐
# 부심
# 자신감으로
# 캐리하는거여
# 안나옴
# 쫄면
# 위도우
# 이런거하면
# 그순간만큼은
# 내거
# 파인이다
# 하면서때려야
# 다른애들이
# 팟지뜸
# 1씩
# 1인분
# 5분에
# 메이코패스나하는넘이
# 같은뎅
# 잘하는거
# 더잘함
# 경쟁전에도움되는걸
# 자리야해줫자나
# 졌잖아
# 궁연계
# 디바랑
# 지리지않앗읍
# 똥싸고
# 탈주햇자나
# 한넘
# 캐리해야지
# 그거까진안됨
# 서브힐러
# 걔말고도
# 또있었음
# 사람아닌애가
# 힐러나하지색갸
# 딜러하고싶은데
# 라서
# 픽들이
# 자리야한거아녀
# 메르시
# 숙달함
# 소르져
# 놀란다
# 세상이
# 메이
# 한조랑
# 3만딜넣고와
# 솔져로
# 그럼인정
# 아나해주는거
# 어절수없이
# 젠야타나
# 왬
# 무지정도하면
# 벽타기
# 무의미하다
# 딜량
# 떄려도
# 방벽에
# 받기
# 싫어
# 아그래
# 눈쟁이한태
# 딜량보다
# 테
# 따지셈
# 처치로
# 딜딸됨
# 방벽도
# 싶음
# 인정받고
# 바스로
# 기억안나는데
# 처치는
# 까봐
# 로드호그가
# 2만정도
# 실질딜은
# 은따는
# 그판이
# 꿀잼이엇는데
# 쨋든
# 개쩔었음
# 궁연계도
# 임쟁이가자
# 옵치다운겜을했다
# 02
# 첫날에
# 돌리게
# 셤끝나고
# 연습많이해놔
# 둘쨋날엔
# 어렵다
# 탱커가
# 탱커를연습해라
# 04
# 이런식이면
# 라인이오피인데
# 자리야랑
# 데뷔할듯
# 프로로
# 라인이
# 운영이
# 갖고놀수있음
# 저렙존에선
# 낮아
# 80안될껄
# 레벨이랑
# 상관없음
# 렙
# 고정도까지
# 연습하고와
# 점수로만
# 티어
# 2천임
# 티어점수가
# 기대가
# 1800대만
# 만들어오면
# 캐리해드림
# 3400이엇지
# 3200이었을걸
# 3200
# 기대한테
# 조아리자
# 기대잘하네
# 기대기대기
# 원챔
# 3천이면
# 다이아네
# 곳수임
# 다이아가야지
# 개곳수
# 개곧슈
# 연습이나좀
# 경쟁전을
# 계속돌려라
# 떨굴때떨구더라도
# 2100점찍으면
# 배치
# 2월달
# 끝나겠지
# 되버린듯
# 빠대는
# 즐겜장소가
# 같이해야함
# 너희랑
# 굳이그럴필요는없지
# 던지는애들만날가능성이크니
# 솔큐돌리면
# 우리랑하면
# 만날듯
# 티어애들이랑
# 조합맞춰주면
# 탱커힐러
# 이길가능성은높지
# 뒤로하더라도
# 실력은
# 안데
# 딜러해야데
# 불안
# 귀찮아
# 안하면
# 앞애서
# 오지게해도
# 잘하면됨
# 케어도
# 1000만이라도
# 넘을게
# 1000은
# 심해다
# 3정도임
# 그정도도
# 안될듯
# 거기가면
# 못나옴
# 거기는
# 트롤천국임
# 이십오까지
# 빠대하면
# 1500은
# 나와여되
# 플레이
# 한땀한땀
# 맞네
# 렙업이나하고와
# 저렙은
# 렙업
# 옵치가
# 잼잇음
# 레스트인데스의
# 소울이
# 돌아옴
# 돌아오는듯
# 맵을
# 맵
# 중요
# 파악도
# 위치
# 힐킷
# 경우는
# 정크같은
# 점프로
# 알아두면
# 영상보면서
# 이런거도
# 쟁이
# 형님
# 쟁이형님
# 동생님
# 하러가야지
# 군필파워
# 꿀먹은
# 꿀빨아서
# 나온듯
# 아껴
# 기대하자
# 돌아오길
# 미친드시
# 빡공하고
# 들어올준비하는듯
# 데이트
# 못한다던데
# 그랫는데
# 안양못가
# 2시간뒤
# 나인데
# 레파토리
# 우리들의
# 레파토리인대
# 데
# 꼬시는
# 역할
# 인증샷
# 가잇엇는데
# 말보다
# 행동
# 유엡씨
# 아닌
# 잘들어가삼
# 칼국수먹고옴
# 밤샐지도모름
# 아쉽구멍
# 빌려야겠네
# 14429임
# 14000은
# 넘김
# 뚜들겨팬다고
# 무조건뭐
# 목적이
# 옵치는
# 죽이는게
# 14000넘기고
# 오래서
# 일간
# 유리하긴
# 죽이면
# 결정적일때
# 필요하지
# 한방이
# 폭력범
# 가는게
# 경찰서로
# 답인듯
# 볍
# 민중의
# 지팡이한테
# 몽둥이질좀
# 받아야할듯
# Ufc
# 남음
# 인정하지
# 정크랫으로해냈다는거굼
# 기본기
# 쓰니깐
# 잡음
# 주먹으로
# 쳐서
# 한대
# 센스가
# 두뇌
# 지렸다
# 일라운드
# 케이오
# 장난아님
# 개썜
# 어퍼컷으로
# 개안되네
# 된듯
# 뜬거
# 뭐뜸
# 30초
# 좀비
# 코리안
# 코좀
# 첨에는
# 맞앚엇는데
# 훅가네
# 어퍼컷
# 오른손
# 기다렸는데
# 금방끝나
# 싱거워
# 글게
# 분명히
# 버뮤데즈
# 관중
# 조낸썐데
# 9
# 랭킹
# 싱겁구만
# 찬성이형
# 개좋음
# 몸
# 가야할듯
# 타이틀전
# 3초만에
# 끝낫수도
# 버텨내면
# 성전환
# 임수희
# 임수현
# 임수정
# 합성
# 이은
# 임구마를
# 만들어보까
# 뭔가를
# 레전드
# 뭘해도
# 이기긴
# 완벽하다
# 이갓헌
# 옵치안하녀
# 냐
# 아직타이밍이아님
# 4000
# 네시간임
# 제대로돌려봐
# 팬더랑
# 넣으면
# 삼처넌
# 4시간임
# 성대라서
# 각성할께
# 너네
# 플래찍는거
# 시간정확함
# 버뮤데즈랑
# 한판해야할듯
# 각성하셈
# 2차셤까지끝나면
# 플래는가있겠지
# 안할래
# 너네끼리하라고
# 너네랑안함
# 점수떨구기싫음
# 안하는거임
# 높을걸
# 오해
# 얼령
# 훈련해라
# 떨구겠디
# 닫혀
# 끝이다
# 해봐
# 점수대낮아서
# 이기면점수후하게줌
# 하이
# 짜짱
# 찾아봤는데
# 임주마
# 아이맥으로
# 할수는있네
# 깔아서
# 데스크탑12
# 패러랠
# 깔려있지만
# 부활의
# 결론은
# 돌려야함
# 맥에서
# 놋뷱터지는거아님
# 노트북아님
# 27인치짜리
# 존나끊길것같은데
# 느린거아님
# 반응속도
# 윈도우로돌리면
# 깔아는보겠음
# 솔져못하겟네
# 박사형은
# 윈도우컴이라
# 잘하셔서
# 잘될수도있는데
# 깔아봄
# 높지만
# 못할가능성은
# 연구실에선
# 눈치보여서
# 돈주고
# 피방가는게
# 맘은편함
# 존슨
# 갈텐데
# 아니왜
# 입학도
# 논문을쓰라는거야
# 학부생한테
# 싫다
# 싫어짐
# 개싫어함
# 여자친구도
# 나도싫음
# 극혐인듯
# 심영
# 누구여
# 심영은
# 고자라니
# 의
# 주인공
# 깔아보고
# 6시
# 반쯤
# 화이또
# 딜러
# 연습도
# 해보게
# 맥크리는
# 타고나야함
# 리퍼의
# 역할은
# 딜런데
# 샷건
# 스탈이라
# 덩치큰
# 위주
# 자르는
# 탱들
# 넓어야
# 면적이
# 박힘
# 총알이
# E로
# 끝이라
# 로드호그한테
# 잡히면
# 조심
# 쏘고
# 도망가고
# 쉬프트로
# 힐킷먹고
# 암살
# 없이
# 보갯음
# 겟음
# 들어가도
# 정면에서
# 궁극기를
# 높은곳에올라가서
# 뒤나
# 리퍼는
# 급습하는식으로써야함
# 멀리서는
# 평타짤짤이넣고
# 뒤로
# 몰래들어가서
# 힐러짤라주면
# 구슬생기니
# 애들짜를때마다
# 체력50짜리
# 이게은근개꿀임
# 맡기러
# 몸을
# 비트에
# 때문이지
# 지기
# 포착햇지
# 이거이거
# 중독이심각하구만
# 나중에복귀했더니
# 마스터찍는거아녀
# 오지게몰입중인가보군
# 60렙까지는
# 빠져살거같네
# 22됨
# 20부터
# 22000받지
# 경험치
# 끝났다
# 상자깡은
# 전설스킨오지게안나옴
# 못하겟다
# 이또
# 너희가
# 필요하다잖아
# 자본금이
# 잔액이
# 랩이
# 안올라
# 그럴리가
# 20프로
# 뽀나스인데
# 피방은
# 23
# 버스태워주는거
# 솔큐가
# 잘풀릴걸
# 네명
# 동시
# 처치함
# 7표
# 받앗어
# 칭찬
# 23랩
# 그런데도
# 잘했네
# 딴거는
# 허졉
# 4시간
# 솔큐전사네
# 맵은
# 알듯
# 알만큼
# 무시무시하게
# 성장하네
# 좋아졋어
# 되가는건가
# 뒤집는
# 뒤집
# 롤챔스
# 보는데
# 승기잡으면
# 나머지
# 아깝다
# 제도가
# 지지치는
# 경우도
# 그런데
# 잇긴해서
# 점령전에서
# 99까지
# 주다가
# 뒤집기도함
# 성장이
# 단한
# 플레이어가성장
# 단단한
# 집가셈
# 소변보기
# 한손으로
# 강력했다
# 페이커는
# 무리수를
# 죽긴했지만
# 강려크
# 무게같은
# 프로도이의
# 달래고
# 삐진여자친구
# 복귀함
# 밤샘갓
# 각
# 밤새다
# 힘들면
# 리장타워로와
# 삐져
# 안놀아줘서
# 다르게
# 밤은
# 평소와는
# 다른일로
# 밤새니깐
# 그런건아니고
# 복잡한게있음
# 풀었음
# 묶은걸풀면
# 달라지는군
# 묶어두었군
# 선구자답게
# 쿠퍼액만
# 그것은
# 질척질척
# 이녀석
# 답군
# 이기회에
# 묶으셈
# 공부와
# 묶엇지
# 편하더군
# 모르더군
# 세컨도
# 잇지
# 놀아줘야
# 밸런스가
# 감이
# 감도가
# 안좋더군
# 굴지성
# 끊김
# 흐름이
# 옥신
# 그렇게됨
# 굴광성
# 굴광성이네
# 옥신은
# 갈대마냥
# 숙이더군
# 중요한거는
# 상대방은
# 성향을
# 우파인지
# 좌파인지
# 양쪽을
# 전부
# 단련시켜놔야해
# 정치적
# 좌파는
# 선호하지
# 좌를
# 그때만은
# 정치얘기가아니고
# 좌
# 탁탁탁
# 로션
# 추천함
# 급이다름
# 베이비로션
# 존슨즈
# 갓무지
# 일딴
# 남자가
# 악력이쌔서
# 고옴
# 그냥하면
# 무뎌짐
# 부드럽게
# 쯔왑쯔왑
# 스무스하게
# 익숙해져야함
# 하는거에
# 발라주는게
# 러브젤이
# 제일좋고
# 가벼운로션
# 그다음이
# like
# 존슨즈베이비
# 달리게
# 솬은
# 연속으로
# 순으로
# 투어
# 못돌아올듯
# 오늘내로
# 30분이라고함
# 기본
# 대단한듯
# 싸는양이
# 싸고옴
# 씻고옴
# 현타임
# 될수
# 잇구만
# 시작이지
# 씻고와서함
# 씻지않음
# 반댄데
# 순서가
# 씻지
# 이상한데
# 이인간
# 상관없지
# 씻고
# 인듯
# 다녀옴
# 밖에서
# 고르자
# 작품을
# 작품을골라
# 일본임
# 보내드림
# 국산
# 슴가
# 개쩌는
# 특집하나
# 있
# 커면
# 개쩌는데
# 자괴감
# 하고나면
# 보기싫도라
# 크면
# 개쩌는거있음
# 자극은
# 그레이몬급
# 메탈
# 미사일
# 인공지능
# 묶는거
# 여러명
# 디테일한
# 1이어야함
# 노모
# 모자이크
# 사살
# 여부는
# 탕탕
# 유모를
# 주면
# 노모여야지
# 죽여버린단건가
# 노모는
# 노모인것도
# 묶는거랑
# 때리는거
# disgrace
# public
# 실허앟
# 싫음
# 하드코어
# 절대
# 국산이
# 현실감
# 감정이입
# 잘찾으면돼
# 못느낄듯
# 실제에선
# 찾을수있어
# 안섬
# 수지인데
# 개얘쁜데
# 가슴위
# 가슴위부터
# 목밑까지
# 머리끝
# 온리
# 에
# 우선순위
# 그런분은
# 보통에
# 잇는걸
# 있다본다
# 찾을
# 확률은
# 별로에
# 차라리봄
# 별로까지로
# 내려가다니
# skeh
# 잘안봄
# 못생기면
# 더낫지
# 별로여도
# 잇는게
# 짜증남그러면
# 안되면
# 얼굴만
# 정
# 내일쯤
# 메일로
# 쏴드림
# 보는걸로
# 질림
# 얼마를
# 질리는건가
# 얀리
# 너무크면
# 비호감됨
# 비현실적이라
# 초보일때
# 초보
# 인데
# 대세는
# 대세
# 괜찮음
# 줄리아도
# Juila
# 줄리아
# 몸매
# 서양
# 안본다
# 않았음
# 혼혈임
# 일본사람인데
# 혼혈인데
# 예쁘고
# 몸매가
# 정확하게
# 굿인데
# 꼴리게
# 외모가
# 가슴모양
# 조차
# 됌
# 륜
# 유륜조차
# 신호가
# 배우신분
# 취향이
# 최근이
# 같은듯
# 줄리아임
# 길거리
# 지나가다가
# 심쿵하지않음
# 심장이
# 아림
# 저걸로
# 어덜까
# 몰입감
# 줄줄
# 파운딩
# 퍽퍽
# 운동이나
# 몸쓰는거
# 만나는거
# 여성분
# 적극적임
# 하는분들은
# 귀찮아하
# 실제로도
# 그런사람들
# 있잖아
# 역도선수
# 땀나는거
# 싫어하는
# 만날까
# 뿌러짐
# 감당안돼
# 강사
# 요가
# 녹을듯
# 들어본적있음
# 요가들었거든
# 학교에서
# 요가강사
# 개힘들던데
# 배워봄
# 요가자세는
# 개힘듬
# 마스터한
# 진자
# 강사는
# 요가강사들은
# 오지는데
# 잔근육이
# icecream
# shit
# 메로나
# 푸슈슛
# 불러도
# 애국가
# 갓창정
# 12살
# 연하
# 요가강사랑
# 결혼함
# 슈바럼
# 돈이많아야함
# 양아치여도
# 돈이많으면돼
# 부럽군
# 돈벌자
# 기승전
# 열심히해서
# 보내주는
# 실리콘벨리
# 인턴
# 꼭갈거야
# 방학에
# 한달가는거
# 타고와야지
# 흑마
# 못느끼는거
# 아녀
# 흑형들이
# 수컹수컹
# 노력은
# 급이다르륻
# 돌진하면
# 무서울듯
# 끊어질듯
# 멧돌
# 유얼
# broken
# 남겨야할듯
# 선구자임
# 우리중엔
# 미즈노
# 아사히
# 달리고옴
# 글래머네
# 그녀
# 노인을
# 돌보는
# 시골마을
# 단발맞지
# 키도
# 글래머에
# 덧니
# 니혼진
# 치곤
# 크네
# 키가
# 사진빨인가
# 그른가
# 적당한데
# 작아서
# 그런것도
# 싫던데
# 나오는거
# 노인
# 상관
# 90년생이네
# 그럴만
# 있어보였는데
# 한살차이네
# 늙음
# 안늙었자너
# 그닥
# 사진봐도
# 생각은
# 안들음
# 애기같단
# 임팩트나
# av나이
# 나이도
# 시낮
# 165센치
# 35의
# 36
# 신체사이즈
# 11월
# 12일
# f컵이네
# 사람인가
# F아닌데
# 안큼
# 올려봐줘
# 맞는지좀
# 보게
# 구글에서
# 서치함
# 찾아보삼
# 아시발
# 늦게신청했는데
# 일부라한양대안갈라고
# 나같은인간이
# 많았나봄
# 또가게생겼네
# 1차
# 1주일늦게신청했는데
# 넉넉하게걸림
# 아까비도아니고
# 1주일도빠른가봄
# 팬더족쳐야겟네
# 어딜
# 맘속
# 쮸르바르
# 시사회
# 임버워치하게
# 영화보여주께
# 임버워치
# 덫설치중인거아님
# 입구에
# 나무
# 뿌리깊은
# 깊음
# 자빠졋네
# 지롤하고
# 명대사인데
# 저걸모르나
# 어피치뭐해
# 법이나
# 카마수트라헌
# 몇렙이냐
# 될예정
# 지금은몇
# 슬슬따라오네
# 기모찌
# 모찌기
# 피로하다
# 그만찍해
# 심하다
# 체력저하가
# 바이아구라가필요한부분인가
# 굴먹어
# 굴좋지
# 댐굿
# 씼
# 솔플
# 노
# 헐헐
# 1명인데
# 총인원
# 한자리에…
# 06이상
# 이지만
# 컴공도
# 2년만
# 8시에
# 마시고
# 와인
# 엿네
# 전무님이
# 결혼할
# 때
# 준대
# 축의금
# 전무님
# 32년짬이라는데
# 32년짬
# 봐라
# tnghks
# 메일확인좀
# 달리는중인듯
# 옵치하다잠든거아님
# 메일
# 보는중인듯
# 뭔메일
# 메일확인했으려나
# 보내줌
# 달려서
# 못일어나는듯
# 훌쩍
# 모닝워치달리는거아녀
# 그분도
# 긴축재정임
# 놉
# 조루아이디로
# 안가고
# 피방갈듯
# 답장이없지
# 뻗은건가
# 그런가봄
# 4번한듯
# 무린듯
# 사연발은
# 엘쥐임
# 봣다는데
# 창훈이가
# 엘지
# 전해라
# 한화라고
# 못해서
# 설에
# 찾아뵙지
# 갔다오느라
# 할머니댁
# 늦엇구먼
# 답장이
# 늙으셔서
# 흐흑
# 못막는다
# 시간은
# 있을때
# 잘해드려
# 84이셔서
# 87
# 육십살씩
# 차이나심스
# 못막네
# 세월은
# 거점
# 막으삼
# 메르시가
# 살려줘야됨
# 나이임
# 살아나도
# 25찍고오셈
# 지금응
# 집왓어
# 푹쉬삼
# 기다리는거
# 메일이
# 내메일
# 확인바람
# 연결
# 티비로
# 봐야되는데
# 폰으로
# 보려면
# 인코딩
# 고맙지만
# 수가
# 이걸
# 안드로이드라
# 가능할지도
# 재생
# 아이폰은
# 귀찮긴함스
# 볼라면
# 그대의
# 폰이라면
# 정보구먼
# 활동
# rm
# 컴터로
# 옮기면끝
# 엔드라이브로
# 옮겨서
# 앤드라이브에
# 올리기에
# 용량이
# 하것지
# 난줬으니
# 보는건
# jinhosohn
# 2000넘게나오면
# 앞으로닥치도록하지
# 안할거니깐
# 호우프로도
# 조용한
# 편이라
# 걍괜춘
# 나한테도
# 보내준거
# 전달좀
# 전달
# 옵치질림
# 정부인이매우바쁜듯
# 가는건가
# 세컨따라
# 엘쥐로
# 있는중
# 엘쥐
# 연수중
# 자바조교
# 합숙
# 침투중
# 깊숙이
# 깊숙의
# 대가
# 중요한게
# 나온
# 딸내미
# 인터스텔라에
# 최근
# 딸이다
# 아들보단
# 이천년생이래
# 뭐하시나
# 대분란의
# 맞이함
# 시대
# 털음
# 털어
# 녕
# 털고
# 남자애
# 얘기중
# 탈탈탈
# 잘햇지
# 멋지구만
# 조교는
# 못하겠다
# 갠톡하면
# 사랑할지도
# 예쁘긴
# 하나보군
# 엉덩이조교
# 못된
# 아가씨가
# 이쁘긴함
# 얼굴값을
# 하는군
# 망해라
# 조졋음
# 순간
# 엉덩이가
# 주물러진
# 낭만은
# 파고다의
# 동생아닌데
# 처음인듯
# 턴건
# 잘해뜸
# 조져놔야됨
# 용기
# 칭찬한다
# 첨엔
# 진심으로
# 잘햇다
# 타일러서
# 하려고했는데
# 박수쳐라
# 짝짝짝
# 회식때
# 모르쇠하길래
# 분노게이지
# 상승
# 아니래
# 그떄부터
# 련이
# 어디어디
# 위치까지
# 찝어서
# 지적하면서
# 체크해줌
# 코디까지
# 탈탈
# 말할거라고
# 학원가서도
# 가만히
# 된다고
# 있어도
# 만들어
# 학원쉴까
# 가라
# 길을
# 할만큼함
# 남자애한테도
# 설교중
# 알아야
# 진실을
# 찾아가지
# 걔한테
# 확인한다고하는데
# 모르쇠하진
# 않겠지
# 하겟지
# 년임
# 반
# 맘약해짐
# 되더라도
# 입싼놈이
# 털어내야지
# 입싼게
# 나쁜거같음
# 묵인
# 하는게
# 남자를
# 생각한다면
# 아니라
# 말해주는게
# 감정
# 이입되네
# 무섭다
# 세상
# 련
# 조져야함
# 남자라
# 썌겐
# 말론
# 조졌다
# 크게도
# 알아
# 못해
# 여기서만
# 큰소리
# 얼굴보면
# 마음만
# 폭군
# 여자얼굴
# 약해짐
# 앞에선
# 쭈글스
# 쫄보무지
# 쫄보
# 엉덩이를
# 주무르기전에
# 걸걸
# 그녀에게
# 상황인건가
# 많다는
# 세상에
# 빵댕녀
# 내눈엔
# 이상적
# 시비걸어서
# 식음
# 빵댕녀다
# 하필
# 원피스
# 주물러질떄
# 자주입음
# 떠오름
# 안지워짐
# 큰일낫네
# 남자친구가
# 같음
# 약아빠진놈
# 과시욕
# 내여자다
# 얘는
# 도장
# 같다
# 꽝꽝
# 간디인데
# 들뻔
# 칼을
# 날릴뻔
# 질풍참
# 알앗네
# 박혁거세인줄
# 지저스
# 간디
# 된
# 이래로
# 간디는
# 첨들음
# 비폭력주의자라
# 핵주먹은
# 알다시피
# 핵이
# 2차대전이후로
# 실전에
# 쓰인적이
# 안쓰여서
# 참으로
# 그럴듯하군
# 잇으나
# 폭발력을
# 절제하는군
# 나조차
# 한계를
# 노우
# 예아
# 벗
# 아임
# 쫄보우
# 캉우군
# 때려주셈
# 미투
# 투
# 여자도
# 없애드림
# 떄리면
# 넘긴다
# 솬이에게
# 전수
# 주먹은
# 평등
# 것인가
# 그랬던
# 미칠듯
# 민욱이
# 예전에
# 삥뜯긴거
# 생각나네
# 육교에서
# 고딩때
# 안외믿에
# 안공애들
# 뜯음
# 삥
# 울학교애들
# 뜯김
# 뜯엇음
# 오히려
# 나왔다는데
# 제법
# 학부모모임에서
# 안양산애들은
# 뜯겼다고
# 말하지마삼
# 어디가서
# A군은
# 삥뜯기고
# 아는
# 끊으심
# 복싱
# 쪽팔려서
# 체육관
# 실화다
# 당함
# 지갑
# 털려서
# 경탁이
# 경탁이는
# 필완
# 제법들털림
# 가리지
# 영중일
# 다녀야지
# 솬이랑
# 집걸어가는애들
# 김
# 안양공고애들이
# 둘러싸서
# 받아감
# 헌금
# 넘들임
# 무서운
# 모임에서
# 학부모
# 관리해야하는거
# 아니냐는
# 그랬음
# 나왔다고
# 말도
# 잇엇는데
# 중학교
# 사진이면
# 김창용
# 먹을듯
# 일짱
# 창용이
# 보스된거
# 지하조직
# 가다
# 많나면
# 아는척
# 그친구
# 수원에서
# 2년동안
# 다녓는데
# 돈안내고
# 무임승차
# 좋아햇지
# 버스에
# 매달려서
# 타는데
# 넘어가더군
# 잘도
# 요령이
# 잇다면서
# 담대하더군
# 이야
# 크게될분아님
# 근황
# 데이식스예뻤어
# 못된것인데
# 들으삼
# 마니마니
# 좋을떄
# 컨디션
# 들림
# 데이
# 낮
# 올데이
# 터리
# 듣고오삼
# 부르면
# 예뻤어
# 뭘들어
# 위에안읽음
# 신곡
# 4시간뛰고오니
# 아왜
# 간다냐
# 인스타에도
# 현주가올린
# 댓글달았는데
# 건대에서
# 놀거리는
# 볼거리
# 1절
# 후렴
# 노래부르는데
# 비슷한애가
# 건대
# 맛집
# 데이트냐
# 찬용스
# 꽤들어본노래맞네
# 꽤들었다니
# 팬
# 밤새는날
# 밤에계속들음
# 신곡이었군
# 시간잇음
# 이번주금요일
# 금
# 데이트가
# 챙겨
# 대실할게
# 놀아
# 풀로
# 없자너
# 잘자
# 말지
# 건대는
# 왜감스
# 우리랑
# 찬용이
# 돈좀있다면
# 경성
# 양육관
# 양꼬치집인데
# 꿔바로우가
# 핵맛
# 쵝오
# 탕슉은
# 흐규
# 좋은데는
# 블루케찹
# 가는데
# 커먼그라운드
# 감주자너
# 있는거
# 체인점아닌가
# 감준데
# 맞다면
# 밥집이야
# ...
# 도와주던가
# 2년을
# 싸워봐서
# 텄지
# 고딩때부터
# 해오던건디뭐
# 남톡방에서
# 올리는거는
# 짤을
# 싸우지는
# 않앗고
# 주제를
# 경험에
# 야한얘기를
# 자기의
# 발언만
# 성추행적
# 안나가면
# O
# 관계중에
# 빠진적이
# 예를
# 콘돔이
# 하는것과
# 것과는
# 여성의
# 별개이다
# 일반인이면
# 야한짤이
# 그런게아니라
# 야한짤도
# 시가수
# 갠찬자너유
# 무대보고
# 얘긴
# 공유하면서
# 올리는건
# 이상한거고
# 이상한거겟지
# 그러려는
# 매체에
# 생각함스
# 야동추천은
# 아닌거고
# 갠찬은디
# 성범죄도
# 왼손한테
# 죄짓는거지
# 이상햇다
# 전화를
# 아니라고만
# 말하다가
# 이해하고
# 전화끊은듯
# 강다니엘
# 돌려보는건
# 스셧
# 안되남
# 되는거라고
# 추천하면서
# 공유하는건
# 노골적이라
# 그러함쓰
# 의견은
# 노골적이긴하지
# 머쓱쓰
# 성추행은
# 여자입장에선
# 공론화햇다는게
# 별로일수도
# 이해를
# 잇겟군
# 하게는
# 이해는
# 그들이
# 이해하기
# 힘들단거
# 그랫다면
# 별로라는게
# 이해는됨
# 충분쓰
# 야동에
# 우리같이
# 절여져있지않아서
# 골자엿으니
# 건전한겨
# 된다아니여
# 성추행만
# 성희롱
# 아니믐
# 그러하다고
# 남성이
# 이해해달라
# 내가옴
# 어찌생각하심
# 일부
# 이상할것같지만
# 되는정도
# 애인이
# 인것같고
# 보든
# 안보든
# 야동도
# 몰카나
# 범죄만
# 가능하다고
# 추천이야
# 할수있고
# 그러췌
# 생각하는데
# 성생활이
# 얘기하는걸
# 별상관없는데
# 야동얘기하는건
# 남한테
# 공유햇엇다
# 느끼심
# 이상함을
# 가치관의
# 차이니까
# 야한짤이냐에
# 싫어할수도있음
# 안맞는거긴한데
# 짤이던간
# 어려워함
# 차이인거지
# 받아들엿다
# 얘기면
# 정준영아니냐
# 짤은
# 그러하나
# 쓰레긴
# 뭔말인지는
# 재활용은
# 얘기한건아님
# 아까말햇듯이
# 많이싸울텐데
# 대화하는것과
# 오엑스
# 친구들과
# 도출하는게
# 합의를
# 공유하는것과는
# 야한짤을
# 음란패설
# 그런느낌이겠지
# 다른거다
# 야한짤이라는거를
# 개쩔지않냐
# 누군가이고
# 핥고싶다
# 생각한거
# 전개
# 얘기니깐
# 위에건
# 맞구나
# 수긍하고
# 다름을
# 인정하자
# 인정하는거
# 받아들엿음
# 당연한거임
# 개오바고
# 남을
# 고마운거지
# 바꾼다고
# 이상해진거같음
# 그마음
# 개변태새끼처럼
# 쓰레기인느낌
# 맞긴하지
# 사실나도
# 변태라고
# 자연스러운건데
# 문제냐고
# 솔직한거라고
# 나오나보지
# 남들보다
# 남성호르몬이
# 있거나
# 표지에도
# 범죄를
# 저지르거나
# 하는거랑은
# 잘못이라고
# 드라마에
# 박재범이나
# 몸좋은
# 벗은거
# 개쩐다고
# 공유할거면서
# 존나빡치게
# 짝쯔
# 존나싸움
# 싸운거는아니고
# 얘기만했으니
# 조용조용
# 느낌이들어서
# 이상해지는
# 여기다가
# 싫었음
# 얘기해봄
# 카톡보고싶다고함
# 존나싸웠지
# 얘기하지않았나
# 되어있는거보고
# 여기하냐고
# 썼으면
# 얘기아니냐고
# 기분나쁘다고해서
# 주제는
# 합심하기
# 가치관과
# 투영된거냐고
# 감정이입이지
# 그러쿠나
# 넘어가야지
# 다른거고
# 끝없음
# 하는거라고
# 이상한거라고
# 썼는데
# 노답아님
# 프로도이랑인데
# 그얘기는
# 차마못함
# 개이프로도
# 저런류는
# 피르고른함
# 넘어가냐고함
# 정면돌파하고
# 터치하면
# 받아들이고
# 잘못한것도
# 그릇으로
# 포용햇다
# 빗겨갈
# 맞짱뜸
# 안맞으면
# 꺼내는
# 여자분이라면
# 주제
# 34명
# 제낌
# 환승당함
# 형수님분
# 스님
# 올린걸
# 형수님이
# 전하다가
# 시작이엇음
# 욕먹을
# 사과해야겠네
# 얘기되다가
# 주제로
# 별말
# 했어서
# 멋진분이라고
# 끊임없는
# 굴레로
# 들어갔군
# 혜원씨는
# 싸우고싶다
# 같아보일수도
# 군대가고
# 안가는거에
# 전쟁가능
# 헤어지고싶을때
# 거의그급
# 군대가야함
# 여자애중에
# ROTC
# 하는애
# 17이라서
# 23이긴한데
# 재수해서
# 23인디
# 6년
# 기다려야해서
# 드는게
# 의문이
# 주워옴
# 지우러감
# 미인쓰
# 첫학기때
# 조교였음
# 안되는건가
# 교육했찌
# 안되는거지
# 특정인이니
# 조교였는걸
# 시간되심
# 금요일은
# 안될것같고
# 모교르
# 목요일도
# 목요일이랑
# 10시부터가능
# 수는
# 저녁빼고
# 불가능하구만
# 다돼
# 비어있는날이
# 광복절임
# 박사들
# 직장인이랑
# 저녁아님
# 불확실히해서
# 그만둘려고
# 탈잉으로
# 50이고
# 패캠은
# 올라올
# 125000인데
# sk는
# 35000인
# 탈잉은
# 한그릇씩
# 포장해오는겨
# 뺨맞을듯
# 삼계탕이면
# 던져버린다
# 개맛집임
# 생방송
# 투데이에
# 맛잇깆함
# 먹어봣는데
# 맛있긴하지만
# 개맛집까진
# 짬뽕은
# 음식자체를
# 짜장은
# 5천이라
# 월매출
# 짜장면도
# 팔아
# 복날에
# 우리학교근처에도
# 회전율이
# 개맛있더라
# 회전율
# 입장에서
# 3군데
# 물집
# 발에
# 1순위
# 피해야할
# 뜨겁잖아
# 왔다갔다
# 적은곳이
# 좋은곳인듯
# 고기집이
# 최악인것같음
# 냄시
# 시키는거
# 자주가는데
# 갈아야함
# 뒈질듯
# 수저
# 포크
# 사이다
# 소금어딧냐
# 김치
# 떠달라
# 포장해달라
# 테이블도
# 상치워야하는데
# 손님나가면
# 띵동띵동
# 빨리치워야
# 주인이
# 지랄하던데
# 치워
# 세상불쌍함
# 알바들
# 사장이군
# 최저시급인데
# 안타까움
# 그런입장에서
# 잘쌓은듯
# 커리어
# 좋으셔서
# 설계한거지
# 존나한게
# 한수였음
# 맛잇긴
# 저렴쓰
# 먹어야곘다
# 배고
# 프네
# 마렵네
# 개배고프네
# 꺼내었는가
# 몹시
# 오길바란다
# 얘기하는
# 내가한건데
# 잘못없다고
# 가치관은
# 바꾸기
# 못바꾼다고
# 살래
# 그런류
# 상책
# 피하는게
# 도달하면
# 한계에
# 헤어지면됨
# 본질임
# 인간관계의
# 빠가인가봐
# 37도래
# 말햇으면서
# 의도를
# 알수업승
# 안들었거나
# 생각없이
# 싫었을수도
# 토론한걸수도
# 날까고싶은
# 안까임
# 너희들과
# 개까여서
# 개우울함
# 쉬어야햄
# 풀타임을
# 1110
# 토일월화
# 휴식시간
# 오늘은25분
# 0시간
# 지옥인데
# 싫어질득
# 자봐야지
# 재밋엇군
# 많이핫메
# 영상보니까
# 미국가고
# 정장입고잇다
# 씨발더워
# 모범답안아닐까
# 주제에대한
# 토론
# 신여성이다
# 이시대의
# 보여주자
# 환상
# 신곡임
# 더워슈발
# 봉오동
# 엑시트
# 기생충은
# 우울
# 시험잘보구와
# 개웃기다는데
# 임윤아
# 존나차이나네
# 한끝차이인데
# 열받게
# 이오언
# 25헌
# 헌52
# 프로도오이
# 운전하러간다
# 강원도갈꺼다
# 강릉일듯
# 춘천에뭐잇음
# 102보충대
# 조르낸
# 지옥이네
# 타겠네
# 바삭헌
# 강릉옴
# 놀러다니시는
# 더위에
# 벼르고벼름
# 은아소원성취
# 소원성취할차례네
# 기력
# 다빠졌을듯
# 강려크해서괜찮
# 행복해보여도
# 기온때문에
# 안죽은게
# 개신났네
# 애기헌
# 호허어어어언
# 닥추어
# 너답네
# 놀다오삼
# 더위먹을지
# 습하군
# 털복숭헌
# 털헌
# 행복해보이네
# 저동네도
# 흐리긴한가봄
# 뭐하는중이려나나
# 어제돟아옴
# 운전핵피곤
# 운전때문에
# 피곤한거
# 어른헌
# 교수님때매
# 존나짜증
# 됬는데
# 신청한거
# 광주랑
# 구미가야함
# 다가가는거
# 시급20임
# 개먼데
# 걸리는거여
# 문제없을듯
# 80임
# 매일감
# 매일가면
# 개오바야
# 이틀임
# 붙여놔서
# 광주가서
# 구미출근
# 굳네
# 굳는데
# 숙박비가
# 붓네
# 여성과
# 지원될거고
# 다른분과함께
# 외로우니
# 김용암
# 네거티브환
# 시럽환
# 딥톡이후로
# 음담패설끊은듯
# 아주바람직
# 솬이아님
# 음란하지않은
# 닥츄랏
# 여행코스추천좀
# 10개국
# 34일
# 서유럽
# 서부
# 서부의
# 다른추천점
# 머니가없어서
# 몇일남앗다고
# 닥츄고
# 쎽쓰
# 토욜쓰
# 힘들때구만
# 파이어
# 3일만고생해라
# 천국이기다린다
# 고생안해도돼냐
# 고생그만해라
# 8월말에나오고
# 결과일단
# 담주에면접두개잇고
# 선묜접임
# 업계는
# 그래놓고
# 대려감
# 잘다녀와라
# 관리나
# 투자하라는데에만
# 맡겨보마
# 투자따위
# 내돈도박을거거든
# 니명의에
# 투자한다
# 주식투자못함
# 차명으로해야함
# 믿음이가겟지
# 반반이다이년아
# 많을거지만
# 내몫인가
# 불리는건
# 1억찍을테니
# 합격이나해라
# 쉬러가봄
# 쉬한다고
# 캔아이
# 도전자
# 조져주지
# 소질잇는듯
# 수정화살
# 연습한판만하고
# 망쳐도
# 플레임
# 핵고수라
# 내려놔도
# 올려놓을
# 700점을
# 조절햇엇지
# 극복한
# 나이를
# 제홍이랑
# 임제홍지림
# 머가지려
# 한판하고털리고나옴
# 접는게답
# 오늘더위좀심각하네
# 경쟁할거같아
# 도전자로
# 들어갈거같음
# 기즌
# 이틀남음
# 뉴아이디임
# 도전자는
# 진호스
# 배치만돌림
# 안떨어지게
# 왜삼각지냐
# 옵치하고싶을때
# 들어가는거지
# 접진않네
# 좋아해사
# 인가해서
# 겜하면
# 친구아이디빌려서하는중이라함
# Vector
# 얘뜰아
# 너들이랑안하니노잼
# 너발라드림
# 롤토아이디점
# 내가잘
# 아이언1임
# 브론즈2
# 스톤즈5임
# 올라갈수있는데
# 원리가뭐여
# 보드게임이라고
# 생각하고하면
# 롤보다핫하더만
# 꼬추여
# 롤인데
# 토체스자너
# 롤에서
# 오토체스
# 소환사보다핫하다고
# 우리통함
# 척하면척알아들어여지
# 고추색기들아
# 전략적팀전투
# 고추야
# 뭐이
# 개똥마려
# 마려운건뭐냐
# 개냐
# 똥마렵다고
# 요즘안맞아서
# 정신못차리냐
# 우기일듯
# 습도
# 삼각지냐고
# 밀어버린다
# 미셈
# 면도기까진
# 너가해라
# 미는건
# 그건못해준다
# 겨드랑이처럼
# 나시입으려면
# 밀어야함
# 아빠미소중
# 임즈꺼먼저
# 깔끔함스
# 뽀송담임
# 무럭무럭
# 자라는중이라
# 없애려고
# 브라질리헌
# 리얼개덥다
# 팬더고추먼저뽑고
# 꿀럭꿀럭
# 되긴됐다
# 뒈졋다
# 임즈알바은제까지야
# 복학전에
# 쳐맞아야지
# 복학하냐
# 집주변피씨방이였다가
# 임즈복학하자나
# 너느
# 형식상하긴함
# 의미가없지만
# 다싸강하고
# 입사할꺼여
# 2차만
# 5킬
# 펜타
# 입싸네
# 셤합격하면
# 펜타킬하고
# 희망만
# 붙어버리고
# 삼일가즈아
# 레전드네
# 3대법인이
# 뭐뭐냐
# 삼일하고
# 삼일가면
# 삼정
# 안진
# 한영
# 은아랑톡해야하니
# 쓰리험
# 투썸험
# 두탕헌
# 호혐이네
# 이호혐
# 금공강이여
# 16학점밖에
# 놀러가지
# 알바잡기전에
# 금공강
# 여행가삼
# 어디로갈끄여
# 황제패키지
# 아지르여행
# 튀자
# 기이한
# 운전은나한테맡기삼
# 돈중에
# 버려야하는거아님
# 그게되는게워라밸
# 얻겠다
# 갈생각인데
# 운전가능
# 그럼당연히안되지
# 따둬야하나
# 해외면허를
# 준비하고있어라
# 해외갈
# 8월에
# 가고싶었으나
# 뺨때리고
# 논문끝나면
# 이놈이프로도
# 하죠
# 더위드심
# 커부
# 할쑤가헙죠
# 더위사냥
# 팬더사냥
# 더위헌
# 공격적이메
# 묘하긴하지
# 쑹컹담
# 잘라버리겟다
# 겨드
# 추릅헌
# 정글숲을
# 지나서가자
# 엉금엉금
# 대한독립만세
# 더지니어스
# 보드게임하고
# 모입시다
# 갂
# 어피치르
# 임주르
# 야간근무라
# 자보는걸로
# 평촌성심병원
# 아프심
# 예방
# 접종
# 접수하러옴
# 수발련아
# 엉덩이맞고가
# 헬스장이여
# 진료일듯
# 2시까진
# 20분즘
# 대기시간때매
# 진료볼듯
# 서울가야되는데
# 대기하고잇는너를
# 슈발럼
# 치겠다
# 가정의학과
# 알바라서
# 왔는데없어졋네슈발련이
# 수납
# 너보임
# 뽀뽀해
# 커플샷좀
# 주사맞아야해
# 보고오라는
# 맞네슈벌
# 잘보고올꺼임
# 7급이라
# 서울시
# 오늘본건어딘데
# 국가직
# 돌아다녀야함
# 붙어도
# 전국을
# 대흥갈게
# 대흥가도
# 조루없음
# 줘카
# 뭐가잇어
# 촵스테이크야
# 촵스테이크
# 화곡헌
# 핵피곡
# 조루어디여
# 신촌이야
# 9시에연습끝남
# 뭔연습
# 이응
# 쉬어이녀나
# 웰컴환
# 빈호쓰
# 서울직시험은언제여
# 이번에합격하면
# 내년임
# 4금
# 최고의플에니
# 변태같은놈
# 4금이면
# 빠대군
# 경쟁이야이년아
# 롤토체스는
# 안하냐
# 호허어어언
# 일주간
# 알바안가서
# 평촌성심병원갔을때
# 2일전일긋
# 금욜에봄
# 만났구나
# 830일
# 강의하는날이긴한데
# 금요일이
# 되어봐야암
# 무조건가능
# 회사근처라서
# 830일에
# 예야
# 메이비
# 대난교
# 주인공잋다
# 쫩쫩헌
# We
# hohuns
# hole
# need
# holehun
# 홀헌
# 손진홀
# 투홀
# 구멍이
# 아이해브
# 임수햄
# 프로도스홀
# 닥쳐소세지들아
# 소세지컷팅식
# 소시지헌
# 소세지헌
# 닥츄라스
# 딱봐도노맛
# 이눔시키야
# 헤프네
# 최저
# 뭘싸이년들아
# 너들은
# 엉덩이부터
# 엉덩이성애자나
# 급식인듯
# 9500원짜리급식
# 닭껴
# 가루약
# 김소연입니다지도교수
# 사용기한과
# 설문지클릭
# 손현순
# 수행
# 시간내어
# 아래와
# 알아보고자
# 약국에서
# 약의
# 의과학대학교
# 인식을
# 조제에
# 조제한
# 중입니다
# 참여해
# 여자친구분임
# 뿌려달래서
# 뭘뿌려
# 면접이라
# 준비할듯
# 졸업했다
# 기대가찍어서
# 몇개올려드림
# 9월까지감
# 논문마무리해야해서
# 걸릴수도있음
# 잘닦고
# 잘닦구
# 닦쳐
# 님들을
# 덥다고
# 존나대충찍음눈뜬게별로없엌
# 졸업축하하네
# 빛나심
# 미분당이라도
# 금방다모임
# 강남인데
# 번개팅구함
# 끝낫러
# 그건이따가
# 제외야임마
# 가까운놈
# 구하는겨
# 가까운거
# 강남에서가깝다고함
# 더가까움
# 판교에있는
# 물론프로도년과
# 통화는했지만
# 혜화감
# 혜화임
# 혜화로가
# 빨리말하삼
# 쒸벌럼아
# 왜구라쳐
# 못받
# 쉅몇시라고
# 강남주변이라며
# 되시길들
# 이제끝남
# 지금집가는중이라
# 집에서옷갈아입고아예올라가려햇지
# 시간이애매해질거같음
# 평촌이년아
# 강남에서버티다가
# 힘들어디질거같아서
# 아예올라가는간뭐냐
# 저녁몇시쉅
# 집있음
# 이제뺐나
# 너랑저녁먹고
# 은아만날
# 저녁가능
# 매우애매
# 5시조금넘어대흥갈듯
# 팬더뒤졋다
# 그때도가능
# 가죽벗겨드림
# 40분컷헤야함
# 헤어지는거면
# 식사는찬찬히하시고
# 뇌피셜때매
# 털렸네
# 개털거임
# 10대예약
# 귓방맹이
# 고생햇고
# 좀만더고생해라
# 내일갈수도
# 내일밥먹쟈
# 몇기
# 감쓰
# 오전만
# 옵치햇음
# baseluck이랑
# 잡혓다는데
# 비밀특훈중인가봄
# 개못햇나봄
# 딜러햇다는데
# 외길인생인가봄
# 딜려엿대
# 겜잘알인데
# 실력줄었나보네
# 겐지했으면
# 잘했을지도
# 절대아님
# 캐릭이라
# 나이라
# 이상하지않음
# 챠오챠오나
# 쳐맞을준비하고
# 승이더많음
# 한명만난그분
# 그분탱이나
# 연습좀하라그래
# 호르헌
# 3800이심
# 페이크파이로
# 3800
# 손진메
# 이메헌
# 수메
# 까먹엇음
# 유학간듯
# 잘사나
# 구마의
# 구마의식
# 띄워드림
# 프로젝터로
# 거부
# 닥칠께
# 다못햇음
# 그럴수잇음
# 그런판도
# 팀겜에서
# 못한거지머
# 이런판
# 저런판
# 잘할수는
# 건강검진에
# 섭취
# 빠는중의
# 순화버전
# 15개상자깡
# 3골드
# 4퍼플
# 중이구나
# 딜러배치
# 공격적
# 프로도곧
# 녹슬지
# 전에와
# 겜돌이라
# 절밥
# 거기멤버들
# 단합심이매우좋은듯
# 학교다닐맛나것네
# 리그도
# 전국약대
# 참여할듯
# 됫드라
# 벌레다됨
# 쉬심
# 가는주우웅
# 정자가는주우웅
# 계절로
# 봄이지
# 표현하면
# 벚꽃핌
# 아롱
# 웰빙이녀
# 운동가기귀찬군
# 운동가야지
# 프사바꿨네
# 필터빨
# 그냥그대로임
# 겨드랑이도
# 변하는중인데
# 뽑는겨
# 핀셋으로
# 못할긋
# 뒈질것같은데
# 밀고나면은
# 난다
# 그렇진않은데
# 빨리안자라서
# 맨들담
# 알아본다하지않았슴둥
# 포기하심
# 없다하심
# 쉽지않은게
# 사원
# 에스케이가서
# 워우예
# 프로도이돈데
# 담주금욜에
# 내방이없음
# 방빼
# 슈루루밤
# 퇴각쓰
# 방이없어도
# 쌍방울
# baseluck로
# 들어올거면
# 상승좀
# 삼계탕느낌인데
# 사리
# 100만원은
# 썻을듯
# 100그릇이면
# 100니까
# 200에
# 가까울것같은데
# 점장해도
# 취직예정
# 910월에
# 결혼많이하네
# 나오년
# 불러줭
# 우리다
# 고기많이먹어임마
# 잡아준데
# 저녁만먹고가냐
# 잡아드림
# 보드게임갖고옴
# 초호화
# 낫지않겠냐
# 멀티방이
# 모텔보당
# 갔던곳같은데
# 모텔가도
# 어택하러
# 개재밌겠다
# 프렌드들
# 어붼졀스
# 꿀잼이겟다
# 마리오하고싶다
# 밟으면서
# 짹즈
# 저택할라믄
# 뭔지는
# 사회자역할해줘야함
# 저게임
# 생각하믄돰
# 알피지
# 멀티방에
# 티비큰거있으니
# 피씨랑
# 모텔가더라도
# 3번출
# 금요르
# 촬영중
# 동아리애들이랑
# 요거를
# 하기로했거든
# 새벽이네
# 새벽노는건
# 이사하면서
# 정했네
# 존나멍청이임
# 가족사진찍음
# 동지가나타났다
# 두친구들의
# 의견을
# 낫지않냐
# 토일이
# 결혼준비때문에
# 제일바쁜가
# 지구에서
# 10월이라
# 제일바쁠듯
# 고모님댁
# 역시개빡세네
# 맣네
# 사드릴게요
# 저녁식사부터
# 함께하는거
# 숙박도
# 멀티룸
# 일요일도
# 청첩장볼때
# 신경쓰셈
# 친구들보니까
# 뒤지려고하더라
# 6개월내내
# 그것밖에안하던데
# 신경쓸게
# 점점생김
# 키보드로
# 아이폰인데
# 로지텍
# 키보드인데
# 꽂아두고
# 블루투스로
# 신통방통
# 만져야함
# 터치할라면
# 버튼으로
# 변경되는
# 변경하면
# 자동페어링
# 그거써봄
# 마우스는
# 마우스인식안됨
# 아이폰에서
# 같을텐데
# 아쉽다잉
# 기계식
# 맛이나네
# 타이핑하는
# 샀나보네
# 개꾸진
# 기본키보드였는데
# 내가썼던건
# 선물이라는데
# 수료
# 데스크톱보다
# 돌려줘야함
# 잘가요
# 터치로
# 혀흑
# 3세대부터
# 마우스도
# 지원됨
# ipadOS
# 갤럭시갈까
# 다음폰
# 손해인상황이라
# 애플을
# 포기하면
# 메뉴1개
# 통일임
# 강제되고
# 차돌양지차돌양지힘줄차돌양지힘줄인데
# 차돌양지를
# 해산물도
# 그건있음
# 재료다떨어지면
# 서울경기
# 지역으로
# 확장많이하면서
# 줄었음이제
# 안먹어도되니까
# 쾌적쓰
# 극복해냄
# 그전날
# 3시간하고감
# 오후에도
# 버닝🔥🔥
# 잠들면
# 광기의저택할거면
# 숙박이나을듯
# 긴데
# 그대들
# 있을란가
# 하실
# 멀티방가든가
# 들고가봄
# 걸리고
# 미션이
# 튜토리얼
# 두시간에서
# 세시간정도
# 난하고싶음
# 회사예비군중
# 킄킄
# 실상
# 결과발표다
# 엎드려빌어
# 1차는다시안보네
# 3유떳다
# 다섯과목중에
# 다시보믄
# 세과목만
# 3과목
# 3유면
# 다시보는거야
# 더고생하자
# 촉박했을텐데
# 마나따
# 다뤄줄게
# 토일요일에
# 오일담
# 고생해야지
# 그랴
# 모유굿
# 거유는
# 깁미깁미
# 무난하게가는데
# 여유있는것도
# 끝내기가능
# 원샷헌
# 순찰하는데
# 하나고
# 군인이
# 둘러싸고
# 사십명
# 커플을
# 넘어야끝남
# 끝나면뭐함
# 후르밤
# 순찰도
# 집갈건데
# 9시에닫음
# 부탄츄갈까
# 드실거라면
# kfc
# 보끈밥
# 부탄츄에
# 중국집보끈밥보다
# 2개뜸
# 합격각이군
# 개고생함
# 만족은못하는데
# 은아도나도
# 최악은피해서
# 결과나와서
# 네놈들은
# 주말에보자
# 후련은함
# 뒤쟛
# 너네와
# 만나기위해
# 이번주를
# 태워보마
# 어떤룸
# 너도고생많앗다
# 수고많았어
# 🙌🙌
# 볼수잇을듯
# 살빠진
# 385시간
# 개힘들다가
# 맨첨에는
# 하드코어튜브
# 버텨보자
# 견뎟음
# 견뎌내야해
# 체스
# 이꾸요잇
# 것들은
# 놀지않을까싶다
# 부르고싶은
# 한달정도는
# 놀자아아
# 고생많으셨네
# 왜불랴
# 이녀나
# 주말에보자나
# 어디서잠
# 개르가앙
# 포우천
# 갸고생이군
# 새집은
# 어디로구할그냐
# 학교근처예상
# 통학하는거
# 날리는듯
# 학교계속
# 편안
# 빨리잡아임마
# 시럽
# 셔럽
# 만들어볼게
# 하우스로
# 잘곳좀
# 방으로해
# 정해줘
# 파티룸으로
# 전문가잔슴
# 책상만
# 모텔같은곳에는
# 있을리가없으니
# 추진력담
# 리스펙
# 멀
# 넓은게
# 책상이
# 안경바꿈
# 파바
# 파마는
# 꼬펌
# 꼬는
# 매직이지
# 꼬불의
# 모이는거
# 결승보고
# 안늦을라나
# 내일아니고
# 주말이랑께
# 스케쥴말고없움
# 밤샘코딩해야돼서
# 예약하겠다
# 멀티방은
# 있는것같고
# 휴플레이
# 나은것같아
# 파티룸이
# 예약갈김
# 가본곳이
# 책상넓은곳이
# 게스트하우스에서
# 잘까
# 게스트하우스
# 짐은
# 왕십리에서
# 일산까지
# 자고오셈
# 자고오는것도
# 개오반뎈
# 파티룸에서
# 엘시케이
# 출발하려함쓰
# 챙겨갈게
# 저택이라고
# 보드겜인데
# 챙겨갈까
# 블러프정도로
# 테포마에
# 밀리지않음
# 무거움
# 러닝타임이
# 보드겜만
# 마리오가
# 러닝타임도
# 개꿀잼인데
# 바르긴함
# 갔던곳
# 밤만
# 거기밖에없거든
# 4인방
# 전화해봄
# 개씹깡패임
# 밟는다
# 먼저한다
# 꼭한다
# 던져드림
# 귀여워해줘야겠구먼
# 기상해서
# 내집
# 수르워언
# 장안구
# 신혼집도
# 정자들이네
# 난자동으로
# 남자동
# 인천시
# 암사
# 존나재밌겠다
# 나냐
# 양아치녀석들
# 못괴롭힘
# 옵치정도하고
# 조루기다리다가
# 광기의저택
# 그담
# 광기
# 못깔듯
# 맞아좀
# 물어봐봄
# 3인실은
# 책상
# 56시쯤이니
# 다시돌아오면
# 태우자
# 알겟군
# 아늑하였다
# 조루네가
# 더좋은곳으로
# 잡을게
# 돈많이벌어서
# 인도하마
# 다메요
# 수고하시게나
# 헤브어스윗드림
# 분당도착
# 날씨핵조으네
# 그래봐짜
# 집구석임
# 너머
# 반차내고싶구만
# 산을보니
# 결혼식장서
# 보겠어
# 소개해준다며
# 청첩장줄때
# 원애
# 마지맏에
# 요즘이
# 드라이브마스터
# 출신이니
# 비싼차
# 기사로
# 얻어타겠음
# 인천공항이면
# 둘러보기
# 타기전
# 뱅기표를
# 잡아둬야할듯
# 닫기도
# 면세점
# 뱅기라
# 무난끄
# 빡시게하고프다면
# 쇼핑을
# 빨리하고
# 식정리를
# 미분당임
# 정자역에
# tower
# 금결원과
# 사이쯤
# 먹어보는건가
# 미분당을
# 얼마안됨
# 파리크로와상
# 111호
# 158
# 분당구
# 성남시
# 정자일로
# 여기있음
# 고기양보고
# 라이언사진
# 조금주면
# 금결원쪽은
# 많이주겠지
# 곳이구만
# 팔린곳이
# 나랑가는게
# 이득이긴하지만
# 프로도신이다
# 쨱쯔헌
# 튜브프로도
# 수프로도
# 미국갔다함
# 원정
# 연락두절됐다던데
# 5분거리에도
# 은아네
# 미분당생김
# 돌아가는것도
# 시절로
# 10분거리에도
# 미분당생긴
# 삼산동에도있음
# 문어발확장
# 신촌이갑
# 슈바가
# 뿌릴예정
# 적절함
# 어쩜
# 나올수가있지
# 시절인가
# 말출일걸
# 전역후던가
# 말출아님
# 알바끝나서
# 복귀하려고
# 로맨틱하넹
# 남친이야
# 영풍문고에서
# 읽고잇게
# 무슨알바하심
# 일일알바
# 알바하는
# 책자
# 일일알바중
# 코딩알바
# 간다고햇지
# 스퍼담
# 강한남좌
# 스트롱
# 거기있음
# 언제언제
# 버스타서
# 5시쯤
# 도착예상
# 쌉임
# 쑥임
# 개쌉임
# 사주려고
# 알바중인데
# 부스열고
# 알바하는데
# 야외에서
# 5시면
# 할게없어서
# 다녀와도됨편하게
# 5시만나서
# 6시반정도에
# 8시8시반까지
# 여유로움
# 전화때릴게
# 61번
# 명동이야
# 다왓네
# 지하철탐
# 암습하러감
# 가잇을게
# 지하철역에
# 왕십리인가
# 대박인걸
# 만나는건가
# 엔터식스에서
# 학교쪽
# 느낌나는곳
# 판자촌
# 골라드셔도
# 들가서
# 곱창골목쪽은
# 비싸당
# 소곱창들이
# 왕십리역
# 맛임
# 그맛이라
# 프랜차이즈는
# 드실라면
# 비프랜차이즈를
# 후진구석으로
# 책읽는중
# 나오셈
# 왜신촌이야
# 바꿔치기인가
# 출구에있음
# 가는길인데
# 나눔하고
# 왜여깃지
# 바꿔치기
# 아니무엇보다
# 췁췁
# 5번출구
# 61출구
# 거기있는데
# 왜못봤냐
# 보이는곳
# 롯데리아
# 예열
# 녀서쿠들
# 사람이없어
# 사람이없어서
# 포천에서뭐하냐
# Ep16
# 갈꺼임
# 뭐뭐잇음
# 많이잇으면
# 안들고가고
# 접때했던
# 러브레터도
# 매우아쉽쿤
# 팬더가와야
# 56시즈음될긋
# 뭐뭐있는지
# 신청해둠
# 6시까진
# 너님들
# 못온단거군
# 후하
# 집옴스
# 이쵸케
# 밤인가
# 향수씀
# 달리아
# 디바인
# Of
# 지방시
# 썼어야하는데
# 시향할수있는
# 향수통
# 여친에게허락받고올걸
# edition이라
# 공항에서만
# 시향이
# 안쓰는데
# 안쓴다는게
# 안가져서
# 기숙사밥
# 도우온까스와
# 부대찌개네
# 어묵탕
# 킹까스
# 적은걸
# 적게품
# 돈가스만
# 배식해주고
# 자율
# 오뎅탕이면
# 미르분다앙도
# 드실거면
# 정통집
# 쥑이더라
# 드삼쓰
# 영혼보내기만
# 간호좀
# 괜찮으신가
# 괜찮으시긴함
# 나가는건
# 밤새러
# 외박하려다가
# 티비보는중
# 긴막대기
# 길쭉
# 답하삼
# 보드게임들고가
# 매우커서
# 크기가
# 큰결심해야함
# 보드겜
# 어떤건지를
# 갓겜이긴함
# 들고간다는거
# 운빨이긴하지
# 일등할지
# 카드겜
# 좋아햇던
# 전애인같은거임
# 정정하시드라
# 뵈었음
# 주말긱사라면
# 충분하비
# 따르따르소스
# 육시까지
# 예상도착시간은
# 못들고
# 출발하여
# 수락산역
# 운동조금하고
# 도착이래
# 노원역이면어디여
# 구로디지털임
# 검색해임뫄
# 구디단이군
# 동대문에서
# 오는거군
# 호허어언
# 뭐부르나
# 코노에선
# 고음노래
# 별로안조아해서
# 잔잔하니
# 적당한걸로다가
# 코노야로
# 2출에잇으마
# 빠가사리
# 박고잇어
# 4가야
# 어여오삼
# 앉을데가없네
# 오는거니
# 앉아잇다
# 도착쓰
# 밑에있어더우니까
# 3번출구에서부터
# 민소매담
# 매끈담
# 으냉골
# 들어가시오
# 얘기좀하려다
# 타니
# 은아만나고
# 은아만나러가네
# 타는거
# 대흥역감
# 합정지남
# 가까우니께
# 왓엉
# 귀가해서
# 쉽시다
# 밤이어따
# 점심들은
# 해산
# 고속버스
# 이시간대는
# 벟써
# 갸빠르네
# 고생들
# 많으셨다
# 살거사고
# 그때봅시다
# 씨야아
# 어디로떠냐냐
# 이따갈듯
# 핵피곤해서
# 룸메됨
# 롤체같이
# 해준이가갑
# 비등한듯
# 죠류는
# 큐트헌
# 연습좀해와
# 절밥들
# 초식
# 계속잠
# 힘이없음
# 롤토할듯
# 정력감소헌
# 짹쯔말고
# 그거빽
# 짹쯔마스터네
# 시킬라믄
# 와야것다
# 체험
# 진짜고수는
# 대디인걸
# 몇인플인디
# 다섯명까지
# 네명이
# 베스트임
# 네명하고
# 다섯명
# 확다름
# 괴물들이
# 노답됨
# 많아질수록
# 괴물프로도
# 괴물튜브
# 괴물어피치
# 거물어피치
# 거유어피치
# 할수록
# 대단하는걸
# Gang
# 예견된
# 강유
# 알바행
# 물어보길해
# 뒈지겠는데
# 연휴내내
# 추석연휴
# 김시낚씨가
# 핵피고르고른
# 작작해
# 매일하면
# 삭는다
# 시험끝났다고
# 아껴써
# 30대야
# 강남옴
# 이대서울병원
# 새삥이라
# 쌔삥
# 떡대보고
# 뽑는지
# 우락부락함
# 경호원들
# 어피치들
# 데스크에
# 서있음
# 인포
# 꿈틀쓰
# 셔츠안에
# 친절해
# 청년경찰들임
# 난동부리면
# 병원안에서
# 청년경찰
# 경찰임
# 알려주던데
# 진짜경찰은
# 부르드라
# 청년경찰이라
# 청원경찰아님
# 근육들이
# 프로도이급이었음
# 브로들
# 무엇이냐
# 정령섬
# 테포마보다
# 모두필요
# 금욕헌이라
# 다등
# 아직미정
# 청첩장데이이
# 인천서
# 잘먹고다녀임마
# 그런사이됨
# 내가공격
# 홍대간다
# 평촌서
# 맛잇게따
# 부탄츄릅
# 스퍼맨시즌3
# 토요웹툰
# 스퍼맨
# 3라니
# 스케일이다름
# 몇년된듯
# 몇달에한번씩
# 이건개지린다
# 대기화면급
# 좌절중
# 청첩장데이
# 가능하신가
# 연휴중
# 모바일일세
# 토욜빼곤갠찬
# 압박감에
# 없어하는듯
# 구경이라도
# 시켜주겠음
# 내도록
# 밥값은
# 하겠소
# 일정봄
# 안될텐데
# 빠듯
# 빡셈스
# 안되는분들은
# 들어갔다는
# 외출이
# 힘들다는
# 9월말부터임
# 고시반출첵은
# 청첩장받으갈수잇음
# 어려운가
# 기다려봐야할듯
# 부산을
# 괜찮을거같음
# 부산만
# 일하는거아님
# 건내받는거
# 받을때
# 데려와서
# 뭐햌
# 오라하셈
# 안친하지않음
# 어피치랑은
# 옵치해야
# 우리집에서는
# 잔사이임
# 난봉꾼담
# 그러겟다고
# 햇갈리게함
# 감사하다는
# JOIN
# 해준도
# 사회봄
# 난봉
# 난봉은
# 감당가능
# 라이언아님
# 사회발표하면
# 되시는거
# 모엿으니
# 신촌쪽에서
# 포천가야하니
# 구함니다
# 그날봐야암
# 서늘하구만
# 비때매
# 시원시원
# 시원하구만
# 거어어어업나
# 탈출각
# 도라이들임
# 아이폰왜쓰냐
# 터프헌
# 회의감듬
# 아이폰의길을
# 포기할수없는게
# 만들어온다
# 승전보
# 옶구만
# 추천해쥬시게나
# 고백못함
# 우울하다
# 약먹었따
# 들어햇으면
# 안사귀면
# 맘먹은거
# 코딩할거
# 마감인게
# 갑자기는
# 미즈컨테이너도
# 괜찮앗는데
# 어썸로즈
# 나눠주는
# 분위기로
# 좋을지
# 감사하게받을
# 육개장집에서
# 219
# 406
# ·
# 돈돈정
# 스키야키와
# 잔다리로6길
# 홍대점
# 화로구이가
# 가격대
# 가정식도
# 찾아봣는데
# 국수집
# 모엿을때
# 제주국수
# 고민할게
# 소울푸드가
# 있는걸
# 다깔비
# 육인분이요
# 계신데
# 형수님도
# 아무도모르는
# 여친되신데
# 고배쿠
# 하긴뭘해이년
# 모이는거임
# 56시
# Closed
# 보자❤️
# 추석들
# 되게들
# 모이는게
# 어떤가
# 일찍모일수록
# 수업있고
# 형수님이라
# 3년만에
# 자리정리함
# 마음가짐으로
# 출바알
# 가있는데
# 올수도
# 결혼식날
# 못오시면
# 우리끼린데
# 중국집도
# 오시는줄
# 유가네도
# 유르
# 호응대에
# 소리질러어어
# 호허어어어어어어언
# 호오오오오허어어어언
# 뒤져어어어어
# 쥭고싶은건가
# 카와이녀석들
# 칭찬하던곳
# 대존맛임
# 친정가
# 생각하시게
# 러브레터
# 챙겨와헌
# 러브젤도
# 챙겨오고
# 올라가볼게
# 벼연하지
# 세월지나도오
# 아아아않아
# 짜이찌엔임
# 딩연
# 5시보다
# 이전에오는사람도
# 오오키
# 중식코스
# 좋으신가
# 1번빼고
# 투표만들게
# 됨들
# 뷔페의
# 생각하시면
# 중식임
# 안좋네
# 뷔페라서
# 구랻
# 하나뺌
# 괜찮은0
# 사는거임
# 들텐디
# 준비때매
# 뿜빠이
# 고르시게
# 안오시나
# 넘어와서
# 뻗으심
# 일산이구나
# 친정집이
# 청첩장에
# 여친분도
# 일산이라
# 정발산
# 웨돔
# 라페
# 잘알이구만
# 웨돔에
# 자연초밥
# 정발산은
# 처음갔을때
# 많이갔지
# 첫여친
# 걸으면
# 웨돔에서
# 호수공원가능
# 깊구만
# 도착임다
# 버스정류장임
# 땀내진동
# 동작역
# 당산으로갈랴
# 5시조금넘을득
# 당산갓다가
# 홍대도착
# 어딧을거야
# 띄발
# 아현임
# 앉아잇음
# 플랫폼에
# 03Sep
# 가본분
# 오션월드
# 대명
# 초대되엇는데
# 톡방에
# 뭐뭐인지
# 준비할게
# 거랑
# 동일하게
# 생각혀먼
# 스키장가는
# 빌리면됨
# 수영복도
# 3만원에
# 입장권
# 올라오라굿
# 가져갈거없음
# 입을땨
# 됬건듯
# 물에젖어도
# 안내려가는걸로
# 기구마다
# 민망쓰
# 가깜
# 상의탈의하고
# 타야되는거있
# Hm
# 올라오삼들
# Hm이
# 출구인가
# 출구걸
# 팔번
# HM이
# 먼제
# 안정했는데
# 어디갈지
# 결과보니
# 뷔페가
# 로헌신은
# 싶은지만
# 투표안하냐
# 애슈르리
# 뒈질래
# 다른뷔페
# 애슐리말고
# 의하면
# 정보에
# 애슐리가
# 피지몰
# W라는대
# 별론곳이
# 어누
# 갠찬듬데
# 한식
# 나버리고골라
# 난암거나노상관
# 로운임
# 출구쪽
# 버릴거야
# 자연별곡으로와
# 73번
# 가시게에
# 매우베리추타
# 성숙해진듯
# 어피치쓰
# 들어감다
# 먹구
# 배든든히
# 뒤질때까지
# 배볼록이됨
# 삼겹살데이만큼은
# 배든든하구먼
# 87키로된듯
# 개뛰엇다
# 런황
# 3006탐
# 잠실광역센터
# 45분이지
# 포천구리
# 3일날
# 개통해서
# 고속도로는
# 16일에
# 잠실서
# 화곡보다
# 신촌보다도
# 3006번이
# 경로로
# 노선
# 개통하고
# 돌아오기
# 폐선
# 샤워해야지
# 편하게싸
# 만남의장소로
# 오래걸렸네
# 집에가는중
# 조루고생이네
# 집구할수있기를
# 크쇼
# 쾌변헌
# 뿌뿌직
# 매우쌈
# 매우시원
# 싸버린듯
# 이거배움
# 메세지도
# 적혀잇음
# 기억나네
# 물어보던게
# 졉밥들
# 코딩배우니
# 돈내
# 과외급아니고
# 생기초지
# 그간봐온정으로
# 대답이나해
# 뭐배우냐
# 감가상각비
# 매출원가
# 과제하나씩
# 프로도이가별로임
# 싸버려
# 겨수님한테
# 그친구한테맡긴다고
# 씨파하는
# 에이쁠내노라그래
# 친구있어서
# 회계세무는
# 메세지입니다
# 메시지입니다
# 소세지입니다
# 삭제헌
# 호런아
# 개요
# 설명하고
# 접때보니
# 파이썬기초
# 전문분야임
# 주시게
# 청첩장을
# 10월전에
# 붓싼
# 10월초에가야할듯
# 알겠소
# 고백데이래
# 화성연쇄살인사건
# 용의자
# 잡혔다함
# 공소시효
# 처벌은
# 잡아내서
# 정애결혼식가시는분
# 5층
# 결혼식에
# 공영호
# 다목적홀
# 서초사옥
# 청첩장보기
# 오오키이
# 결혼식갔자너
# 같이하자고해놓고쌩깜
# 골드찍엇던디
# 미안하넹
# 보드게임함
# 스플랜도
# 신인데
# 얼마안남았다
# gkfr
# 보드게임임데
# 디펜스같은
# 운빨이
# 모바일게임도
# 디펜스게임함
# 삭제는
# 안했지만
# 냥코대전쟁
# 매우좋아할것같이
# 롤체인듯
# 롤체도
# 개명작
# 달타냥이
# 2주됨
# 돈을지를게아니라면
# 스테이지별
# 지르는중
# 뽕맛
# 얼마나함
# 갑인
# 모바일게임은
# 쩐주가
# 하고싶긴한데
# 하지않는다
# 무료인
# 안한주제에
# 한척한거
# 롤토가
# 겜이나해
# 롤토연습좀
# 노상대
# 라이언예외
# 실버이하
# 은헌
# 밀러간다
# 머리밀고
# 빡공하려나보네
# 임즈머리민단얘기엿음
# 많아져서
# 숯이
# 쳐줘야함
# 정글헌도
# 쳐줘야
# 밀어줘
# 고백이나하삼
# 그선택을
# 수도승의
# 세드스
# 놀쟈
# 시간맞춰야지
# 2시이전빼고
# 결혼식이고
# 아침과외
# 고시반출첵땜시
# 못갈거같고
# 유현이결혼식은
# 둘즁에
# 통보함
# 픽스하면
# 들어보겠음
# 주말있음
# 데이트데이인가
# 103
# 북한산
# 토욜날은
# 개천절
# 데이트할수도
# 가까워져서
# 바빠지면
# 미리해두셈
# 채널을
# 진지채널
# 심리학
# 하시는
# 눌럿고
# 여유로울때
# 20대후반부터
# 벌었다고
# 어그로끌길래
# 억단위로
# 너네되는시간
# 토요일안됨
# 아이즈원
# 정원영
# 얘몇살이냐
# 17인가
# 그럴겅
# 띠동갑인가
# 이녀석이
# 어린여자아이
# 팬더취향이
# 삼촌이
# 아낀다
# 키큼
# 지린다고만
# 못잇을거같아
# 하는식
# 가을이니
# 부탄츄의
# 떽쯔
# 밴쯔
# 학교간다이녀나
# 지네같은
# 다음학기
# 복학이냐
# 가을인가
# 데이트하러가는듯
# 지네헌
# 막학기
# 고시반출첵하러간다
# 지네같은녀석둘아
# 학교다니는군
# 꼬꼬헌인가
# 꼬꼬추헌
# 꼬무룩헌
# 12시반쯤
# 신촌어떰
# 계획좀
# 뉴하우스
# 입점
# 안할수도있음
# 올해안에
# 벌수있다는
# 보장이되어야
# 대출받아서
# 들어갈텐데
# 보장이안돼서
# 얻어야해서
# 아파트가
# 낮을뿐
# 보증금이
# 기본적으로는
# 인강촬영중
# 강의인가
# 패스트캠퍼스에서
# 인터뷰도
# 10월말에
# 유튜브에올라감
# 친구들❤️
# 반이지
# 못먹을거같은디
# 가져
# 그런얘기가
# 세상돌아가는일을
# 검찰개혁
# 이거구나
# 조국때문인듯
# 도착하겟다
# 시흔초흔에
# 땡기는군
# 몸상태가
# 뻐킹임
# 어제회식끝나고와서
# 점심먼저먹고잇게들
# 가봐야함
# 초르밥도
# 알콜헌
# 점심먼저하고
# 행선지만통보하삼
# 7분듸에
# 역가는중
# 자나보네
# 연습하러가자
# 궈궈
# 준다했음
# 혜원씨가
# 직진하다보면
# 스벅지나서
# 들어가잇음
# 스벅이랴
# 글로갈게
# 롤체
# 안들어가야지
# Stop
# 으디야이년들아
# 홀덤
# 몇개생겼는데
# 포커펍
# 25000원
# 이렇게하고
# 입장
# 칩
# 찍는거임
# 사행성은아님
# 같은느낌
# 당구장
# 세븐이랑
# 좀다름
# 홀덤은
# 에이스타
# 추천해줬어
# 있엇구만
# 내년넘어가면
# 레알이네
# 보내줄
# 미래관
# 택배실
# 해룡로
# 굿귯
# 리마인드좀
# 이틀쯤
# 에어캡
# 하긴했는데
# 경고함
# 박살날수도
# 개땡큐
# 작은거지만
# 들어했으면
# 감사해
# 잘어울릴것같아서
# 배송조회
# 받았다고
# 연락왓는데
# 택배실에
# 쉅중이라
# 받자마자
# 진출해서
# 생중계
# 전약협이라고
# 구경각인가
# 잡아줄지
# 3400점
# 맥크리잇더라
# 성대인데
# 경기할듯
# 욕해도
# 쌉가능
# 휴일이었네
# 해보실
# 개천절에
# 준비하긴해야하지만
# 모인다면
# 시간투자가능
# 고난도가되긴함
# 헬스장이다
# 이제학교감
# 통보
# 운동하냐
# 살빼려면
# 장소시간
# 홍대것지머
# 아니되어요
# 다녀와라
# 근데그
# 너가갖고오는거냐설마
# 가야하는거아님
# 광기하려면
# 넓은곳이
# 개넓은데
# 연귀실
# 103에
# 박사형이
# 허락해주심
# 809
# 가구는
# 망쳐놓을예정
# 공휴일에
# 때려죽여도
# 저렴한데
# dyson
# 청소기나
# 안필요함
# 연구실구석에똥싸고나올께
# 이정도어떰
# 참아도
# 기대하고있을게
# 저만큼
# 1일화
# 29기
# 2경기
# 2선승제
# 2일수
# 3선승제
# 3전
# 4위전
# 4팀의
# 5일토
# 6일일
# dream
# ✔문의
# ⭐
# 경기일정
# 김종면
# 마채민
# 막강한
# 송출됩니다
# 시작됩니다
# 영남대
# 전국으로
# 전쟁이
# 중계가
# 중앙운영위원회
# 해설자
# 👉
# 졋어
# 1경기는
# ❗옵치
# 계정에서
# 부득이한
# 사정으로
# 진행하겠습니다
# 높긴하드만
# 파라땃네
# 즐거웠음되었다
# 궁쓴파라
# 솬하이라이트
# 수면시킴
# 최플담
# 최플은
# 최고의플레이
# 기모치한녀섣
# 연구실몇시까지가야함
# 일찍이면
# 좋긴함스
# 너네오고싶을때
# 11시까진감
# 맘마도
# 재밌겠구만
# 시골감
# 그오오
# 고맙당
# 들어있는거
# 서비스엿나
# 훼이크다
# 상자만
# 향수지
# 고단수네
# 시켜먹어도
# 개천절이
# 주중이라
# 근처에도
# 대부분열거야
# 중식같은거
# 개꿀1
# 피해야겠네
# 안먹을래
# 조커
# 음울함
# 개봉됨
# 그영화
# 추르처언
# 찝찝함
# 나눌
# 이야기를
# 연락안되겠네
# 분노를
# 영화보고난
# 표출
# 무비라기보단
# 히어로
# 문제의식이
# 영화이기도
# 같이봐야지
# 샹룐아
# 조질라그랫는디
# 조커보고
# 좆커
# 이거줌
# 포스터랑
# 연기개잘한다던데
# 컷인데
# 잘놀고있으면
# 다녀오겠음
# 언제쯤갈예정
# 2인플도
# 가능하니
# 4시쯤부터는
# 일해야할듯
# 강의촬영인데
# 강의자료만들어야함
# 갠찬스
# 맛난거먹읍세
# 10시쯤만나서
# 대흥으로가보겠다
# 9시반에
# 스벅가서
# 코코보고
# 9월까지
# 한다고했는데
# 확인해봐야겠다
# 눈눈은
# 세컨인가봄
# 아차싶겠는걸
# 아차들아
# 똥지린다
# 지리긴함
# 가져갈깦
# 팬더가판단하삼
# 팀웍이중요
# 인천거
# 출퇴근중
# 11시에운동끝나고
# 버스개밀림
# 올수잇겟냐
# 덜자면됨
# 10시이후로오는인간
# 뺨따구10대
# 씻을준비중
# 11시에보는거어떰
# 바로나갈게
# 출발했으면
# 아니가
# 10시반으로
# 타협보자
# 얼리버드네
# 열시반은
# 갈기세인데
# 열시면
# 쭈쭈바야
# 아홉시반까지
# 오라메
# 스벅으로
# 마지막놈
# 두시간잤다
# 대흥스벅이냐
# 두번이상은
# 불꼬담
# 물론가는중
# 근육통회복이
# 괄약근육통
# 슈바르련이
# 눈좀붙여
# 차안에서
# 예습이나해가야지
# 솔라리복잡하네
# 이십분고
# 자고가는중
# 불같은
# 오자마자자는거아녀
# 3번째부터는
# 노력해보마
# 공덕
# 주무시고계시죠
# 이제동작
# 망할놈이
# 뺨씻고간다
# 궁둥이씻고와라
# 동작헌
# 노시게들
# 개꾸르잼인디
# 쐉욕먹고옴
# 트롤짓해서
# 돌아가눈중
# 내가쏨
# 부자네
# 개꿀잼이었다
# 연구실대여
# 임즈껴서
# 와야된다
# 3대1로
# 솬이끼면
# 욕먹을수있음
# 부셔질듯
# 화곡으로간다
# 꾸덕
# 해피타임튜브
# 뭔게임임
# 발릴거같은디
# 그건그럼
# 똥퍼먹음
# 트롤링함
# 팀킬함
# 개인전
# 모래주머니였음
# 브레인인줄
# 협력게임임
# 인간들을
# 트롤햇나보군
# 회수를
# 없다함
# 솬담주에날잡자
# 삽질때매
# 즐기느라
# 하드코어로
# 작작하고왈
# 뒤졋다샹년이
# 너의고향
# 거기여
# 추억의스팟
# 개고생이네
# G스팟
# 5시간동안
# 즐거운대화
# 12시간수면예정
# 오늘집가면
# 분당가야함
# 핵스케쥴아님
# 생활이가능하다니
# 잠없어도
# 잠은안자도
# 살수없다
# 없이는
# 드가자마자
# 미틴놈아
# 빨리자야겟군
# 아침출첵이라
# 어서주무삼
# 췍스
# 출근철
# 짜
# 추천으로
# 즐겼던
# 뭐였드라
# 뭐시기던가
# 스카이프
# 스와이프
# 벽돌깨기
# 부수는거임
# 푸슛헌
# 축축헌
# 인스타털린것같은데
# 계정삭제함
# 한글날
# 강의자료만들기
# 몰아서해놔봐
# 뀨뀨뀨
# 잘찍음
# 츕
# 딱치고
# 정령섬하러와
# 넷이하면
# 토나올듯
# 워크맨에도
# 아만헌
# 더듬
# 호로헌
# 만지게
# 찌찌뜯어버린다슈발것아
# 은아와함께지
# 나랑해
# 한끼는
# 쮸쭈밤바야
# 먹어야됨
# 쮸밤바색꺄
# 여친이랑가는거아녀
# 말인디
# 샹노무쉐캬
# 공부나해야지
# 곧셤이니
# 탈출할겨
# 호다닥
# 적을듯
# 깔려죽지말고
# 럴럴함
# 어딘디
# 세택인가
# 학여울역에
# 사야할만한
# 입금해주시면
# 생일축하혀
# 뭐할수잇는
# 챙겨주지않나
# 잘머글께
# 롯데시네마가는게함정
# 빨라알려줘
# 우리역할분담이나
# 부탁드리랴고함
# 식사수량
# 추가사항
# 그게머하는거임
# 담당자랑
# 식사먹은수량보다
# 안했다는거
# 호텔에서
# 확인해주는거임
# 당일에
# 식장에서
# 연락함
# 먹던가
# 일찍먹던가
# 뒈져라
# 사다줄게
# 상세하개
# 쓋임
# 홀리뻐큉
# 유캔두잇헌
# 살아나갈수있다
# 소장각
# 생일잘보냄
# 앓아누웠을듯
# 불꼬같은
# 불타서
# 노릇노릇
# 마찰열
# 잘보냈냐
# 다모이겟구만
# 이제다음주면
# 일하러
# 검은머리파뿌리썰
# 내가다먹는다
# 분식해서
# 식권수량
# 닥쵹
# 서비스로받음
# 개힘들닼
# 해야할것이
# 내가햇엇던
# 사기당한줄알앗음
# 4개중엔
# 내가써본
# 지낫을때
# 공주교대분이
# 연락왓엇음
# 매일매일꾸준히
# 감감무소식
# OK를
# 보낸결과
# 받아본적없음
# 먼저왔다는거지
# 접을거야
# 글램에서
# 글램이랑
# 틴더랑
# 호감보내서
# 제일낫다던데
# 스와이프는
# 만나고왓엇음
# 무용학고
# 과금
# 존나쌤
# 들은것같은데
# 투명하게
# 말햇엇음
# 개깝친
# 맞는것같은데
# 난리친거
# 커피빈간거
# 스벅인가
# 강남하면
# 다틀려서
# MIXXO지
# 아닌거같다는
# 개웃겼는데
# 머리정갈한거
# 젊어지는중
# 축핳
# 내가쓴건데
# 내가쓴게아닌
# 복잡한상
# 상이군
# 석사논문을
# 논문쓰고싶다길래
# 학부연구생들
# 떠먹여주고
# 이름안넣었는데
# 저자에
# 필요없는
# 상받음
# 내가받음
# 대리수상으로
# 사정때매
# 쓴애들이
# 사정
# 결혼해야하나
# 12년내로
# 생각있냐고
# 소개에
# 적는거
# 25살인데
# 결혼생각을
# 결혼어떻게햌
# 당연하짘이제
# 박사하는데
# 슈퍼OK
# 기승전짹
# 하트순삭이네
# 돈개많이드는
# 어플이군
# 적당히해야겠다
# 많이듦
# 녹네
# 360개인가
# 6개남음
# 그만큼에
# 76000원인가
# 그쯤했던듯
# 54달러인가해서
# 와아
# 있길
# 폭리네
# 버티는삶
# 누르느라
# 이기능
# 저기능
# 그냥하셈
# 생각바꼇다고하삼
# 새퀴
# 혼이담긴
# 날라가붕게
# 기대되는구만
# 전담
# 타짜들
# 회계사임

# %%
# 사람이 이해할 수 있는 형태로 코퍼스 사전 재구성 해보기 (term-frequency)
[[(dictionary[id], freq) for id, freq in cp] for cp in corpus]
# Out:
# [[('갓창정인지', 1.0), ('알게된다', 1.0), ('왜', 1.0), ('이거보면', 1.0)],
#  [('창정헌', 1.0)],
#  [('내일부터', 1.0), ('라이언은', 1.0), ('연구실', 1.0), ('출근', 1.0)],
#  [('아님', 1.0), ('파티', 1.0), ('하는거', 1.0)],
#  [('헬파티', 1.0)],
#  [('헬파이어', 1.0)],
#  [('파이어에그', 1.0)],
#  [('리마리오', 1.0)],
#  [('프로도', 1.0)],
#  [('예스', 1.0)],
#  [('호우', 1.0)],
#  [('팟팟헌', 1.0)],
#  [('리마리오헌', 1.0)],
#  [('느끼헌', 1.0)],
#  [('안그래도', 1.0)],
#  [('오늘힘듬', 1.0)],
#  [('대단', 1.0)],
#  [('허리', 1.0)],
#  [('괘안', 1.0)],
#  [('이정도는가뿐', 1.0)],
#  [('즐거운', 1.0), ('첫츌근', 1.0)],
#  [('야옹', 1.0)],
#  [('돈많이', 1.0), ('벌어와유', 1.0)],
#  [('보고싶다', 1.0), ('프로도신', 1.0)],
#  [('그래도', 1.0), ('다행인듯', 1.0), ('얼굴봐서', 1.0), ('저번에', 1.0)],
#  [('되었다', 1.0), ('만날때가', 1.0), ('이제', 1.0), ('튜브를', 1.0)],
#  [('기대하라', 1.0), ('다음주', 1.0)],
#  [('굿굿', 1.0)],
#  [('2박3일', 1.0), ('곤지암으로', 1.0), ('담주에', 1.0), ('스키타러감', 1.0)],
#  [('데려가삼', 1.0), ('스키담', 1.0)],
#  [('하앜', 1.0)],
#  [('라이언', 1.0), ('여기', 1.0)],
#  [('좋음', 1.0)],
#  [('너의', 1.0), ('떠나버린', 1.0), ('세컨과', 1.0), ('졸업하고', 1.0)],
#  [('닮은', 1.0), ('아이', 1.0), ('잇음', 1.0)],
#  [('호우', 1.0)],
#  [('목소리도', 1.0), ('비슷', 1.0), ('심지어', 1.0)],
#  [('다름', 1.0), ('이름이', 1.0), ('하지만', 1.0)],
#  [('연수아냐', 1.0)],
#  [('신수인씨', 1.0)],
#  [('신수인', 1.0)],
#  [('10학번이랑', 1.0), ('이름똑같넼', 1.0)],
#  [('이름이', 1.0)],
#  [('걔는', 1.0), ('남자', 1.0), ('물론', 1.0)],
#  [('Ma', 1.0)],
#  [('굿', 1.0)],
#  [('금결원', 1.0), ('많음', 1.0), ('이쁜사람', 1.0)],
#  [('교육받는중이려나', 1.0)],
#  [('4명임', 1.0), ('여자', 1.0)],
#  [('몇명', 1.0), ('입사', 1.0)],
#  [('25', 1.0)],
#  [('호우', 1.0), ('1', 1.0), ('6분의', 1.0)],
#  [('간택될수있을것인가', 1.0), ('과연', 1.0), ('어피치는', 1.0)],
#  [('어피치는', 1.0), ('되야함', 1.0), ('미스코리아는', 1.0)],
#  [('지노우', 1.0)],
#  [('왜', 1.0), ('없어짐', 1.0), ('팬더', 1.0)],
#  [('이제', 1.0), ('무지', 1.0), ('팬더버림', 1.0)],
#  [('변하니', 1.0), ('사랑이', 1.0), ('어떻게', 1.0)],
#  [('무지', 1.0), ('바람둥이임', 1.0)],
#  [('나픈아이', 1.0), ('저런', 1.0)],
#  [('여자', 1.0), ('벌써', 1.0), ('여럿울림', 1.0)],
#  [('먹튀', 1.0)],
#  [('당연', 1.0)],
#  [('그건', 1.0), ('기본임', 1.0)],
#  [('이런마', 1.0)],
#  [('노답', 1.0), ('지하철', 1.0)],
#  [('퇴근', 1.0)],
#  [('모습으로', 1.0), ('복귀예정', 1.0), ('새로운', 1.0), ('조만간', 1.0)],
#  [('팬더', 1.0),
#   ('모으는줄', 1.0),
#   ('발견해서', 1.0),
#   ('사려고', 1.0),
#   ('엄청난', 1.0),
#   ('쿠션을', 1.0),
#   ('푼돈', 1.0)],
#  [('중', 1.0)],
#  [('최악', 1.0)],
#  [('2호선', 1.0), ('과소평가한듯', 1.0), ('그동안', 1.0), ('내가', 1.0)],
#  [('출근', 1.0),
#   ('2호선은', 1.0),
#   ('그자체임', 1.0),
#   ('시간대의', 1.0),
#   ('이프로도대마왕', 1.0),
#   ('진정한', 1.0)],
#  [('2호선은', 1.0), ('그정도', 1.0), ('되지', 1.0)],
#  [('기운내삼', 1.0)],
#  [('2호선은', 1.0), ('출근시간의', 1.0)],
#  [('지옥그자체지', 1.0)],
#  [('3개보내고', 1.0), ('4번째탐', 1.0)],
#  [('2명을', 1.0), ('보며', 1.0), ('힘내삼', 1.0)],
#  [('라이언', 1.0), ('끝나', 1.0), ('언제', 1.0), ('튜브', 1.0)],
#  [('아심', 1.0)],
#  [('다음주', 1.0)],
#  [('12일넘어서', 1.0), ('1월', 1.0), ('만나자고함', 1.0)],
#  [('데리러가는일은', 1.0), ('없길', 1.0), ('한강으로', 1.0)],
#  [('지노우', 1.0), ('팬더', 1.0), ('빨리', 1.0)],
#  [('슬픔', 1.0)],
#  [('기다리셈', 1.0), ('돈이', 1.0), ('없음', 1.0)],
#  [('알바', 1.0)],
#  [('누가', 1.0), ('사갈까봐', 1.0), ('조마조마중', 1.0), ('진심', 1.0)],
#  [('백곰카페라도', 1.0)],
#  [('여기', 1.0), ('너무', 1.0), ('따뜻하다', 1.0), ('복지가', 1.0), ('연봉과', 1.0)],
#  [('라이언', 1.0), ('머스트', 1.0), ('컴', 1.0)],
#  [('제발가고싶다', 1.0)],
#  [('담학기뒷통수', 1.0)],
#  [('rr', 1.0)],
#  [('고고담', 1.0)],
#  [('넘는', 1.0), ('상상을', 1.0), ('초봉이엇움', 1.0)],
#  [('건설임', 1.0), ('라이언의', 1.0), ('목표는', 1.0), ('왕국', 1.0)],
#  [('많아야함', 1.0), ('여사원이', 1.0)],
#  [('저런', 1.0)],
#  [('하앜', 1.0)],
#  [('라이언은', 1.0), ('가야함', 1.0), ('그리고', 1.0), ('나와', 1.0), ('브라질을', 1.0)],
#  [('없다', 1.0), ('포기할수', 1.0)],
#  [('2월', 1.0)],
#  [('돈모아서', 1.0), ('한번에', 1.0)],
#  [('왕국', 1.0), ('건설예정', 1.0), ('이주해서', 1.0)],
#  [('아마존담', 1.0)],
#  [('초봉얼마임', 1.0)],
#  [('얼마', 1.0), ('예상', 1.0)],
#  [('넘는다', 1.0), ('안했던가', 1.0), ('오천좀', 1.0)],
#  [('그런줄', 1.0), ('알앗눈데', 1.0)],
#  [('더', 1.0), ('따뜻햇음', 1.0), ('좀', 1.0)],
#  [('쩌는데', 1.0)],
#  [('어피치', 1.0), ('역시', 1.0)],
#  [('갓헌', 1.0)],
#  [('말햇던', 1.0), ('면접때', 1.0), ('안좋게', 1.0), ('알고보니', 1.0), ('임원이', 1.0)],
#  [('서강대', 1.0), ('출신이엇음', 1.0)],
#  [('저런', 1.0)],
#  [('서강대', 1.0), ('3명', 1.0), ('밖에', 1.0), ('없눈듯', 1.0), ('전체에서', 1.0)],
#  [('라이언도', 1.0), ('석사따면', 1.0)],
#  [('프리패스임', 1.0)],
#  [('없음', 1.0), ('석사', 1.0), ('혜택', 1.0)],
#  [('군대가', 1.0), ('차라리', 1.0), ('혜택큼', 1.0)],
#  [('갓투사', 1.0)],
#  [('더', 1.0), ('1호봉', 1.0), ('2년이라', 1.0), ('공군은', 1.0), ('높음', 1.0)],
#  [('더', 1.0), ('1호봉', 1.0), ('육군은', 1.0), ('쳐주고', 1.0)],
#  [('이런', 1.0)],
#  [('2호봉', 1.0), ('겅군은', 1.0)],
#  [('사기다', 1.0)],
#  [('3호봉', 1.0), ('장교는', 1.0)],
#  [('계장부터', 1.0), ('시작', 1.0), ('장겨출신은', 1.0)],
#  [('장교는', 1.0), ('인정한다', 1.0)],
#  [('여자는', 1.0)],
#  [('더', 1.0), ('시작', 1.0), ('낮게', 1.0)],
#  [('군대안가서', 1.0)],
#  [('샷', 1.0)],
#  [('진정한', 1.0), ('남녀평등', 1.0)],
#  [('800차이', 1.0), ('초봉', 1.0)],
#  [('여사원이', 1.0), ('있었으면', 1.0), ('좀만더', 1.0)],
#  [('최고였을듯', 1.0)],
#  [('여사원', 1.0)],
#  [('많지', 1.0), ('않은듯', 1.0)],
#  [('많음', 1.0), ('현대보단', 1.0)],
#  [('세컨보다', 1.0), ('이쁨', 1.0)],
#  [('그', 1.0),
#   ('던진건가', 1.0),
#   ('또', 1.0),
#   ('이프로도', 1.0),
#   ('이후로', 1.0),
#   ('잠잠하네', 1.0),
#   ('폰', 1.0)],
#  [('어피치', 1.0), ('잡아와', 1.0)],
#  [('세컨과', 1.0), ('잇음', 1.0), ('닮은아이', 1.0)],
#  [('미친', 1.0)],
#  [('개쩌네', 1.0)],
#  [('6천얼마', 1.0), ('한', 1.0)],
#  [('최고', 1.0)],
#  [('2호선', 1.0), ('너무', 1.0), ('사랑스럽다', 1.0), ('진짜', 1.0)],
#  [('좀만', 1.0), ('참으삼', 1.0)],
#  [('팬더', 1.0), ('오고있음', 1.0), ('인형이', 1.0)],
#  [('진짜', 1.0), ('커밍쑨임', 1.0)],
#  [('2호선은', 1.0), ('아름답지', 1.0), ('원래', 1.0)],
#  [('그래도칼퇴시켜주니', 1.0), ('매우', 1.0), ('좋네', 1.0)],
#  [('개털리고옴', 1.0), ('교수님한테', 1.0), ('나는', 1.0)],
#  [('5시퇴근이라', 1.0)],
#  [('칼퇴는아님', 1.0)],
#  [('왜', 1.0), ('성원이형', 1.0)],
#  [('5시임', 1.0), ('아', 1.0), ('천국이네', 1.0)],
#  [('논문써야되서', 1.0)],
#  [('아이디어', 1.0), ('안나와서', 1.0), ('털림', 1.0)],
#  [('아님', 1.0),
#   ('하는거', 1.0),
#   ('빨리', 1.0),
#   ('내라고', 1.0),
#   ('너뮤', 1.0),
#   ('아이디어를', 1.0)],
#  [('계속', 1.0), ('그래서', 1.0)],
#  [('갈구시는중', 1.0)],
#  [('뭐라고', 1.0), ('보통', 1.0), ('성원이형은', 1.0), ('함', 1.0)],
#  [('그런식으로', 1.0), ('접근하면안된다고', 1.0)],
#  [('bfs말고', 1.0), ('dfs로', 1.0), ('하래', 1.0)],
#  [('한', 1.0), ('방식을', 1.0), ('생각해야', 1.0), ('심도있게', 1.0), ('쭉', 1.0)],
#  [('문제해결이된다고', 1.0)],
#  [('이런', 1.0)],
#  [('그', 1.0), ('털림', 1.0), ('데프콘도', 1.0)],
#  [('다른', 1.0), ('동근이는', 1.0)],
#  [('박사형들한테', 1.0), ('세미나에서', 1.0)],
#  [('핵털림', 1.0)],
#  [('성원이형', 1.0), ('박사형들도', 1.0), ('스타일로', 1.0), ('텀', 1.0)],
#  [('당연', 1.0)],
#  [('오랫동안', 1.0), ('참교육받으심', 1.0)],
#  [('성원이형한테', 1.0)],
#  [('당연', 1.0)],
#  [('갈구는군', 1.0), ('성원이형이', 1.0), ('은근히', 1.0), ('잘', 1.0)],
#  [('교수님들', 1.0), ('다', 1.0), ('모든', 1.0), ('비슷할듯', 1.0)],
#  [('석이형은', 1.0), ('아니지', 1.0), ('않나', 1.0), ('인성이형이랑', 1.0)],
#  [('개빡셈', 1.0), ('인성이형', 1.0)],
#  [('돼', 1.0)],
#  [('인성이형이', 1.0)],
#  [('갈구진', 1.0), ('않잖아', 1.0)],
#  [('개갈굼', 1.0)],
#  [('이런', 1.0)],
#  [('알앗는데', 1.0), ('착한줄', 1.0)],
#  [('착하지않음', 1.0)],
#  [('개빡세대', 1.0)],
#  [('헐', 1.0)],
#  [('석이형은', 1.0)],
#  [('석이형은', 1.0), ('아마', 1.0)],
#  [('관심없을듯', 1.0)],
#  [('근데석사생개많음', 1.0)],
#  [('13두명', 1.0), ('또들어간', 1.0), ('이번에', 1.0)],
#  [('헐', 1.0), ('누구', 1.0)],
#  [('아', 1.0), ('디비랩', 1.0)],
#  [('디비랩인기개많음', 1.0)],
#  [('신기', 1.0)],
#  [('닥쳐봐', 1.0)],
#  [('임구마언제봉인해제냐', 1.0)],
#  [('이제', 1.0), ('곧', 1.0), ('임구마', 1.0), ('해제함', 1.0)],
#  [('팬더', 1.0), ('아니', 1.0)],
#  [('머치', 1.0), ('하우', 1.0)],
#  [('만팔천원', 1.0), ('웃', 1.0)],
#  [('아니', 1.0)],
#  [('산다', 1.0), ('이맛에', 1.0)],
#  [('굿', 1.0)],
#  [('고마워요', 1.0), ('다들', 1.0), ('핳', 1.0)],
#  [('드럽게', 1.0), ('사놓고', 1.0), ('욕먹음', 1.0), ('집에선', 1.0), ('핳핳', 1.0)],
#  [('네오짱도', 1.0), ('올라왓데', 1.0)],
#  [('끝났데', 1.0), ('면접', 1.0), ('튜브도', 1.0)],
#  [('굿', 1.0)],
#  [('유혹', 1.0), ('카톡', 1.0)],
#  [('거부함', 1.0), ('알아서', 1.0), ('온다함', 1.0)],
#  [('아마', 1.0), ('딜이', 1.0), ('라이언이랑', 1.0), ('모종의', 1.0), ('있는듯', 1.0)],
#  [('설마', 1.0)],
#  [('🔞', 1.0)],
#  [('그러타', 1.0)],
#  [('공유인듯', 1.0), ('세컨', 1.0)],
#  [('이제', 1.0), ('세컨', 1.0), ('2명이라', 1.0)],
#  [('원레', 1.0)],
#  [('2명이', 1.0), ('승격함', 1.0), ('이엇던', 1.0), ('트리플', 1.0)],
#  [('1명씩', 1.0)],
#  [('스와핑담', 1.0)],
#  [('렌탈담', 1.0)],
#  [('오늘도', 1.0)],
#  [('대단', 1.0)],
#  [('난봉꾼임', 1.0)],
#  [('오늘부터', 1.0)],
#  [('3일간가족여행임', 1.0)],
#  [('아쉽', 1.0)],
#  [('성원이형', 1.0)],
#  [('당연', 1.0)],
#  [('너는', 1.0), ('도시락', 1.0), ('먹어', 1.0)],
#  [('굳', 1.0)],
#  [('도시락', 1.0), ('어디꺼', 1.0)],
#  [('석천이오빠꺼', 1.0), ('혜리꺼', 1.0)],
#  [('밥', 1.0), ('사먹어', 1.0)],
#  [('도시락이', 1.0), ('머가', 1.0), ('좋아', 1.0)],
#  [('사실구라임', 1.0)],
#  [('걍', 1.0), ('귀찮아서', 1.0), ('밥사먹기', 1.0), ('샌드위치먹는다', 1.0)],
#  [('서브웨이', 1.0)],
#  [('개굿', 1.0)],
#  [('그거없음', 1.0)],
#  [('귀엽스', 1.0)],
#  [('버려', 1.0)],
#  [('한솥도시락', 1.0)],
#  [('없어', 1.0)],
#  [('튜브이랑', 1.0), ('홍반', 1.0)],
#  [('나중에', 1.0)],
#  [('구마년소환점', 1.0)],
#  [('꼬셔야함', 1.0), ('너가', 1.0)],
#  [('난', 1.0), ('수험생이니', 1.0), ('알아서꼬시도록', 1.0)],
#  [('달려올거임', 1.0), ('바로', 1.0), ('야동주면', 1.0)],
#  [('떠오른다', 1.0), ('오바워치가', 1.0)],
#  [('갓헌과', 1.0), ('함께', 1.0)],
#  [('어피치', 1.0), ('넌', 1.0), ('연습좀해', 1.0)],
#  [('한조', 1.0)],
#  [('시발', 1.0)],
#  [('님들', 1.0)],
#  [('12시', 1.0), ('이번주', 1.0), ('토요일', 1.0)],
#  [('안양오셈', 1.0), ('튜브만나러', 1.0)],
#  [('면회', 1.0)],
#  [('오키', 1.0)],
#  [('굿', 1.0)],
#  [('모여라친구들이여', 1.0)],
#  [('좀', 1.0), ('아', 1.0), ('갈수도', 1.0), ('늦게', 1.0), ('토욜이네', 1.0)],
#  [('다', 1.0), ('끝난건가', 1.0), ('오', 1.0), ('튜브이', 1.0)],
#  [('늦게', 1.0), ('그날', 1.0), ('까지', 1.0), ('놀겠지', 1.0)],
#  [('베이베', 1.0), ('안재워줄거야', 1.0)],
#  [('갈수', 1.0), ('있을듯', 1.0), ('저녁때까지', 1.0), ('확실히', 1.0)],
#  [('팬더', 1.0), ('무지', 1.0), ('사랑', 1.0), ('여전한', 1.0)],
#  [('포에버임', 1.0)],
#  [('멈추지않아', 1.0)],
#  [('논스탑', 1.0)],
#  [('가야함', 1.0), ('난', 1.0), ('저녁에', 1.0)],
#  [('프로도타랑', 1.0)],
#  [('난', 1.0),
#   ('5급', 1.0),
#   ('hsk', 1.0),
#   ('날이라', 1.0),
#   ('넘어갈듯', 1.0),
#   ('보고', 1.0),
#   ('오전에', 1.0)],
#  [('피곤하다', 1.0)],
#  [('저녁몇시귀가할꺼냐', 1.0)],
#  [('모르지', 1.0)],
#  [('튜브삘에따라다름', 1.0)],
#  [('난일단보류', 1.0)],
#  [('모유', 1.0)],
#  [('모유', 1.0)],
#  [('모유담', 1.0)],
#  [('맛잇음', 1.0)],
#  [('과사녀', 1.0)],
#  [('나옴', 1.0), ('모유가', 1.0)],
#  [('뭐', 1.0)],
#  [('넌', 1.0), ('왜안자', 1.0)],
#  [('출근안하냐', 1.0)],
#  [('합숙연슈옴', 1.0)],
#  [('술', 1.0), ('열라마심', 1.0)],
#  [('이제', 1.0), ('공부방', 1.0), ('출발하냐', 1.0), ('프로도타는', 1.0)],
#  [('집에옴', 1.0)],
#  [('핸폰두고다님', 1.0)],
#  [('너그럼', 1.0), ('주말에못오겠네', 1.0)],
#  [('술먹고주정', 1.0)],
#  [('가지', 1.0)],
#  [('귀가', 1.0), ('내일', 1.0)],
#  [('언제컴백하냐', 1.0)],
#  [('그렇구만', 1.0)],
#  [('숙취해소하고와라', 1.0)],
#  [('복귀예정', 1.0), ('저녁먹고', 1.0), ('토욜', 1.0)],
#  [('부부장님', 1.0), ('사기임', 1.0)],
#  [('마심', 1.0), ('말하면서', 1.0), ('슐만', 1.0)],
#  [('망함', 1.0), ('앉아서', 1.0), ('자리', 1.0), ('잘못', 1.0)],
#  [('술', 1.0), ('마스터가되는게', 1.0), ('이참에', 1.0)],
#  [('뻗은척하셈', 1.0), ('적당히마쉬고', 1.0)],
#  [('좀', 1.0), ('그래', 1.0), ('너도', 1.0), ('쉬어', 1.0)],
#  [('모유', 1.0)],
#  [('이런', 1.0), ('나픈', 1.0), ('팬도', 1.0)],
#  [('내일', 1.0), ('그럼', 1.0)],
#  [('전부오는건가', 1.0)],
#  [('3시까진', 1.0), ('갈겡', 1.0)],
#  [('좀', 1.0), ('멀어가꼬', 1.0), ('셤장소가', 1.0)],
#  [('굿', 1.0)],
#  [('1시까지오래', 1.0), ('일단', 1.0), ('튜브씨가', 1.0)],
#  [('1번가집합', 1.0), ('1시에', 1.0)],
#  [('임즈님이', 1.0)],
#  [('예스', 1.0)],
#  [('맥날임', 1.0), ('임즈님은', 1.0)],
#  [('모름', 1.0)],
#  [('아마그럴지도', 1.0)],
#  [('명돈', 1.0), ('임즈하면', 1.0)],
#  [('명돈환', 1.0)],
#  [('명돈', 1.0), ('극혐', 1.0)],
#  [('명돈', 1.0), ('거기', 1.0), ('세트', 1.0), ('솬이', 1.0), ('좋아함', 1.0)],
#  [('그럼가야지', 1.0)],
#  [('내일', 1.0)],
#  [('점심먹고오신더니', 1.0), ('튜브님', 1.0)],
#  [('나와함께미리점심하실분모집', 1.0)],
#  [('맥날팸', 1.0)],
#  [('굿', 1.0)],
#  [('모여라', 1.0), ('얘들아', 1.0)],
#  [('어피치는', 1.0), ('몇시에', 1.0), ('와', 1.0)],
#  [('일찍간다던데', 1.0), ('일찍와서', 1.0)],
#  [('오전에', 1.0), ('내일', 1.0), ('나', 1.0), ('바로감', 1.0), ('운동뛰고', 1.0)],
#  [('굿', 1.0)],
#  [('12까지올사람', 1.0), ('손', 1.0)],
#  [('프로도타', 1.0)],
#  [('오바워치', 1.0), ('할듯', 1.0)],
#  [('굿', 1.0)],
#  [('12시턴', 1.0), ('네오이도', 1.0)],
#  [('굳', 1.0), ('얼른들모여', 1.0)],
#  [('일찍오면', 1.0), ('임즈', 1.0), ('조은데', 1.0)],
#  [('굿', 1.0)],
#  [('가야함', 1.0), ('나', 1.0), ('저녁엔', 1.0)],
#  [('심지어', 1.0), ('임즈', 1.0), ('점심먹고온대', 1.0)],
#  [('그래야', 1.0), ('사주는데', 1.0), ('점심', 1.0)],
#  [('임즈', 1.0), ('점심', 1.0)],
#  [('어피치', 1.0), ('주고가삼', 1.0), ('카드', 1.0)],
#  [('그냥오라니까', 1.0)],
#  [('사먹겠음', 1.0), ('우리가', 1.0)],
#  [('개굳', 1.0)],
#  [('집에서먹고온개', 1.0)],
#  [('다시한번', 1.0)],
#  [('꼬셔보갰음', 1.0)],
#  [('꼬시기', 1.0), ('늦은', 1.0), ('점심으로', 1.0)],
#  [('님들', 1.0)],
#  [('12시점심', 1.0)],
#  [('꼬심', 1.0)],
#  [('와라', 1.0)],
#  [('12시30', 1.0)],
#  [('아뷰리털고', 1.0), ('잇으삼', 1.0)],
#  [('물론', 1.0), ('30이전에', 1.0), ('가긴', 1.0), ('할건데', 1.0)],
#  [('모르니', 1.0), ('혹시', 1.0)],
#  [('먼저', 1.0), ('바로갈게', 1.0), ('있으면', 1.0), ('점심먹고', 1.0)],
#  [('빨리오셈', 1.0)],
#  [('개춥네', 1.0), ('하', 1.0)],
#  [('님들', 1.0), ('개추움', 1.0), ('따시게', 1.0), ('오늘', 1.0), ('입으셈', 1.0)],
#  [('시험화이팅', 1.0)],
#  [('네오이', 1.0), ('대리시험', 1.0)],
#  [('시헌잘봐라', 1.0)],
#  [('아이온에잇을테니알아서오3', 1.0)],
#  [('프로도아', 1.0)],
#  [('아이온에', 1.0)],
#  [('튜브이있다', 1.0)],
#  [('만나라', 1.0)],
#  [('만남', 1.0)],
#  [('이제', 1.0)],
#  [('내려서감', 1.0)],
#  [('이제', 1.0), ('감', 1.0), ('나도', 1.0)],
#  [('밥', 1.0), ('가자', 1.0), ('먹고', 1.0), ('오버워치', 1.0)],
#  [('아', 1.0), ('드럽게', 1.0), ('어렵네', 1.0)],
#  [('역시', 1.0), ('극혐', 1.0), ('중국어', 1.0)],
#  [('여기', 1.0),
#   ('너무', 1.0),
#   ('좀', 1.0),
#   ('내랴감', 1.0),
#   ('멈', 1.0),
#   ('쉬다', 1.0),
#   ('암튼', 1.0)],
#  [('갈듯', 1.0), ('두시반이면', 1.0)],
#  [('굿굿', 1.0)],
#  [('출발했습니당', 1.0)],
#  [('굿굿', 1.0)],
#  [('어디잇을거임', 1.0)],
#  [('어디냐', 1.0)],
#  [('전화좀', 1.0)],
#  [('우리', 1.0), ('이미아이온임', 1.0)],
#  [('감', 1.0), ('10분', 1.0), ('이내로', 1.0)],
#  [('아이온', 1.0), ('화장실임', 1.0)],
#  [('굿굿', 1.0)],
#  [('네오아', 1.0), ('도착하면전화', 1.0)],
#  [('가는중', 1.0)],
#  [('드럽게', 1.0), ('춥네', 1.0)],
#  [('아이온으로', 1.0), ('컴컴', 1.0)],
#  [('아빠옴', 1.0)],
#  [('안옴', 1.0)],
#  [('노래', 1.0), ('녹음한거', 1.0), ('업로드', 1.0)],
#  [('노래방', 1.0), ('안감', 1.0), ('오늘은', 1.0)],
#  [('감', 1.0)],
#  [('근데', 1.0), ('녹음응', 1.0), ('안함', 1.0)],
#  [('미리브탁하지', 1.0)],
#  [('오늘즐거웠다제군들', 1.0)],
#  [('꿀잼', 1.0)],
#  [('아', 1.0), ('몰려옴스', 1.0), ('피로가', 1.0)],
#  [('사진', 1.0)],
#  [('카톡', 1.0), ('임즈', 1.0), ('복귀한데', 1.0)],
#  [('합격하면', 1.0)],
#  [('헿', 1.0)],
#  [('빠른시일내에', 1.0), ('이렇게또모이길', 1.0)],
#  [('예스예스', 1.0)],
#  [('아', 1.0), ('목에', 1.0), ('상처남', 1.0)],
#  [('개', 1.0), ('거슬리네', 1.0)],
#  [('그녀의', 1.0), ('손톱자국', 1.0)],
#  [('목안', 1.0)],
#  [('노래의', 1.0), ('어제의', 1.0), ('여파', 1.0)],
#  [('나도', 1.0), ('어제', 1.0), ('피맛나는느낌이었는데', 1.0)],
#  [('따뜻한거많이먹고', 1.0)],
#  [('닥치고자니까', 1.0), ('좀나아짐', 1.0)],
#  [('낫음', 1.0), ('뭐가', 1.0), ('안에', 1.0), ('흑흑', 1.0)],
#  [('목암', 1.0)],
#  [('음', 1.0)],
#  [('어제', 1.0), ('인연부름', 1.0)],
#  [('당연', 1.0)],
#  [('모여서', 1.0), ('오랜만에', 1.0), ('튜브가', 1.0)],
#  [('추억노래', 1.0), ('특집함', 1.0)],
#  [('굿', 1.0), ('임원', 1.0)],
#  [('지노우', 1.0), ('뷱극곰은', 1.0), ('안키윰', 1.0)],
#  [('나', 1.0), ('북극곰이', 1.0), ('키우는거일걸', 1.0)],
#  [('팬더vs북극곰', 1.0)],
#  [('팬더', 1.0), ('닥', 1.0)],
#  [('북극곰', 1.0)],
#  [('님이', 1.0)],
#  [('진짜', 1.0),
#   ('아', 1.0),
#   ('오늘', 1.0),
#   ('목안에', 1.0),
#   ('목지짐', 1.0),
#   ('염증이', 1.0),
#   ('있었음', 1.0)],
#  [('구덩이', 1.0), ('만들어서', 1.0), ('약채움', 1.0), ('지지고', 1.0)],
#  [('조심해라', 1.0)],
#  [('훅간다', 1.0)],
#  [('노목무지', 1.0)],
#  [('진심', 1.0), ('관리해야함', 1.0)],
#  [('당연', 1.0)],
#  [('관리도', 1.0), ('탈모', 1.0)],
#  [('관리도', 1.0)],
#  [('곧휴는', 1.0), ('쉬야할때만', 1.0)],
#  [('라이언처럼', 1.0), ('자주사용', 1.0)],
#  [('거절함', 1.0), ('더블데이트', 1.0), ('라이언이', 1.0)],
#  [('가소로운', 1.0), ('녀석', 1.0)],
#  [('그렇잖아', 1.0), ('더블데이트하면', 1.0), ('하러가기', 1.0)],
#  [('라이언은', 1.0), ('들고다니는걸로암', 1.0), ('따로', 1.0), ('원래개인텐트', 1.0)],
#  [('무관', 1.0), ('장소는', 1.0)],
#  [('같이', 1.0), ('거칠게', 1.0), ('다니면', 1.0), ('못다룸', 1.0)],
#  [('인정', 1.0)],
#  [('같이', 1.0), ('브라질', 1.0)],
#  [('2월이', 1.0), ('기회일듯', 1.0)],
#  [('삼바삼바', 1.0)],
#  [('달려', 1.0)],
#  [('🏃🏃', 1.0)],
#  [('데려와', 1.0), ('윤아씨', 1.0)],
#  [('챙겨서', 1.0), ('텐트', 1.0)],
#  [('🏪', 1.0)],
#  [('갖고싶다', 1.0), ('나왔던데', 1.0), ('베라에', 1.0), ('팬더케이크', 1.0)],
#  [('내가', 1.0), ('대신', 1.0), ('먹어줄게', 1.0)],
#  [('걱정', 1.0)],
#  [('🐼🐼🐼🐼🐼', 1.0)],
#  [('좀', 1.0), ('대신', 1.0), ('사진이라도', 1.0)],
#  [('맛은', 1.0), ('무의미', 1.0)],
#  [('굿', 1.0)],
#  [('나만의', 1.0), ('비밀', 1.0)],
#  [('미미', 1.0), ('부넝슈워더', 1.0)],
#  [('아이니준희', 1.0)],
#  [('과연', 1.0), ('어디에', 1.0), ('준희는', 1.0), ('흑', 1.0)],
#  [('문하영이', 1.0), ('성정체성을', 1.0), ('준희의', 1.0), ('크다', 1.0), ('흔든건', 1.0)],
#  [('몰라', 1.0), ('문하영과', 1.0), ('있을지도', 1.0), ('함께하고', 1.0)],
#  [('너도', 1.0), ('크다', 1.0), ('임마', 1.0), ('잘못이', 1.0)],
#  [('왜', 1.0), ('내가', 1.0)],
#  [('꼬임에', 1.0), ('너와', 1.0), ('몇몇', 1.0), ('아이들에', 1.0)],
#  [('난', 1.0),
#   ('준희의', 1.0),
#   ('문전박대', 1.0),
#   ('뿐이야', 1.0),
#   ('수상함을', 1.0),
#   ('알고', 1.0),
#   ('했을', 1.0)],
#  [('고백한거잖아', 1.0), ('넘어가', 1.0)],
#  [('양아치야', 1.0), ('이', 1.0)],
#  [('난', 1.0), ('입니다', 1.0), ('피해자', 1.0)],
#  [('대보세여', 1.0), ('증거를', 1.0)],
#  [('비선실세', 1.0), ('이준희의', 1.0)],
#  [('내가', 1.0), ('그', 1.0), ('보고', 1.0), ('들었다', 1.0), ('자리에서', 1.0)],
#  [('준희의', 1.0), ('들어야햇단', 1.0), ('말입니다', 1.0), ('방에서', 1.0), ('울부짖음을', 1.0)],
#  [('라이브로', 1.0)],
#  [('1대1로', 1.0)],
#  [('결과를', 1.0), ('아는데', 1.0)],
#  [('너희들이다', 1.0), ('뛰어들게', 1.0), ('불바다로', 1.0), ('한건', 1.0)],
#  [('흑흑', 1.0)],
#  [('아니야', 1.0)],
#  [('나도', 1.0), ('피해자야', 1.0)],
#  [('너', 1.0),
#   ('다행으로', 1.0),
#   ('배에서', 1.0),
#   ('아셈', 1.0),
#   ('안던진걸', 1.0),
#   ('준희가', 1.0)],
#  [('배에서', 1.0),
#   ('나임', 1.0),
#   ('뻔한거', 1.0),
#   ('살려준게', 1.0),
#   ('자살할', 1.0),
#   ('준희', 1.0)],
#  [('이프로도', 1.0),
#   ('오버워치', 1.0),
#   ('우리', 1.0),
#   ('다음날에도', 1.0),
#   ('만난', 1.0),
#   ('했네', 1.0)],
#  [('역시', 1.0)],
#  [('멋지군', 1.0)],
#  [('역시', 1.0), ('그럴줄', 1.0), ('알았습니다', 1.0)],
#  [('프로도', 1.0), ('버릴수', 1.0), ('없는', 1.0), ('한조를', 1.0)],
#  [('이', 1.0), ('남자의', 1.0), ('어디까지인가', 1.0), ('한계는', 1.0)],
#  [('없지', 1.0), ('프로도이에게', 1.0), ('한계따윈', 1.0)],
#  [('대단', 1.0)],
#  [('어피치', 1.0), ('역시', 1.0), ('프로도잡는', 1.0)],
#  [('안듣는다고', 1.0), ('알아봄', 1.0), ('죽일때부터', 1.0)],
#  [('개웃겼음', 1.0)],
#  [('히이즈어어쌔신', 1.0)],
#  [('그냥', 1.0), ('단순', 1.0), ('맘에', 1.0), ('안듬', 1.0), ('이유는', 1.0)],
#  [('듣지않은', 1.0), ('말을', 1.0), ('자신의', 1.0)],
#  [('댓가로', 1.0)],
#  [('처결', 1.0)],
#  [('이프로도', 1.0), ('어리둥절핼', 1.0)],
#  [('역시', 1.0)],
#  [('노는게', 1.0), ('우리끼리', 1.0), ('제일재밌음', 1.0)],
#  [('요새', 1.0), ('튜브이가', 1.0)],
#  [('계속', 1.0), ('콜하던데', 1.0)],
#  [('또', 1.0), ('주말에', 1.0), ('한번볼까', 1.0)],
#  [('내려가기전에', 1.0), ('네오찡', 1.0)],
#  [('어피치는', 1.0), ('주말에는', 1.0), ('프리할거고', 1.0)],
#  [('나도그러하고', 1.0)],
#  [('너도그러하고', 1.0)],
#  [('굿', 1.0)],
#  [('주말', 1.0)],
#  [('토욜', 1.0)],
#  [('일요일가능', 1.0)],
#  [('괜찮긴한데', 1.0), ('토요일도', 1.0)],
#  [('내가', 1.0), ('7시반에', 1.0), ('약속이있어서', 1.0), ('토요일에', 1.0)],
#  [('물론', 1.0), ('두탕해도되지만', 1.0)],
#  [('이번주', 1.0), ('나', 1.0), ('바쁨', 1.0), ('주말은', 1.0)],
#  [('흑', 1.0)],
#  [('설마', 1.0)],
#  [('나', 1.0), ('대신', 1.0), ('준희', 1.0)],
#  [('산행', 1.0), ('회사에서', 1.0)],
#  [('극혐', 1.0)],
#  [('아', 1.0), ('맞다', 1.0)],
#  [('나', 1.0), ('일요일엔', 1.0)],
#  [('안되는구나', 1.0)],
#  [('왜', 1.0), ('카톡', 1.0), ('임즈', 1.0), ('근데', 1.0), ('안함', 1.0), ('복귀', 1.0)],
#  [('물어봤는데', 1.0)],
#  [('붙으면', 1.0), ('온대', 1.0)],
#  [('이렁', 1.0)],
#  [('롯월', 1.0), ('일욜', 1.0)],
#  [('호오', 1.0)],
#  [('굿', 1.0)],
#  [('나도놀고싶다', 1.0)],
#  [('주말에', 1.0), ('2시간씩하련다', 1.0), ('오버워치는', 1.0)],
#  [('한조', 1.0)],
#  [('이호한조', 1.0)],
#  [('와카테도쿠라이', 1.0)],
#  [('건배사', 1.0), ('추천', 1.0)],
#  [('깐빠이', 1.0)],
#  [('부서', 1.0), ('이렇게', 1.0), ('폭파가능', 1.0), ('하면', 1.0)],
#  [('라이언이', 1.0), ('하라는데로', 1.0)],
#  [('굿굿', 1.0)],
#  [('건배사함', 1.0), ('성원이형도', 1.0)],
#  [('저런', 1.0)],
#  [('어피치는', 1.0), ('파워', 1.0)],
#  [('배치받음', 1.0), ('운영부', 1.0)],
#  [('호우', 1.0)],
#  [('어떤일을함', 1.0), ('운영부는', 1.0)],
#  [('그대로', 1.0),
#   ('네트워크', 1.0),
#   ('등등', 1.0),
#   ('말', 1.0),
#   ('서버', 1.0),
#   ('운영임', 1.0)],
#  [('안함', 1.0), ('개발은', 1.0)],
#  [('이럴수가', 1.0)],
#  [('이런', 1.0)],
#  [('아님', 1.0), ('좋은거', 1.0)],
#  [('좋지', 1.0)],
#  [('개', 1.0), ('얼타는중', 1.0)],
#  [('개발이좋지않음', 1.0)],
#  [('새로운', 1.0), ('세계임', 1.0)],
#  [('모르겠는데', 1.0)],
#  [('너의', 1.0), ('봤다', 1.0), ('이름은', 1.0)],
#  [('느껴졌다', 1.0), ('덕력이', 1.0), ('사방에서', 1.0)],
#  [('아', 1.0)],
#  [('개마심', 1.0), ('슐', 1.0)],
#  [('하셈', 1.0)],
#  [('아', 1.0)],
#  [('왜', 1.0), ('지금도', 1.0), ('지하철은', 1.0), ('헬인건가', 1.0)],
#  [('너의', 1.0), ('그럴떈', 1.0), ('보는거임', 1.0), ('이름은을', 1.0)],
#  [('지노우', 1.0), ('치트키좀', 1.0)],
#  [('있을듯', 1.0), ('라이언만', 1.0), ('휴', 1.0)],
#  [('난', 1.0), ('사업', 1.0), ('접음', 1.0)],
#  [('복귀해', 1.0)],
#  [('여자', 1.0), ('과장임', 1.0), ('어린', 1.0), ('제일', 1.0)],
#  [('이쁨', 1.0)],
#  [('평범', 1.0)],
#  [('공략', 1.0)],
#  [('이미', 1.0), ('평촌', 1.0)],
#  [('나와', 1.0), ('프로도타', 1.0)],
#  [('오버워치중일듯', 1.0)],
#  [('이런미친놈들', 1.0)],
#  [('세상을', 1.0), ('이미친', 1.0)],
#  [('경쟁전', 1.0), ('그저께', 1.0), ('올림', 1.0), ('이백점', 1.0)],
#  [('지하철은', 1.0), ('눈', 1.0), ('오는', 1.0)],
#  [('세상이다', 1.0), ('지배하는', 1.0), ('프로도타가', 1.0)],
#  [('눈사람', 1.0), ('만들고', 1.0), ('싶아', 1.0)],
#  [('숙취', 1.0)],
#  [('몸그렇게만들고', 1.0), ('조루수준이네', 1.0), ('체력', 1.0)],
#  [('아저씨', 1.0), ('팰뻔', 1.0), ('후두려', 1.0)],
#  [('매우', 1.0), ('새치기', 1.0), ('짜증나네', 1.0)],
#  [('그게', 1.0), ('지하철의일상이지', 1.0)],
#  [('매일본다', 1.0), ('서울역에선', 1.0)],
#  [('눈오는날은', 1.0), ('믹스가', 1.0), ('티오피가된다', 1.0)],
#  [('깡패호험', 1.0)],
#  [('닥쳐', 1.0)],
#  [('너의이름은', 1.0), ('보3', 1.0), ('분꿀꿀하면', 1.0), ('이따퇴근하고', 1.0)],
#  [('범계역', 1.0), ('안되겟다', 1.0), ('코노와', 1.0)],
#  [('가자', 1.0), ('4곡만', 1.0)],
#  [('타키군', 1.0)],
#  [('나이', 1.0), ('토모에', 1.0)],
#  [('미츠하', 1.0)],
#  [('덕력', 1.0), ('충만하다', 1.0)],
#  [('좋아', 1.0)],
#  [('기모찌이이', 1.0)],
#  [('이런', 1.0), ('삼바같은', 1.0), ('친구들', 1.0)],
#  [('기미노', 1.0), ('나마에와', 1.0)],
#  [('명작이야', 1.0)],
#  [('나는', 1.0), ('두번봄', 1.0)],
#  [('나이', 1.0), ('오보에테', 1.0)],
#  [('미츠하', 1.0), ('Search', 1.0)],
#  [('진심', 1.0),
#   ('보고', 1.0),
#   ('덕후', 1.0),
#   ('될지도', 1.0),
#   ('모르겠다능', 1.0),
#   ('이거', 1.0)],
#  [('팬더쳐', 1.0)],
#  [('미즈하', 1.0)],
#  [('개꿀잰', 1.0)],
#  [('이거보면', 1.0), ('튜브', 1.0), ('내', 1.0), ('생각에', 1.0)],
#  [('이애기만', 1.0), ('한다', 1.0), ('한동안', 1.0)],
#  [('돼', 1.0), ('이거', 1.0)],
#  [('잇음', 1.0), ('튜브', 1.0), ('뭐하고', 1.0), ('지금', 1.0)],
#  [('오버', 1.0)],
#  [('튜브', 1.0), ('롤', 1.0)],
#  [('카톡', 1.0), ('복귀', 1.0), ('같은데', 1.0), ('될거', 1.0), ('해도', 1.0)],
#  [('그런듯', 1.0)],
#  [('나도그렇게생각함', 1.0)],
#  [('금의환향을', 1.0), ('본인은', 1.0), ('원하는듯', 1.0)],
#  [('이런', 1.0)],
#  [('너의', 1.0), ('이름은을', 1.0), ('봐야함', 1.0)],
#  [('그건', 1.0), ('나오는건가', 1.0), ('뉴가', 1.0)],
#  [('너의', 1.0), ('이름은', 1.0), ('Search', 1.0)],
#  [('오', 1.0)],
#  [('왜', 1.0), ('좆밥임', 1.0), ('평점이', 1.0)],
#  [('평가못함', 1.0), ('평점으로', 1.0)],
#  [('이', 1.0), ('여형이라는', 1.0), ('영화', 1.0)],
#  [('얘기가있음', 1.0)],
#  [('미즈하', 1.0)],
#  [('하아', 1.0)],
#  [('교수', 1.0)],
#  [('하', 1.0)],
#  [('2월', 1.0), ('2일까지', 1.0)],
#  [('파이썬마스터해오래', 1.0)],
#  [('성원', 1.0)],
#  [('아', 1.0)],
#  [('교수님', 1.0), ('이상함', 1.0)],
#  [('답', 1.0), ('통수가', 1.0)],
#  [('이미당했으니', 1.0)],
#  [('나는', 1.0), ('여기서', 1.0)],
#  [('뽕을뽑고간다', 1.0)],
#  [('가야지', 1.0), ('존나', 1.0), ('커서', 1.0)],
#  [('너가', 1.0), ('뽑힘', 1.0)],
#  [('도망간자의', 1.0), ('여유', 1.0)],
#  [('너무', 1.0), ('아', 1.0), ('창렬하다', 1.0)],
#  [('프로도타', 1.0), ('어디야', 1.0)],
#  [('내일', 1.0), ('아이온에', 1.0), ('가면', 1.0), ('서식할듯', 1.0)],
#  [('님들은', 1.0)],
#  [('많음', 1.0), ('가면', 1.0), ('창렬형님들', 1.0), ('편의점에', 1.0)],
#  [('오늘', 1.0), ('점심도', 1.0), ('창렬하고', 1.0)],
#  [('아', 1.0)],
#  [('힘내삼', 1.0), ('조지면됨', 1.0), ('프로도이', 1.0)],
#  [('프로도타', 1.0), ('가야지', 1.0), ('코노', 1.0)],
#  [('12시에', 1.0), ('걸어와라', 1.0), ('범계로', 1.0)],
#  [('운동', 1.0)],
#  [('어피치', 1.0), ('노래연습', 1.0)],
#  [('라이언이랑', 1.0),
#   ('거기에', 1.0),
#   ('겁나', 1.0),
#   ('데이식스', 1.0),
#   ('목소리', 1.0),
#   ('비슷한애', 1.0),
#   ('있음', 1.0)],
#  [('강습', 1.0), ('받을거임', 1.0), ('프로도타한테', 1.0)],
#  [('더', 1.0), ('재밌다', 1.0), ('킹', 1.0)],
#  [('아님', 1.0), ('근데', 1.0), ('기대만큼은', 1.0), ('막', 1.0)],
#  [('다운받아', 1.0), ('보시길', 1.0)],
#  [('승호햄', 1.0)],
#  [('햄헌', 1.0)],
#  [('비엔나헌', 1.0)],
#  [('죽순무지', 1.0)],
#  [('당연', 1.0)],
#  [('역시', 1.0)],
#  [('무지', 1.0), ('이미', 1.0)],
#  [('많은', 1.0), ('파트너가있음', 1.0)],
#  [('마', 1.0)],
#  [('당연', 1.0)],
#  [('하지만', 1.0), ('고고한척', 1.0)],
#  [('악마가안에있음', 1.0)],
#  [('나', 1.0), ('색마임', 1.0)],
#  [('단지', 1.0), ('상대가', 1.0), ('없을뿐', 1.0)],
#  [('그', 1.0), ('고2', 1.0), ('그때', 1.0), ('그렇다면', 1.0)],
#  [('라인', 1.0), ('지움', 1.0)],
#  [('그때', 1.0), ('가름', 1.0), ('배를', 1.0), ('현자타임으로', 1.0), ('황금거위의', 1.0)],
#  [('핳', 1.0), ('안될놈은', 1.0), ('안됨', 1.0)],
#  [('그럼', 1.0), ('즁딩', 1.0)],
#  [('소개좀', 1.0)],
#  [('프로도타한테', 1.0), ('부탁', 1.0)],
#  [('없음', 1.0), ('프로도이에게', 1.0), ('공유는', 1.0)],
#  [('독식', 1.0)],
#  [('이런', 1.0), ('쉬바', 1.0)],
#  [('다잊고', 1.0), ('미즈하가', 1.0), ('짱이다', 1.0)],
#  [('미츠하', 1.0), ('Search', 1.0), ('미야미즈', 1.0)],
#  [('입덕햇냐', 1.0)],
#  [('미츠하아아', 1.0)],
#  [('요츠하아아', 1.0)],
#  [('타키군', 1.0)],
#  [('망했다', 1.0), ('안양외고', 1.0)],
#  [('성추행', 1.0)],
#  [('안됨', 1.0), ('2대1도', 1.0), ('경쟁률', 1.0)],
#  [('흑흑', 1.0)],
#  [('똥학교됨', 1.0)],
#  [('망한건가', 1.0), ('없어서', 1.0), ('이과', 1.0)],
#  [('이과있을걸', 1.0)],
#  [('비공식적으로', 1.0)],
#  [('망한듯', 1.0), ('비공식적이라', 1.0)],
#  [('걍', 1.0), ('과고이런데는', 1.0), ('넘기는데', 1.0), ('십대일도', 1.0)],
#  [('다', 1.0), ('안됨', 1.0), ('2대1도', 1.0), ('외고들', 1.0)],
#  [('역시', 1.0)],
#  [('이과', 1.0)],
#  [('바래야할판', 1.0), ('안없어지길', 1.0), ('우리학교', 1.0)],
#  [('이제', 1.0), ('외고는', 1.0)],
#  [('그냥망함', 1.0)],
#  [('흑흑', 2.0), ('아냥와이까오', 1.0), ('우리의', 1.0)],
#  [('프로도타가', 1.0), ('않는', 1.0), ('이상', 1.0), ('재단이사장', 1.0), ('취임하지', 1.0)],
#  [('내가', 1.0), ('갈아엎지', 1.0), ('이사장으로취임하면', 1.0), ('학교', 1.0)],
#  [('광수형', 1.0)],
#  [('바꺼주셈', 1.0), ('사서', 1.0), ('학교좀', 1.0)],
#  [('rnt', 1.0)],
#  [('굿', 1.0)],
#  [('굿', 1.0)],
#  [('프로도외고', 1.0)],
#  [('호혐외고', 1.0)],
#  [('이런이런', 1.0)],
#  [('다들', 1.0), ('주말에', 1.0)],
#  [('뭐하심', 1.0)],
#  [('이럴때일수록', 1.0)],
#  [('몸조리', 1.0), ('집에서', 1.0)],
#  [('부럽', 1.0)],
#  [('나는연구실에서', 1.0)],
#  [('공부하다', 1.0), ('파이썬', 1.0)],
#  [('이제', 1.0), ('인천감', 1.0)],
#  [('나는', 1.0)],
#  [('만드는중', 1.0), ('발표자료', 1.0)],
#  [('아이온', 1.0), ('임튜브은', 1.0)],
#  [('감', 1.0), ('밥먹고', 1.0), ('유가네서', 1.0)],
#  [('엌', 1.0), ('유가넼', 1.0)],
#  [('닭갈비볶음밥', 1.0)],
#  [('닥치라우', 1.0)],
#  [('병우', 1.0)],
#  [('우병우헌', 1.0)],
#  [('청와대헌', 1.0)],
#  [('비선헌', 1.0)],
#  [('헌', 1.0)],
#  [('정어피치병우같은놈', 1.0)],
#  [('와라', 1.0), ('경쟁전으로', 1.0), ('오버워치나해', 1.0)],
#  [('일단', 1.0), ('1960점임', 1.0), ('배치고사끝냄', 1.0)],
#  [('1차끝나고한번더달릴테니', 1.0), ('2월말에', 1.0), ('실력닦아놔라', 1.0)],
#  [('잘한거임', 1.0)],
#  [('중간정도', 1.0)],
#  [('맘먹으면', 1.0), ('플래까진좁밥이다', 1.0)],
#  [('2500만들고와라', 1.0), ('최소', 1.0)],
#  [('무지', 1.0), ('이미', 1.0), ('넘음', 1.0)],
#  [('망함', 1.0), ('이번시즌', 1.0)],
#  [('다', 1.0), ('배치고사', 1.0), ('짐', 1.0)],
#  [('이런', 1.0), ('같웅', 1.0), ('염보성', 1.0)],
#  [('염보성을알아', 1.0)],
#  [('스타충이네', 1.0)],
#  [('너는', 1.0), ('아는가', 1.0), ('어케', 1.0)],
#  [('프로도', 1.0), ('스타신임', 1.0)],
#  [('바름', 1.0), ('이영호도', 1.0)],
#  [('프로도', 1.0), ('뭐임', 1.0), ('종족', 1.0)],
#  [('색마임', 1.0)],
#  [('색꺄', 1.0), ('혼종이다', 1.0)],
#  [('혼헌', 1.0)],
#  [('오늘도', 1.0), ('편의점도시락', 1.0)],
#  [('않나', 1.0), ('그거', 1.0), ('완전', 1.0), ('창렬하지', 1.0)],
#  [('낫베드', 1.0), ('도시락은', 1.0), ('퀄리티', 1.0), ('편의점', 1.0)],
#  [('개춥네', 1.0), ('오늘', 1.0), ('근데', 1.0)],
#  [('난', 1.0), ('안면도임', 1.0)],
#  [('갓음', 1.0), ('블리자드', 1.0), ('시전하고', 1.0), ('여기는', 1.0), ('프로도신이', 1.0)],
#  [('프로도신', 1.0), ('오줌', 1.0), ('자제좀', 1.0)],
#  [('프로도신', 1.0), ('자제좀', 1.0), ('배설', 1.0)],
#  [('설사험', 1.0)],
#  [('진심', 1.0),
#   ('라이언이랑', 1.0),
#   ('목소리', 1.0),
#   ('있음', 1.0),
#   ('닮은애', 1.0),
#   ('데이식스에', 1.0)],
#  [('신기방기', 1.0)],
#  [('라이언은', 1.0)],
#  [('부름', 1.0), ('비슷하게', 1.0)],
#  [('구냥', 1.0)],
#  [('마', 1.0)],
#  [('담', 1.0)],
#  [('라이언은', 1.0), ('마스터임', 1.0), ('카마수트라', 1.0)],
#  [('Av배우', 1.0), ('괜찮을듯', 1.0), ('데뷔해도', 1.0)],
#  [('설마', 2.0), ('가끔', 1.0), ('일본가는게', 1.0)],
#  [('찍고옴', 1.0)],
#  [('다만', 1.0), ('브라질에서만', 1.0), ('판매함', 1.0)],
#  [('대단', 1.0)],
#  [('입수해야할듯', 1.0), ('하나', 1.0)],
#  [('그럴듯', 1.0)],
#  [('여러분', 1.0)],
#  [('소식이있습니다', 1.0), ('초대형', 1.0)],
#  [('들은준비되셨나요', 1.0)],
#  [('들을준비되셨나요', 1.0)],
#  [('이미', 1.0), ('아는사람이', 1.0), ('있을수도있지만', 1.0)],
#  [('우리', 1.0), ('임튜브씨가', 1.0)],
#  [('약대에합격하셨습니더', 1.0)],
#  [('고대는예비번호래', 1.0), ('붙고', 1.0), ('차의과대학은', 1.0)],
#  [('이제소환해', 1.0)],
#  [('굿', 1.0)],
#  [('힘내자프로도아', 1.0)],
#  [('사랑한다', 1.0)],
#  [('친구야', 1.0)],
#  [('그런의미로', 1.0)],
#  [('임즈소환하고', 1.0)],
#  [('굿', 1.0)],
#  [('방금', 1.0)],
#  [('굿', 1.0)],
#  [('확인해서지금', 1.0)],
#  [('미쳐잇는가봄', 1.0)],
#  [('소환할게', 1.0), ('좀이따전화하면', 1.0)],
#  [('프로도아', 1.0)],
#  [('집근처에', 1.0)],
#  [('3년을', 1.0), ('기다렷으니', 1.0)],
#  [('커피숍뭐있냐', 1.0)],
#  [('공부어디서하냐', 1.0)],
#  [('우리집', 1.0)],
#  [('커피숍천지지', 1.0)],
#  [('너', 1.0), ('공부어디서함', 1.0)],
#  [('난', 1.0), ('독서실이지', 1.0)],
#  [('아', 1.0), ('카페는잘안감', 1.0)],
#  [('독서실다니는데뭐하러감', 1.0)],
#  [('오호', 1.0)],
#  [('와이', 1.0)],
#  [('생겨나서', 1.0), ('우후죽순으로', 1.0), ('커피숍도', 1.0), ('한창유행탈때', 1.0)],
#  [('20개넘음', 1.0),
#   ('300미터', 1.0),
#   ('가본커피숍만', 1.0),
#   ('근방으로', 1.0),
#   ('우리집에서', 1.0)],
#  [('굿', 1.0)],
#  [('근데왜', 1.0)],
#  [('무지', 1.0), ('튜브', 1.0), ('invited', 1.0)],
#  [('앗', 1.0)],
#  [('어서와', 1.0)],
#  [('젠장', 1.0)],
#  [('하이루', 1.0)],
#  [('선수를빼았겼꾼', 1.0)],
#  [('그의', 1.0), ('드디어', 1.0), ('컴백', 1.0)],
#  [('잠깐', 1.0)],
#  [('이거', 1.0), ('왜케', 1.0), ('진동', 1.0)],
#  [('바이브레이터', 1.0)],
#  [('설정가야지', 1.0), ('심하지', 1.0)],
#  [('쑥스', 1.0)],
#  [('녀석', 1.0)],
#  [('그런것부터', 1.0), ('붙자마자', 1.0)],
#  [('준비하다니', 1.0)],
#  [('되엇굼', 1.0)],
#  [('허허', 1.0)],
#  [('Im', 1.0), ('back', 1.0), ('come', 1.0)],
#  [('굿굿', 1.0)],
#  [('고대도', 1.0), ('붙었으면', 1.0)],
#  [('근데', 1.0), ('나서', 1.0), ('내고', 1.0), ('예치금', 1.0)],
#  [('고대', 1.0), ('발표라', 1.0)],
#  [('드랍가믕', 1.0)],
#  [('아', 1.0), ('안되나', 1.0)],
#  [('내고', 1.0), ('예치금', 1.0), ('50만원', 1.0)],
#  [('붙으면', 1.0), ('고대', 1.0)],
#  [('머리쓰네', 1.0), ('이자식들', 1.0)],
#  [('50만원', 1.0), ('증발', 1.0)],
#  [('50만원과', 1.0), ('고대중', 1.0)],
#  [('그래더', 1.0), ('내야지', 1.0)],
#  [('어느것을', 1.0), ('이건가', 1.0), ('택하겠습니까', 1.0)],
#  [('고대지', 1.0), ('당얀', 1.0)],
#  [('무서운녀석들', 1.0)],
#  [('당연', 1.0), ('고대', 1.0)],
#  [('50갚지뭐', 1.0), ('알바해서', 1.0)],
#  [('그래도', 1.0), ('맘편해서', 1.0), ('정말다행임', 1.0)],
#  [('카톡', 1.0), ('신기하네', 1.0)],
#  [('이제', 1.0), ('핸드폰도', 1.0)],
#  [('바꿔야지', 1.0)],
#  [('얼마만이냐', 1.0)],
#  [('갤3', 1.0), ('하고', 1.0)],
#  [('와라', 1.0), ('아이폰으로', 1.0)],
#  [('돈이', 1.0), ('일단', 1.0)],
#  [('잠만', 1.0)],
#  [('궁해', 1.0)],
#  [('이거', 1.0), ('합격하니', 1.0)],
#  [('다', 1.0), ('돈이라서', 1.0)],
#  [('미안해짐', 1.0)],
#  [('그래도', 1.0)],
#  [('그게낫지', 1.0)],
#  [('그치', 1.0)],
#  [('돈좀쓰면어때', 1.0)],
#  [('이녀석들', 1.0)],
#  [('붙었는데', 1.0)],
#  [('크으', 1.0)],
#  [('난', 1.0), ('안면도임', 1.0)],
#  [('꺄', 1.0)],
#  [('왜', 1.0), ('거기얔', 1.0)],
#  [('끌려갔네', 1.0)],
#  [('신입연수', 1.0)],
#  [('이하', 1.0)],
#  [('아하', 1.0)],
#  [('중', 1.0), ('타임', 1.0), ('펀', 1.0), ('해피', 1.0)],
#  [('개추우', 1.0)],
#  [('대낮부터', 1.0)],
#  [('역시', 1.0), ('어피치도', 1.0)],
#  [('되더니', 1.0), ('직장인이', 1.0)],
#  [('클라스가', 1.0)],
#  [('대낮부터', 1.0), ('펀타임이라니', 1.0)],
#  [('녀석', 1.0)],
#  [('허허', 1.0)],
#  [('Fun', 1.0)],
#  [('예스', 1.0)],
#  [('수줍', 1.0)],
#  [('enjoy', 1.0)],
#  [('eat', 1.0)],
#  [('하앍', 1.0)],
#  [('이제', 1.0), ('튜브이도', 1.0)],
#  [('페북', 1.0)],
#  [('페북은', 1.0)],
#  [('노노', 1.0)],
#  [('어차피', 1.0)],
#  [('되어있음', 1.0), ('입학하면', 1.0), ('하게', 1.0)],
#  [('그때가서', 1.0)],
#  [('일단', 1.0), ('하나하나', 1.0)],
#  [('해가야지', 1.0)],
#  [('왜', 1.0), ('가로지', 1.0)],
#  [('무엇보다', 1.0)],
#  [('개인정보', 1.0)],
#  [('소중한곳에', 1.0), ('잘쓰겠음', 1.0)],
#  [('허허', 1.0)],
#  [('♡', 1.0)],
#  [('하앜', 1.0)],
#  [('인증', 1.0)],
#  [('아', 1.0), ('오늘', 1.0), ('발표난', 1.0), ('애들', 1.0), ('잇는데', 1.0)],
#  [('못생김', 1.0)],
#  [('나만', 1.0), ('합격한거', 1.0)],
#  [('모르겟네', 1.0), ('아닌가', 1.0)],
#  [('냐일', 1.0), ('해야함', 1.0), ('행군', 1.0)],
#  [('설마', 1.0), ('30', 1.0)],
#  [('설마', 1.0), ('15겠지', 1.0)],
#  [('행군', 1.0), ('30키로', 1.0)],
#  [('30', 1.0)],
#  [('졸잼각', 1.0)],
#  [('군대야', 1.0), ('직장이', 1.0)],
#  [('어피치', 1.0), ('국정원임', 1.0), ('사실', 1.0)],
#  [('함', 1.0), ('뭔', 1.0), ('행군을', 1.0)],
#  [('튜브이랑', 1.0), ('드디어', 1.0)],
#  [('여행갈수있게되었군', 1.0)],
#  [('가면', 1.0), ('국내라도', 1.0)],
#  [('졸잼일듯', 1.0)],
#  [('굿', 1.0)],
#  [('부산쳐들어가지뭐', 1.0), ('아니면', 1.0)],
#  [('당연', 1.0)],
#  [('잘', 1.0), ('네오이가', 1.0), ('안내해줄거임', 1.0)],
#  [('간김에', 1.0), ('샤홍도보고', 1.0)],
#  [('흐흣', 1.0)],
#  [('그것도', 1.0), ('나름', 1.0), ('재밌을지도', 1.0)],
#  [('사실', 1.0), ('는', 1.0)],
#  [('일본이', 1.0), ('태국이나', 1.0)],
#  [('개쩜', 1.0)],
#  [('무지', 1.0), ('feat', 1.0)],
#  [('내가', 1.0),
#   ('그', 1.0),
#   ('녀가', 1.0),
#   ('붙은걸', 1.0),
#   ('아나', 1.0),
#   ('알아야하는데', 1.0)],
#  [('그뇬', 1.0)],
#  [('그', 1.0), ('년', 1.0), ('둘', 1.0)],
#  [('셋', 1.0)],
#  [('넷', 1.0)],
#  [('그뇬', 1.0), ('그뇬하고', 1.0), ('작년', 1.0), ('제작년', 1.0)],
#  [('둘', 1.0)],
#  [('굿굿', 1.0)],
#  [('둘', 1.0)],
#  [('그', 1.0), ('둘은', 1.0)],
#  [('먹음', 1.0)],
#  [('붙었을리가없음', 1.0)],
#  [('당연', 1.0)],
#  [('그뇬', 1.0), ('작년', 1.0), ('특히', 1.0)],
#  [('튜브이도', 1.0), ('조용히', 1.0)],
#  [('많이함', 1.0)],
#  [('강남에서', 1.0), ('공부중', 1.0)],
#  [('하앍', 1.0)],
#  [('성대', 1.0), ('자퇴라니', 1.0)],
#  [('개나이스', 1.0)],
#  [('굿', 1.0)],
#  [('기다려왔따', 1.0), ('이날만을', 1.0)],
#  [('닿음', 1.0), ('부모님과', 1.0), ('연락', 1.0)],
#  [('저녁에', 1.0), ('고기집', 1.0)],
#  [('하앍', 1.0)],
#  [('하앍', 1.0)],
#  [('고기가지고되나', 1.0)],
#  [('아', 1.0)],
#  [('지금', 1.0)],
#  [('난감한게', 1.0)],
#  [('고대붙음', 1.0)],
#  [('다른', 1.0), ('애들은', 1.0)],
#  ...]

# %%
# Author Topic Model 실행
if not os.path.exists("kakao(ATM)_model"):
    model = AuthorTopicModel(corpus=corpus, num_topics=4, id2word=dictionary.id2token, \
                author2doc=author2doc, passes=10)
    model.save('kakao(ATM)_model')
else:
    model = AuthorTopicModel.load("kakao(ATM)_model")

# %%
model.show_topic(0)
# Out:
# [('닥쳐', 0.00913352474795045),
#  ('오우', 0.006077150842656581),
#  ('핡', 0.005814291204809277),
#  ('넌', 0.004275330190804228),
#  ('그게', 0.003936329056179983),
#  ('찍', 0.003518902685383488),
#  ('됨', 0.0033362068393125244),
#  ('일단', 0.0031497496609154147),
#  ('가서', 0.0030418551056656984),
#  ('올', 0.002905564005796451)]
