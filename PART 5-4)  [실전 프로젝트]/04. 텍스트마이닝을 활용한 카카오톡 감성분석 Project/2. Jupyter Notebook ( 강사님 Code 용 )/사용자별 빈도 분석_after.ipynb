# %%
import pickle
from pprint import pprint
import pandas as pd

# %%
with open("data/cleaned_data.pk", "rb") as f:
    data = pickle.load(f)
    
data.reset_index(drop=True, inplace=True)
print(data.head())
print(data.info())
# Out:
#                Date User            Message
# 0  2017/01/01 20:32   무지  이거보면 왜 갓창정인지 알게된다
# 1  2017/01/01 21:40  어피치                창정헌
# 2  2017/01/01 22:19  어피치   라이언은 내일부터 연구실 출근
# 3  2017/01/01 22:20   무지          파티 하는거 아님
# 4  2017/01/01 22:39  프로도                헬파티
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162861 entries, 0 to 162860
# Data columns (total 3 columns):
# Date       162861 non-null object
# User       162861 non-null object
# Message    162861 non-null object
# dtypes: object(3)
# memory usage: 3.7+ MB
# None

# %%
users = set(data["User"])
users
# Out:
# {'네오', '라이언', '무지', '어피치', '튜브', '프로도'}

# %%
authors = data.groupby('User')
pprint(authors.groups)
print(type(authors.groups))
# Out:
# {'네오': Int64Index([   273,    274,    276,    277,    342,    374,    396,   3784,
#               3785,   3787,
#             ...
#             157425, 157427, 158059, 158060, 158062, 161067, 161068, 161074,
#             161075, 161080],
#            dtype='int64', length=324),
#  '라이언': Int64Index([     9,     14,     15,     18,     19,     24,     25,     26,
#                 30,     32,
#             ...
#             162840, 162843, 162844, 162845, 162846, 162849, 162850, 162852,
#             162854, 162860],
#            dtype='int64', length=39243),
#  '무지': Int64Index([     0,      3,      6,      8,     10,     11,     13,     16,
#                 17,     22,
#             ...
#             162815, 162816, 162820, 162822, 162830, 162834, 162836, 162839,
#             162841, 162842],
#            dtype='int64', length=47861),
#  '어피치': Int64Index([     1,      2,      5,      7,     12,     20,     21,     23,
#                 27,     28,
#             ...
#             162649, 162654, 162655, 162668, 162670, 162683, 162855, 162856,
#             162857, 162859],
#            dtype='int64', length=12705),
#  '튜브': Int64Index([   853,    854,    856,    861,    862,    863,    866,    867,
#                870,    871,
#             ...
#             162778, 162779, 162786, 162787, 162788, 162789, 162790, 162794,
#             162795, 162826],
#            dtype='int64', length=42258),
#  '프로도': Int64Index([     4,    204,    205,    242,    245,    246,    249,    251,
#                253,    255,
#             ...
#             162696, 162700, 162701, 162702, 162710, 162847, 162848, 162851,
#             162853, 162858],
#            dtype='int64', length=20470)}
# <class 'dict'>

# %%
author2doc = {}

for user, index in authors.groups.items():
    author2doc[user] = list(index)
    
print(author2doc)
# Out:
# {'네오': [273, 274, 276, 277, 342, 374, 396, 3784, 3785, 3787, 3791, 3793, 3799, 3801, 3803, 3805, 3808, 3809, 3811, 3813, 3816, 3819, 3820, 3823, 3826, 3848, 3849, 3850, 3851, 3855, 3857, 3862, 3870, 3873, 3874, 3889, 3890, 3892, 3897, 3901, 3905, 3911, 3929, 3934, 3936, 3937, 3938, 3943, 3947, 4418, 4419, 4427, 4429, 4436, 4437, 4438, 4440, 4444, 4445, 4451, 4452, 4454, 4458, 4461, 4462, 4464, 4472, 4474, 4480, 4482, 4484, 4490, 4491, 4493, 4495, 4498, 4500, 4501, 4502, 4504, 4506, 4508, 4512, 4515, 4518, 4520, 4521, 4527, 4532, 4536, 4541, 4543, 15741, 32226, 32227, 32231, 32233, 32234, 32236, 32253, 32256, 32260, 32261, 32264, 32267, 42185, 42188, 42189, 42192, 42197, 42208, 42286, 42289, 42290, 42291, 42293, 45199, 45202, 45208, 45209, 45227, 45228, 48740, 48741, 48742, 48743, 48748, 49663, 49665, 49668, 49669, 49671, 49673, 49675, 49677, 49694, 49697, 49699, 49701, 49702, 49705, 84101, 84102, 84107, 84108, 84111, 84114, 84118, 84120, 85304, 93097, 93098, 93100, 93101, 106745, 106833, 106834, 106835, 106836, 106848, 106849, 106851, 106854, 106857, 107477, 107478, 107481, 107482, 107485, 107490, 107491, 107492, 107495, 107633, 127860, 127864, 127866, 127871, 127872, 127882, 127884, 127887, 127893, 127896, 127898, 127907, 127911, 127914, 127925, 127927, 127934, 127935, 127941, 127945, 127948, 127960, 127962, 127968, 127974, 127976, 127983, 127992, 128000, 128011, 128024, 128026, 128035, 128040, 128051, 128053, 128060, 128064, 128068, 128073, 128077, 128080, 128081, 128089, 128091, 128092, 128097, 128098, 128099, 128100, 128104, 128106, 128109, 128111, 128113, 128117, 128121, 128123, 128127, 128130, 128133, 128136, 128138, 128139, 128143, 128144, 128145, 128149, 128150, 128153, 128157, 128159, 128160, 128164, 128166, 128167, 128174, 128176, 128180, 128184, 128188, 128189, 128196, 128197, 128202, 128206, 128211, 128212, 128213, 128215, 128217, 128219, 128222, 128225, 128227, 128232, 128234, 128236, 128239, 128244, 128247, 128248, 128249, 128250, 128252, 128254, 128255, 128261, 128262, 135779, 135780, 135785, 135787, 135793, 136902, 145578, 145582, 145585, 145586, 145588, 145593, 145594, 145602, 145612, 145613, 145614, 145616, 145619, 145621, 145622, 145624, 153790, 153792, 154227, 154253, 157413, 157417, 157419, 157420, 157424, 157425, 157427, 158059, 158060, 158062, 161067, 161068, 161074, 161075, 161080], '라이언': [9, 14, 15, 18, 19, 24, 25, 26, 30, 32, 35, 38, 40, 41, 43, 45, 46, 47, 49, 51, 52, 56, 58, 60, 62, 63, 66, 75, 76, 81, 82, 87, 92, 93, 100, 107, 147, 148, 149, 155, 156, 157, 161, 162, 163, 165, 166, 168, 169, 170, 171, 174, 175, 176, 178, 179, 181, 183, 185, 186, 189, 192, 193, 196, 197, 198, 199, 202, 203, 212, 234, 235, 238, 265, 266, 267, 270, 271, 286, 287, 290, 292, 319, 320, 323, 324, 325, 327, 329, 330, 333, 336, 337, 338, 340, 345, 346, 349, 350, 353, 355, 359, 362, 363, 364, 366, 367, 368, 369, 375, 378, 382, 383, 384, 385, 386, 387, 388, 395, 397, 399, 400, 401, 404, 405, 410, 416, 417, 422, 424, 427, 430, 431, 432, 437, 438, 439, 468, 479, 507, 508, 516, 517, 519, 520, 521, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 535, 536, 537, 538, 540, 541, 543, 544, 545, 546, 547, 549, 550, 553, 554, 559, 564, 569, 570, 573, 578, 619, 622, 623, 626, 627, 633, 636, 639, 642, 643, 651, 652, 654, 655, 656, 657, 658, 660, 661, 663, 664, 665, 666, 686, 690, 692, 693, 695, 696, 697, 700, 713, 722, 723, 730, 731, 737, 738, 743, 744, 747, 748, 749, 750, 808, 809, 810, 811, 812, 813, 814, 815, 817, 818, 819, 820, 823, 824, 826, 827, 828, 829, 830, 832, 833, 836, 838, 840, 844, 847, 849, 851, 852, 855, 857, 858, 859, 860, 864, 865, 868, 869, 872, 874, 876, 878, 879, 880, 881, 883, 884, 886, 887, 894, 895, 897, 899, 900, 903, 904, 905, 910, 911, 912, 913, 914, 915, 918, 920, 921, 923, 924, 927, 928, 933, 934, 935, 938, 941, 945, 946, 948, 949, 951, 953, 954, 955, 956, 958, 959, 960, 961, 963, 964, 965, 966, 967, 970, 971, 972, 974, 975, 977, 979, 980, 982, 983, 987, 989, 993, 994, 998, 1003, 1004, 1005, 1008, 1019, 1026 ...

# %%
user1_msg = [str(data["Message"][idx]) for idx in author2doc['네오']]
user1_msg
# Out:
# ['오 튜브이 다 끝난건가',
#  '그날 늦게 까지 놀겠지',
#  '저녁때까지 확실히 갈수 있을듯',
#  '무지 여전한 팬더 사랑',
#  '어피치는 몇시에 와',
#  '먼저 점심먹고 있으면 바로갈게',
#  '출발했습니당',
#  '튜브 자취 라이언에게도 물어보고 학교 선배들 연락닿는 사람있으면 물어봐서 주변 시세나 학교다니기 편한 곳 물어보면 좋음',
#  '애들 많이 사는 곳도 물어보고 그리고 집은 아직도 직접 발품파는게 최고인듯',
#  '하지만 자취는 진짜 돈 많이 깨진다는거',
#  '거기 긱사랑 월세 시설은 잘 모르지만 긱사가 저렴하지',
#  '긱사살면서 주변에 동기있으면 학교 정보도 더 잘 주워듣고',
#  '근데 또 막상 2학기 부터 집구하는건 좋은방이 없음',
#  '그냥 부동산가서 물어봐도 시세 알려줄듯',
#  '자취하고 싶으면',
#  '나는 긱사 추천인데',
#  '당연히',
#  '학교근처',
#  '웅웅',
#  '아하 그럼 아직 알게된 선배는 없는거지',
#  '주변시세랑 긱사 어떤지 선배한테 듣는게 최고이긴 한데',
#  '굳 아마 포천이라도 학교 근처라 방들 비싸지 않을까',
#  '긱사 시설 양호하다면 난 긱사 추천',
#  '웅웅  나중에 맘 바뀌면 자취로',
#  '그런방법이',
#  '긱사마다 다름',
#  '보통 침대랑 책상은 잇음',
#  '이불은 없음',
#  '몇인실이야',
#  '튜브 상대방이 코골면 어때',
#  '긱사에 높은 확률로 코골이 잇을듯',
#  '와 엄청 세세하네',
#  '우선 약대끼리 기숙사면',
#  '룸메이트는 편할확률 상승함',
#  '스케줄도 같아서 서로 안불편할 확률이 높아',
#  '그럴수 잇음',
#  '긱사마다 달라',
#  '근데 약대 긱사는 없을듯',
#  '긱사마다 다름',
#  '보통 종합대 긱사는 통금 잇는데',
#  '의대 약대는 통금 잘 없을걸',
#  '진리임',
#  '포천 병원이 종합대 캠퍼스 근처야',
#  '웅웅',
#  '아하',
#  '수업은 포천에서 하구',
#  '엘에이',
#  '우선 낼모레 학교에 전화에서 긱사 약대끼리만 쓰는거 맞는지 물어보는게 좋을듯',
#  '오 신기',
#  '어피치야 첫정장 구두 갈색이어도 되지',
#  '브라운이어도 단정한거 맞나',
#  '요즘 구두 검은색이 넘나 많이 나와',
#  '웅웅',
#  '괜히 교수님 만나니까',
#  '걱정되서',
#  '땡스땡스',
#  '바로 유급',
#  '1년 더쉼',
#  '오 진짜 그랫음',
#  '굳',
#  '바로',
#  '정신과로 입원할듯',
#  '그자리에서 입원',
#  '갈색이나 검은색하려구',
#  '정장은 이미 맞췃어',
#  '단정한걸로',
#  '예과때 쓰던 거 너무 거만색이라  멀리서 보면 검은 색인데 가까이 서 보면 투톤인걸로',
#  '새로 삼',
#  '투톤많이 나온다더라',
#  '나 이제 실습이라',
#  '정장 입고 다녀야해서',
#  '가운과 정장',
#  '진짜 오래걸림',
#  '여기까지 오는데',
#  '그래도 됨',
#  '가운 벗기고',
#  '정신과로',
#  '그럼',
#  '동기들이',
#  '문진해줄듯',
#  '신문에 나올듯',
#  '의대 입학 제대로 시키라고',
#  '맞어',
#  '그렇다더라',
#  '그러게',
#  '그사람은 손해본게 없음',
#  '쓰레기임',
#  '그니까',
#  '그냥 정시 시스템 자체에',
#  '그런거 거르는게 없으니까',
#  '수능보고 접수하면',
#  '컴퓨터가 합격시켜줌',
#  '무지 祝你生日快乐  맛난거 많이 먹고 담에 보쟝',
#  '휴 이번주는 좀 나은편인데  병원에서 나가지를 못하네',
#  '맨날 병원에 있음',
#  '난 다행이 오늘 교수님 휴가라',
#  '평소에 병원 기숙사에서 새벽에 출근하고 할일하고 과제하면 하루 끝남',
#  '이게 의사의 삶인듯',
#  '무지도 홧팅',
#  '서울왔는데 만나지를 못하네',
#  '나두',
#  '결코 할만하지 않은듯',
#  '나 고3때보다 시간 없는거 같은데',
#  '근데 이번주는 교수님 휴가라 좀 나아',
#  '나 여기서 아직도 병원 밖에서 지하철 가는 길밖에 모름',
#  '일산 지금 꽃박람회 하던데',
#  '휴',
#  '힘들다',
#  '가끔 보고 있음',
#  '노래도 듣구 있어',
#  '일산 전혀 모름',
#  '웨스턴돔 갔다 호수공원 나쁘지 않음  꽃도 피고 공원 예뻐',
#  '기회되면 박람회도 슬쩍',
#  '아 거의 24시간 병원에 살고 있음',
#  '주말에만 집오고',
#  '옙',
#  '카페왓슴',
#  '밥먹고 병원가야지',
#  '웅웅',
#  '농구장 앞에 카페에 있엉',
#  '프로도이 어피치 담에 봐 가끔 주말에 식사라도 간단히',
#  '아마 담달 주말에는 좀 나을듯',
#  '공지',
#  '다들 축하해요',
#  '어피치는 나중에 한강 밤도깨비 데이트 하셈',
#  '추천함',
#  '잉 그런가',
#  '2시반 순대국',
#  '진호도 옴',
#  '순대국먹고 갈까',
#  '낮부터',
#  '웅웅',
#  '갈게',
#  '굳',
#  '나도 2시 반까지 감',
#  '오 멋짐',
#  '퍼듀는 어디에 있음',
#  '중부인가',
#  '오호',
#  '어피치 어디야',
#  '튜브이 약대 다닐만해',
#  '육주동안 성추행범이 교육담당하고 있는과 상대하느라 너무 피곤했다',
#  '오늘 모임',
#  '많이배웠음  또잘가르킴',
#  '아하',
#  '응징 못함 낙하산임',
#  '진호는 대학원 생활중이야',
#  '내년부터',
#  '내년 언제 입학함',
#  '여러분 감사합니당  어제 답장을 못했넹 어제도 셤 쳐서 다들 너무 고맙구 이번 겨울에 올라가는데 그때 또 다같이 모이자 시간나면 짧게 놀러가는 것두 좋구',
#  '해피뉴이어\n다들 새해복 많이 받고  올해도 다들 건강하게 보내고 원하는 일 많이 이루길',
#  '이번 겨울에는 언제 모이기로 했어',
#  '나어제부터 방학했음',
#  '일월초에 보쟝',
#  '목요일날 방잡고 노는거임',
#  '나도 받고싶음',
#  '벌써 개강 3주차당',
#  '목욜날 다 오는거야',
#  '설마 담주 목욜인가',
#  '내가 이거무서워서',
#  '근황을 못올리겠음',
#  '진호 사진첩',
#  '올 근데 다들 설때 멀리 안가나보네',
#  '좋다 가까운게 좋지',
#  '서울 왔는데 아빠 허리 다치셔서 오늘 수술하는 날이라 저녁 늦게즘에 갈게',
#  '저녁때정도',
#  '꼭가기는하겠음',
#  '우선 수술끝나는거 보구 갈겡',
#  '수술 점심때 하시니까 상황보구나서 갈겡',
#  '아아 그래서 부산 안내려가신 거구나',
#  '라이언이 아버님도 잘 쉬셔야겠네',
#  '암튼 되는데로 바로 안양으로 갈겡',
#  '웅웅 고마워 튜브아',
#  '코노에 있음 아이온 맞은편',
#  '무슨얘기지',
#  '학교 생활 너무 지친다',
#  '뮌뎅',
#  '아',
#  '성공했엉',
#  '웅웅',
#  '스벅이 그 얘기였군',
#  '웅웅',
#  '웅웅',
#  '구엽당',
#  '웅웅',
#  '그게 카페 알바녀군',
#  '웅웅',
#  '웅',
#  '아항',
#  '웅',
#  '크',
#  '웅웅',
#  '그래서 프사도 스벅이군',
#  '웅웅',
#  '웅웅',
#  '역시',
#  '웅웅',
#  '웅웅',
#  '아하',
#  '그러게',
#  '아무도 모르겠네',
#  '아쉽',
#  '더 좋은사람 만날거임',
#  '프로도인 안질른거 아님',
#  '튜브이 쥐깠네',
#  '무섭다',
#  '난 사람깠음',
#  '쥐가 더 무서움',
#  '헐',
#  '대단쓰',
#  '라이언이 요즘 논문써',
#  '힘들겠네',
#  '몇편써야 졸업이야',
#  '아아 그래',
#  '하나쓰면 바로 졸업해',
#  '일년은 꼭채워야하지',
#  '일년안에 안되겠지만',
#  '아항 그렇구낭',
#  '교수님들',
#  '학생 부려먹어야지',
#  '지금은 바로 던트갈생각',
#  '거의 타임머신일듯',
#  '병원 들어가서 정신없이 일하고 나오면 몇년 지나 있을거 같은데',
#  '나중에 부산에서 있게되면 몇년뒤에 부산 다시 놀러와',
#  '예전보다 비싼거 먹으러가자',
#  '인턴도 부산일수도 있어',
#  '그래도 한 3년차 정도부터는',
#  '여유있으니까',
#  '아 병원은 내가 선택이야',
#  '근데 부산병원이 정도들고 부산도 나쁘지 않아서 고려중',
#  '웅웅 수술과 생각중인데 아직 정해진건 없으니까',
#  '부산좋아  나중에 부산에서 보면 좋은데가자',
#  '크게 수술과 비수술과 나눠서',
#  '보거든',
#  '내과계열 외과계열이라고 하지',
#  '웅웅 정형은 수술이고',
#  '내과도 빡세',
#  '수술은 안빡센데가 적긴하지',
#  '재활 마취 이런데가 좀 낫고',
#  '웅웅 적성은 좋아',
#  '아무래도 책만 보는것 보단 재밌는데',
#  '바쁘니깡',
#  '그랬으면',
#  '이학기정도에 다시 다 같이 모이자',
#  '웅웅',
#  '방학없엉',
#  '웅웅',
#  '방학기대할 나이는 지났지',
#  '우린',
#  '없엉',
#  'cc좋지',
#  '안깨지면 최고고',
#  '깨지면 최악이지',
#  '의대선 더욱',
#  '맨날봄',
#  '웅웅',
#  '웅웅',
#  '더 좋은사람만나',
#  '여자는 많으니까',
#  '대학원도 끊내고 직장 얻으면 더 기회는 많을거야',
#  '그때까지 외롭겠지만',
#  '지금도 어린애 아니면 여자는 결혼 원할걸',
#  '튜브이',
#  '봤음',
#  '장기가 너무 귀여움',
#  '쥐는 징그럽고',
#  '장기는 미니어쳐임',
#  '생각해보니 쥐 심장은 봤었다',
#  '그러자',
#  '나 구월달에 셤볼수도 있는데',
#  '그럼 유월에 보던가 끝나고 봐야할수도',
#  '실기가 부담이 큼',
#  '웅웅',
#  '개빡셈 실기',
#  '부산에',
#  '내방이 없엉',
#  '내가 올라갈겡',
#  '4년뒤에 오면 좋은 방잡고 놀자',
#  '부산은',
#  '웅웅',
#  '아쉽',
#  '서울은 방없어도 귀가 가능하니까',
#  '자는것도 재미겠지만',
#  '송은영 결혼식 가는분들 내일 안양 몇시에  도착예정임',
#  '근데 진호는 공무원 준비한다고 사라진건가',
#  '일찍가네  솬이도 그때가',
#  '가서 라이언이 있는데로 갈겡',
#  '그랭그랭',
#  '프로도 축하축하축하',
#  '다들 새해복 많이 받아  원하는 일들 다 잘되길 바랄게',
#  '아니  그냥 공부중이야',
#  '이길은 평생공부인듯',
#  '담번에 보내줄게 진호',
#  '다들 홧팅하장',
#  '웅웅 이제 9일 남았다',
#  '웅웅 모두 홧팅하장',
#  '끝나고 곧보자 안양이나 평촌에서',
#  '화곡은 좀 멀긴하다',
#  '화곡은 다음 기회라도 꼭 고고할게',
#  '아님 중간즘 어디도 좋음',
#  '그럼 안양',
#  '웅웅  시간 빠르다',
#  '웅웅 이런것 있음',
#  '😀😀',
#  '진호도 새해복 많이 받고 좋은 일 많이 생기길',
#  '소정이 결혼식 갈것 같은데 식전이나 식후에 식사나 커피하실분',
#  '진호는',
#  '나도 슬렉스에 흰셔츠 입을려고',
#  '라이언이 어디야',
#  '빨리 수련 끝나고 싶다',
#  '5년뒤에 끝나지 정확히는 4년반',
#  '인턴하고 던트 못되면 군대먼저',
#  '아마도',
#  '재워줄수는 있는데 나 없는 집에서 자야할수도 있음',
#  '시간 잘 맞춰서 인계없고 당직없는 주말에 오면 제일 좋음',
#  '굳굳',
#  '하하',
#  '집 결정했나보네 축하행',
#  '어피치 결혼식도 곧이네',
#  '그거 청년경찰들임',
#  '병원안에서 누가 난동부리면 제압',
#  '진짜경찰은 아님',
#  '그냥 청년경찰이라 부르드라',
#  '아 그런건가  몰겠네']

# %%
import nltk

total_tokens = [token for doc in user1_msg for token in doc.split()]
print(len(total_tokens))
# Out:
# 998

# %%
text = nltk.Text(total_tokens, name='NMSC')
print(len(set(text.tokens)))
pprint(text.vocab().most_common(10))
# Out:
# 774
# [('웅웅', 30),
#  ('많이', 9),
#  ('있음', 7),
#  ('다들', 7),
#  ('근데', 6),
#  ('잘', 5),
#  ('더', 5),
#  ('긱사', 5),
#  ('바로', 5),
#  ('너무', 5)]

# %%
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

plt.figure(figsize=(16, 10))
text.plot(50)

# %%
from wordcloud import WordCloud

wc = text.vocab().most_common(100)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(dict(wc))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
def user_freq_analysis(username, data, author2doc):
    
    user_msg = [str(data["Message"][idx]) for idx in author2doc[username]]
    total_tokens = [token for doc in user_msg for token in doc.split()]
    text = nltk.Text(total_tokens, name='kakao')

    #pprint(text.vocab().most_common(10))
    path = "c:/Windows/Fonts/malgun.ttf"
    if platform.system() == 'Darwin':
        rc('font', family='AppleGothic')
    elif platform.system() == 'Windows':
        font_name = font_manager.FontProperties(fname=path).get_name()
        rc('font', family=font_name)
    else:
        print('Unknown system... sorry~~~~')

    plt.figure(figsize=(16, 10))
    text.plot(50)

    wc = text.vocab().most_common(100)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
    wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
                          relative_scaling = 0.2,
                          #stopwords=STOPWORDS,
                          background_color='white',
                          ).generate_from_frequencies(dict(wc))
    plt.figure(figsize=(16,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
user_freq_analysis("무지", data, author2doc)
