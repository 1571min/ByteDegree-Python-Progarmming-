# %% [markdown]
#  #  Byte degree 미니 프로젝트
#  ## Daum 영화 제목 및 댓글 크롤링

# %% [markdown]
# ### 문제
#     - https://movie.daum.net 에 접속하여 본인이 좋아하는 영화를 선택합니다.
#     (1) 메인 Tab에서 영화 제목을 크롤링 합니다.
#     (2) 평점 Tab에서 영화 댓글을 크롤링 합니다.
#
# ### 조건
#     (1) 각 크롤링은 함수을 만들어 호출하는 형태로 작성한합니다. (영화 제목과 댓글 총 2개의 함수가 만들어져야 함)
#     (2) 영화 제목 크롤링 함수는 인자값으로 영화 ID를, 댓글 크롤링 함수는 인자값으로 영화 ID와 최대 page 수를 받을 수 있어야 합니다.
#     (3) 댓글 크롤링 후 최종 결과는 댓글의 Value 만 크롤링 되어야 하며 불필요한 HTML 테그가 결과에 포함되어서는 안됩니다.
#     (4) 만약 댓글의 전체 page 수가 함수에 인자로 지정한 최대 page 수 보다 적게 존재하는 경우는 이를 체크하여 크롤링을 멈춥니다.
#         (e.g. 함수 인자에 최대 크롤링 page를 100으로 지정했다 하더라도 실제 크롤링 대상 page가 10개만 존재한다면 크롤링 멈춤)
#     (5) 모든 작성은 jupyter notebook에서 하며 수행 결과를 포함시켜 ipynb 확장자 파일로 제출합니다.
#
# ### 추가 hint
#     (1) 영화의 댓글은 get 방식으로 page 별로 호출 할 수 있습니다. (page는 1부터 시작)
#     (2) BeautifulSoap의 find_all을 활용하면 리스트로 반환된 결과를 len 함수를 통해 개수를 확인할 수 있습니다.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 영화 메인 정보 크롤링 함수 (메인 Tab)

# %%
def get_daum_movie_title(movie_id):   # 체크 : movie_id를 받을 수 있어야 함
    url='https://movie.daum.net/moviedb/main?movieId={}'.format(movie_id)
    
    resp=requests.get(url)
    soup=BeautifulSoup(resp.text)
    
    title_tag=soup.find_all('strong.tit_movie')
    
    if title_tag:
        return title_tag.get_text()
    return ""

# %%
# 영화 메인 제목 크롤링 함수 호출
get_daum_movie_title('125368')
# Out:
# '해치지않아 (2019)'

# %%
## 크롤링 결과 확인
print(get_daum_movie_title('125368'))
print(get_daum_movie_title('126072'))
print(get_daum_movie_title('129100'))
# Out:
# 해치지않아 (2019)
# 닥터 두리틀 (2020)
# 나쁜 녀석들 : 포에버 (2020)

# %% [markdown]
# ### 영화 댓글 크롤링 함수 (평점 Tab)

# %%
## 영화 댓글 클롤링 함수
def get_daum_movie_comment(movie_id,maxPage):
    count=0
    for i in range(maxPage):
        url='https://movie.daum.net/moviedb/grade?movieId={}&type=netizen&page={}'.format(movie_id,i+1)
        resp=requests.get(url)
        soup=BeautifulSoup(resp.text)
        comment_list=soup.find_all('p',class_='desc_review')
        id_list=soup.find_all('em',class_='link_profile')
        commentNumber=len(comment_list)
        for r in range(0,int(commentNumber)):
            count+=1
            print(count,"개 ,",
                  id_list[r].get_text(),"님",
                  comment_list[r].get_text().strip(),end='\n\n')

get_daum_movie_comment(125368,100)
# Out:
# 1 개 , 감자 님 노잼...
#
# 많이 아쉽다 ㅜㅜ님 잔잔한 웃음과 감동이 있는 영화!지만
#
# 3 개 , 쿠킹맘 님 영화보고. 동물원.에. 있는.  동물둘한테. 미안해진영화네요.   이제. 동물원. 못갈거. 같아요
#
# 4 개 , 최지영 님 생각  없이 가서 잘 웃고왔어여
#
# 아무튼이래저래많이아쉬운 영홥니다선도를 잃은듯 보고왔습니다
#
# 6 개 , 여젤이를짜냥해 님 왜 난재미있던데 님들 돈아깝지않아요  그리고누가 영화를 현실성따지면서보나요 ㅎㅎ 영화는영화일뿐
#
# 7 개 , 아지 님
#
# 8 개 , 양정상 님 예고편이 전부인 영화 "북극곰이 콜라를 마시고.." 나머지 스토리는 너무 뻔한데로 흐르는데 그 이상의 재미가 없는 영화
#
# 9 개 , o키키o 님 핵노잼 대박 핵노잼ㅜㅜ
#
# 그냥 생각없이 웃고싶은 분들만 보세요 ㅋㅋ은거보니 맘찢..ㅋ
#
# 11 개 , 수선화 님 재미없다 ᆢᆢᆢᆢᆢㅠㅠ
#
# 영화는 부산행정도는 만들어라 극한직업/백두산이 흥행하는 한국영화가 너무 우울하다.
#
# 13 개 , Citizen 님 탈을 쓴다는게 너무 허황된게 아닌가~라는 생각을 시작으로 보았는데 생각보다 현실감도 있고 재밌었어요~~
#
# 14 개 , 우성1차 님 부담없이 가볍게 즐길 수 있는 영화
#
# 15 개 , 단다리 님
#
# 16 개 , 해피엔딩 님 제2의 극한직업이라고 봅니다.....
#
# 아이들이 보기 괜찮은 영화 님 너무 우려를 하고 봐서 그런가 볼만했다.
#
# 18 개 , 양심대로살자 님 B급 감성의 망작
#
# 19 개 , 오드리이쁜이 님 웃기다 그냥 웃으면서 보면된다
#
# 20 개 , Dyl 님
#
# 그래도 영화니까 괜찮습니다만에 잼있게 웃었습니다
#
# 22 개 , sangil 님 내용을 억지로 끼워 맞춘 말도 안되는 공감이 전혀가지 않는 영화이고 재미없네요.
#
# 23 개 , 상도폭주기관차 님 ...
#
# 24 개 , 블링크지우 님
#
# 그런데말이죠 해치지않아 기린 오랑우탄 북극곰은 닥터두리틀에도있네~~ ㅋㅋ
#
# 26 개 , 보라미 님 재미있게 보고 가볍게 나올 수 있었습니다~
#
# 27 개 , 바크 님 어른 들의 시선 으로 보기엔 다소 유치 하지만  그 속엔 인간이 지켜야야 도리 또한  있다
#
# 소소하게 재밌는 영화. 등장 인물들이 너무 전형적이어서 내용 전개가 뻔한 영화.
#
# 29 개 , 하얀그리움 님 잼있었어요
#
# 30 개 , 후토 님 노잼
#
# 31 개 , 김미란 님
#
# ㅜㅜ 내돈~~까비 아까비간에 나오고  싶었던영화
#
# 33 개 , vgqry 님 이것은 코미디가 아니야
#
# 34 개 , 이현아 님 완전 웃겨요  3대가 가서봤는데  다들 좋아했네요 오랜만에  가족들 즐겁게 즐긴영화였어요
#
# 영화보면서 이렇게 웃기는 처음같은데 간만에 허리끊어져라 웃었습니다
#
# 36 개 , song 님 자괴와 자위 사이에서 관객은 모욕된다.
#
# 극한은 억지스러운 웃음..음.빌 때 움..ㅎ들 데리고 괜찮게 봤습니다.
#
# 기대치 낮추고 코믹보다 그냥 킬림타임용으로 보시길
#
# 39 개 , 선녀 님 가족이 함께 재미있게 봤어요
#
# 밋밋함이 결말까지 이어지는 부분은 좀 아쉬운 듯 합니다.없던 것 같고....
#
# 이건 보는 분들의 시각차이인 듯 싶어요.~서로 상생하는데 저는 내용 전제적으로
#
# 42 개 , 영재서원맘 님 친구가 배꼽빠지게 웃었다해서 봤는데 도대체 그배꼽은 왜빠진걸까요~ㅠ 전너무잼없었어요~ 개인차가 이렇게 날수있을까요~ㅠ
#
# 과도한 액션이런거 없어서 좋앗구여 좋앗구요 머리 안아프면서
#
# 44 개 , 보령생수대리점입니다 님 개인적으로  전  웃으며 재미있게  보았어요
#
# 기대 안하고 보면 괜찮다 정도님 코미디가 맞나 싶을 정도로 안 웃김
#
# 킬링타임용으로 보시는 건 좋을 듯보지 마세요
#
# 47 개 , 구하리 님 전 별로
#
# 48 개 , Zo 님 아내가 나도 모르게 불면증을 고쳤대요.
#
# 싱겁고 싱거우니 싱거워서 싱거워라
#
# 50 개 , 우주최강 님 좋아요...볼만하다...평점낮은건  안보고 거짖평점한듯...
#
# 약간 콜라가 억지가 있는 부분이 있긴하지만 뭐...볼만했어요 저는
#
# 52 개 , Vash 님 평가 할게 없어요 너무나 보는 사람의 마음이나 영화내용을 너무나 해쳐 놓아서...
#
# 53 개 , naturalplan 님 연기를 못했다기보다 유머내공이 부족한 배우들 심지어 박영규씨도 못 살림
#
# 몰입도 안되고 웃긴부분도 없고~~~~~화중 최악일꺼같애요~ 스토리도 없구 재미도 없구~
#
# 55 개 , 가장귀한열매 님 롯데시네마에서는 싫어했을 듯 ㅋㅋ  콜라가....
#
# 56 개 , 안녕하세요 님 귀여운 재미가 있어요. 안재홍, 정봉이식 유머를 좋아하신다면 좋아하실들. 그러나 극한직업이나 엑시트가 얼마나 잘 만든 영화였는지 생각하게 되더라고요.
#
# 57 개 , 시간 님
#
# 58 개 , 맑고푸른하늘 님 아이들한테는 어떨지 몰라도 ,별로였음 .
#
# 59 개 , JEH 님 돈이아깝고 시간도 아깝고  메시지는 알겠는데 진짜~휴~  재미없는 코메디영화
#
# 60 개 , 필립권 님 화가 난다 이런 영화를 본 내 자신에게
#
# 아니다. 그냥 동물원을 가세요었을거 같음미없음
#
# 소소한 재미가 있어요 아이들과 보세요
#
# 63 개 , 모카 님
#
# 64 개 , 러브레볼루션 님 가족과 함께부담없이 즐길수있는  가족영화
#
# 65 개 , 장지원 님 까만코 보다가 같이 코~할 뻔...ㅜㅜ
#
# 66 개 , 코끼리아저씨 님
#
# 67 개 , 베개 님 소소하니 나름 재미도 있고 감동도 있는 좋은 영화였어요..
#
# 막내는 2학년이데 한번도 안웃었어요ㅡㅡ스토리도 그닥 완성도 낮은 영화인것 같아요 초등학생 아들들이나 관심 조금 있는 정도
#
# 69 개 , 촐촐로니하 님 마음 편히 웃으면서 보기에 좋은 영화. 소소한 재미가 있어서 좋았음.
#
# 70 개 , 정희자 님 웃음과 잔잔한 감동~♡
#
# 71 개 , Hellowyoon 님
#
# 72 개 , 터프송 님 4인가족이 같이 봤는데, 아들 딸 전부 재밌다고 하네요. 신파는 없고, 해피엔딩으로 마무리.
#
# 경쟁작이 없어 그나마 선방하는듯.설정 + 성공보다는 의리라는 뻔한 클리쉐.
#
# 74 개 , 동원 님 잼나게보신분들은 득뎀한거고  잼없게보신분들은 안됐지만 고생하셨어요, 다행히난꿀잼.
#
# 75 개 , 그대맘내맘 님 이걸 재미없다는 사람은 매사 부정적인 사람이 많을듯ㅋㅋ넘 웃겨서 콜라먹다 채했음
#
# 후반부로 갈 수록 몰입감이 있어 재미있게 봤어요! 있을거라고 상상을 못한다라며
#
# 77 개 , 잽이 님
#
# 너무 편하고, 재미있게 본 영화^^보없이 봤던 영화. 하지만
#
# 79 개 , 교통카드 님 간만에 유쾌하게 우스며 본 영화네요. 좋았어요.
#
# 80 개 , 서주인테리어필름 님 나무늘보 때문에 많이 웃음...^^
#
# 81 개 , 네잎클로버 님 가볍게 웃고 왔습니다^^
#
# 82 개 , 호현레이저 님
#
# 83 개 , 홍만식 님 재밌지 않아~~
#
# 84 개 , 손애영 님 헉~~감동도 스릴도 액션도 코믹도 없는 영화~~
#
# 85 개 , 호공 님 잼있게 봤어요
#
# 86 개 , 도리야끼 님
#
# 제점수는8점입니다바다 님 평점 넘낮은거같아요
#
# 88 개 , 으이오 님 재밌던뎈ㅋㅋㅋㅋ나무늘보가 킬링이었다
#
# 89 개 , 맹은자 님
#
# 90 개 , 돌체비타 님
#
# 91 개 , Quss05 님 보는 동안 작은 감동느끼는 영화
#
# 92 개 , louis 님 영화내용이 자극적이지 않으면서도 웃으면서 볼 수 있는 영화.
#
# 93 개 , 무량 님 칠십,년대  쥬라기 공원!
#
# 94 개 , 어잉 님 무거운 주제를 무겁지 않게 잘 다루어주었고 결말까지 괜찮다. 거기에 가미된 유머코드는 우리에게 선보이는 소중한 선물.
#
# 티비로 특선드라마 수준....관에서 볼 정도는 아님
#
# 96 개 , 알드 님 별로라는사람은 문제의식이 없는거지.. 진짜 코미디도 신경쓰면서 사회문제를 잘 다뤘어요
#
# 동물 탈 쓰고 처음 나왔을때 얼마나 웃기던지...많이 웃었습니다.
#
# 98 개 , 빗방울 님 아이들과 웃으면서 재밌게 봤습니다.
#
# 99 개 , 가츠 님 아무리 코미디 영화지만 너무 성의 없게 만들었네. 닥터두리틀 보려다가 한국영화 본다고 선택했는데 후회가 좀 되었음.
#
# 100 개 , 신생살이 님 잼난다
#
# 101 개 , 이영재 님
#
# 102 개 , 대전 님 재미가없었습니다.. 너무지루해서 여자친구하고 폰만 만져댔네요..ㅎㅎ
#
# 103 개 , 현승 님 흠 괜찮던데 참신하고 ..
#
# 104 개 , UIIA 님 참신하고 재밋는 영화, 동물의 관점에서 생각해볼 수 있다는 문제의식이 있는 영화네요. 별로라는 사람들 글쎄요.
#
# 105 개 , 권오연 님 그냥 vod나오면 가족 다들 모였을때 5500원 내고 보면 돈 생각 안날 정도의 영화.
#
# 전체적으로 참신한 소재에 웃긴 장면도 많고 나름 생각할 거리를 주려는 시도도 마음에 들었어요! 재밌게 보고 갑니다 흥하세요~로 괜찮았어요 ㅎㅎ 스토리가 유치한 부분?도 있었지만,
#
# 107 개 , 쌍둥이 님 재미나게 봤어요 ~~
#
# 연기도 매우 훌륭했슴다~~~♡♡♡회고발성도 적당하게 있는 좋은 영화입니다~
#
# 109 개 , 수호천사 님
#
# 마무리에 힘이 너무 빠지는 경향은 있지만 부담없이 볼 수 있는 가족영화입니다. 너무 낮은 평점이 많아 균형 맞춥니다.
#
# 111 개 , 이장균 님 그냥 킬링타임무비 어린아이가 있다면 보시면 좋아요
#
# 112 개 , 동면모드 님 한국 영화계갖어쩌다 이렇게 됐을꼬. 보통 좌익정권하에 좋은 영화들이 많이 탄생되는데 작금의 영화계는 진짜 절망이다. 2000년대 초반이 그리워
#
# 113 개 , 마도로스 님 닥터 두리들처럼 특수 효과할 돈은 없고, 동물 옷 입고 싼 제작비로 어떻게든 흥행대박 노려본다???
#
# 114 개 , 키리 님
#
# 115 개 , 자유인 님 아주 큰 기대 안하면 볼만함. 통신사 쿠폰으로 할인 안받고 보면 좀 억울하게 느낄순 있음.
#
# 116 개 , cat 님 재미있어요
#
# 117 개 , 코끼리 님
#
# 한참 웃었어요 박미라 님 재밌어요  자극적이지 않고 편안하게 보면서  웃겨요
#
# 119 개 , 이쁜이 님 저도  재밌게 봤어요  특히  엔딩씬에선  웬지  뭉클함도 ᆢ
#
# 120 개 , 이호은 님
#
# 기분 잡치니 한 달 뒤 티비로 보시길.풋한 스토리는 시궁창에..
#
# 졸라 재미읍써~~~ 님 자다가  깜짝  놀라 깼다
#
# 123 개 , 인바이브 님 아이들과 어르신들이 많이 깔깔거리기는 했지만 내용은 글쎄....
#
# 124 개 , 뜬구름 님 재밌었어요~  저런 리조트 있었음 좋겠다는 생각과 함께~  아이와 재미나게 봤어요
#
# 125 개 , 가을비 님 재밌어요
#
# 126 개 , 별그대0000 님 재밌음. 인간과 자연이  공존할 수 있는 모습을 보여주고 싶었던것같음
#
# 127 개 , 임정욱 님
#
# 128 개 , 박은미 님 재미있어오 보시고 판단하세요  남편과 봤어요
#
# 129 개 , Nayah 님 아이들과 재밌게  봤어요   잔잔하게 웃을수있는 영화에요
#
# 130 개 , 늘잘노력하자 님 좋아요
#
# 131 개 , 뿌루루후 님 최..악 입니다..
#
# 할때마다 빵빵 터졌어요.~~하고처럼 툭툭 던지는 대사들이
#
# 133 개 , marineboy 님
#
# 134 개 , 지터 님 소소한 웃음에 비해 너무 많이 포기한 개연성
#
# 135 개 , 나노미 님 유치한데 웃김 ~^_^
#
# 광고보고  봤어요일콤프레샤 님 안재홍
#
#  그러나 웬지 모르는 공허함이랄까.. 빈 구석들이 보이는 느낌도 있었던게 아쉽긴 했으나 그런대로 편하게 관람 했어요 ~~
#
# 138 개 , 트렌실베니아 님 좋아요
#
# 많이 웃었습니다좋은하루 님 평점이 낮아 보여 10점 줍니다.
#
# 140 개 , 댄디 님 돈아깝고시간아깝고 그런영화~~^^
#
# 141 개 , 예륨 님
#
# 142 개 , 김희동 님 아이하고 재미있게 봤어요
#
# 143 개 , 그저오늘을산다 님 지금 세식구 보고 왔는데 .. 대사 연기 .. 시동 닥터두리틀 이 영화 이렇게 최근 봤는데 요새 한국 영화가 더 낫네요
#
# 144 개 , ahoahoaho 님 아이들하고 같이 보세요.
#
# 145 개 , 호냐냐 님 너무 별로였어요
#
# 146 개 , 예쁜풍경 님
#
# 147 개 , 킹콩 님
#
# 12세 이상이 아니라 12세 이하 수준 봄
#
#  함께보면 너무 좋을것같음 억지웃음없이 웃어서 힐링했음같아 자녀있는 분들은음이 나오긴했지만
#
# 150 개 , 블루스카이블루씨 님 영화좀 성의있게 만듭시다
#
# 151 개 , kjshca 님 넘 재미 없다
#
# 152 개 , ccrg 님 까만코가 그래서(동물원에 온 사람들이 페트병, 돌 등을 던지고 괴롭혀서) 이상해졌다라는 대사 공감
#
# 153 개 , saint 님 너무 현실적+감동적으로 결말을 내려다 보니 후반부엔 재미가 떨어지네. 콜라 마시는 곰 계속 하지
#
# 154 개 , 사람 님 보는 동안 즐거웠습니다. 좋은 영화의 기준은 여러가지 일수 있는데 초등학생 아들과 함께 재미있게 봤으니 이 또한 훌륭한 영화라고 생각해요
#
# 155 개 , 수채화 님 초등학생  수준의  코미디. 북금곰이  코카콜라  먹는  장면은  재밌었다.  훈훈한  마무리도  좋았다.
#
# 가족영화로 좋습니다.님 팩드가 몇번있었음 대박였을텐데.약해요ᆢ전개와 흐름이ᆢ
#
# 157 개 , 까미 님 그냥 저냥
#
# 좀 성의있게 시나리오를 쓰면안되나요런영화를 만들다니~
#
# 159 개 , 바다라니 님 정말 재미있게 봤습니다. 굿굿
#
# 160 개 , 이주용 님 가족끼리 보기 좋아요!
#
# 161 개 , 캐띠 님
#
# 162 개 , rora 님 유쾌하면서 나름의미 있는 영화
#
# 163 개 , 건스맘 님 초딩 아들이 잼있었다네요^^전  스토리가  좀 아쉽긴했어요~편의점  나쁜놈 벌받아야됐었는데~^^잘봤습니다^^
#
# 164 개 , 블루베리 님 올해 앞으로 볼 영화 통틀어서도 최고일듯싶다.. 잘봤습니다
#
# 동물 사람 그리고 내가했던일을억지고 무엇이고를 떠나서
#
# 166 개 , 스누피브라운 님 그냥 후하게 줄래
#
# 167 개 , 심연규 님
#
# 배우들의 대사들에 기대했던 재치는 없었다영화 중 가장 별로
#
# 169 개 , 채종산 님
#
#  웹툰 원작을 너무 각색해버려서 원작의 향기가 나질 않아 아쉬웠음...좀 웃었지만..
#
# 171 개 , 형이꽁주 님
#
# 강변호사 열정 멋져요~~ 코믹하고 재미있었어요. 요즘 열정없이 사는 나를 생각할수 있는 영화기도하였어요
#
# 173 개 , Mr김칫국 님 큰 웃음 없지만 간간히 터지는 소소한 웃음의 드라마틱한 영화
#
# 오늘 영화보다 잤다억지 설정 덩어리. 했는데 웃음코드도 별로
#
# 175 개 , 자연과함께 님 딸들과 아내와 함께 웃고 즐기는 시간을 보냈습니다. 동물과 사람에 대해 다시한번 생각을 하게 만드는 재미있는 영화 입니다.
#
# 176 개 , yoonjinseon 님 마냥 웃긴것만은 아닌 영화. 남편은 지루해했지만 초등 중등 아이들이 재미있어했어요.
#
# 177 개 , 잉여인간 님 지루한 구석은 많았지만 웃긴부분은 있었고 몰입감도 있었다
#
# 178 개 , 즐산 님 인간과 동물의 공존을 위한 소동극 ..  재밌었어요 ~^^
#
# 짱짱한 상태에서 영화를 봤다......고 메이져영화라도 나는 재미없으면 잠을잔다.
#
# 180 개 , 베르세르크 님
#
# 내 돈~~ , 메리엘 님 재미가 참 없네요~~  어디서들 그리 웃으셨을까요?
#
# 182 개 , 유가희 님
#
# 183 개 , 바람의전설 님 한국영화 문제다 문제 이것도 영화라고 개봉했나 진짜 내 생에 최악의 영화다18  돈 물어도
#
# 184 개 , 쥬 님
#
# 강추합니다!, 허재은 님 완전 재밌어서 즐겁게 웃으며 봤네요ㅎㅎ
#
# 영화가 전 더 좋아요.소하게 웃을 수 있는cg 많이 넣는 영화보다
#
# 187 개 , huj5555 님 킬링타임으로 괜찮은 영화. 재밌었어요
#
# 188 개 , 박하은 님
#
# 189 개 , 폭풍 님 영화보며 크게 웃은 적이 없었는데 몇번을 웃었네요. 겨울철에 해피엔딩 따뜻한 영화 추천합니다^^
#
# 190 개 , gduhivvjsk 님 예고편을 100분으로 늘려놓은듯한 느낌..
#
# 돈아까워무나다만든다?y 님 주인공꽝
#
# 192 개 , 김정은 님 너무 재미없습니다
#
# 걍 예고편이 끝x1sky 님 참신한 아이디어 하지만 그걸로 끝..... 뻔한 이야기 전개... 개연성 없는 편집.....
#
# 194 개 , 그놈의닉네임 님 아... ㅋㅋ 이것도 쥬만지2처럼 예고편이 전부네. 솔까 개노잼입니다. 5점 정도 되는데 개연성 개판에 -1점, 중반 이후 후반으로 갈수록 부실해지고 급히 끝내는 느낌이 강해서 -1점. 제 느낌은 3점 드립니다. 원작을 떠나서 걍 코미디로 끝까지 가야 괜찮은데 변호사 끼워놓고 쓸데없는 드라마 쳐넣어서 이도저도 아니게 됨... 탈 소품 잘 만들어 놓고 활용 못하고 흐지부지 ㅋㅋ
#
# 오랜만에 재미있게 잘 본  영화에요데 보고 나와서는 계속 가슴속이 멍멍해요었네요
#
# 196 개 , 탠 님 가족이랑 다같이 재미있게봤어요. 중간에 잠깐 지루하기도 하는데 그래도 나름 재밌네요. 초등딸은 너무 재미있었데요. 정봉이 연기톤이 좋아서 맘에 들어요.
#
# 197 개 , 대박 님 괴작
#
# 우리동물원 에서 내려놓앗음밋는 순간이오겠지 기다리고 기다렸는데
#
# 199 개 , 뭐래 님 내용이 착해서 재미없는게 아니라 못만들어서 재미가 없습니다 까만코 CG에 점수드립니다
#
# 200 개 , PNCS 님 자극적이지 않고, 가족들하고 편안하게 볼만한 영화로 괜찮았음 ㅋㅋ
#
# 201 개 , 도전인생 님 그냥별로 ㅎㅎ. 솔직히 재미없음
#
# 202 개 , 붉은천사 님 재미도없고..감동도 없고..
#
# 203 개 , 길동현 님
#
# 204 개 , 민지네 님 제밋다고해서 봤는데..영화로보기엔...티브에서 봐도 별루였을텐데...돈 아깝게 생각해요.
#
# 205 개 , 재미니 님 뭔가 밋밋한...예상되는 내용...하지만 애들은 좋아함
#
# 206 개 , 김치찌게 님 자다가 보다가 나왔네요.^^
#
# 207 개 , 연중무휴 님 평점 알바가 있긴 있구나..이딴 영화를 잼있다고 하는걸 보니ㅋㅋ 강소라야..작품 고르는 안목 좀 키워라. 안타깝다
#
# 끝날무렵 나와버린영화처음로첨에반짝웃기고
#
# 209 개 , 김두진 님
#
# 210 개 , tomboy716 님 별 기대 없이 봤는데 기대이하였습니다.
# 211 개 , 봄꽃 님
#
# 212 개 , 정시우 님 나쁘지 않긴 한데 정말 나쁘지만 않아요
#
# 213 개 , 어른 님 선정적이지 않고 다소 황당한데 재밌어요.
#
# 214 개 , DUM SPIRO-SPERO-BELLA VITA 님 장난해?? 영화가 장난이야?? 죽을래???
#
#  지금 당장 해치지않아 보러 영화관가세요!!어서 스트레스 풀렸네요!!
#
# 216 개 , 장발장 님
#
# 사자, 고릴라는 티가 많이나고 북극곰cg는 많이어색.
#
# 218 개 , 기린아 님 혹시나....
#
# 219 개 , qwerty 님 원작 스토리 따라가면서 재미에 조금 더 치중했으면  좋았을 듯..가미된 로펌 변호사 스토리가 오히려 독이 된거 같아요...무튼 잔잔하게 재밌어요 내 돈 보단 남의 돈으로 보세요..!
#
#  가자 영화보러....다. 으로 대통령아니다 님 영화보면서 개가튼 나라때문에
#
# 221 개 , 최고가되어 님
#
# 강추합니당웃음의 여운이 길게 남던 영화서있는
#
# 223 개 , 아가리찢어버리기전에닥쳐 님
#
# 영화관 웃음소리 ㅎ한나라 님 편하게  웃고  재밋게 봤어요
#
# 225 개 , 박시현 님
#
# 방학이라 아이들이 많더군요. 가족영화로 괜츈!만.. 선정적이지 않아서 편하게 봤어요
#
# 227 개 , 구봉숙 님 평점 믿지 마세요. 동물원 밀어버린다고 한 부분부터 어떻게 될지 빤히 보여서 걍 나왔습니다. 그리고 인간이 동물워에서 동물탈바가지 쓰고 동물인 척한다고 사람들이 속나요?? 말같지도 않은 설정....
#
# 228 개 , yeoyulim 님 잔잔한 드라마같은 영화ㅎㅎ 엄청 잔잔함...... 거의 누워서 봄ㅠㅠㅠ 안재홍좋아해서 봤는데 진짜 중간에 나갈까말까 고민엄청했음
#
# 229 개 , silk 님 욕이나 선정적 장면없이 아이들이랑 보기 좋아
#
# 230 개 , 띠붕 님 같이죽자
#
# 엄청난 재미와 감동보다 잔잔한 드라마입니다나올때 기분좋은 영화예요나 하지 않고 웃음코드도 있어서 가족 영화로는 좋았어요
#
# 232 개 , 조영숙 님
#
# 233 개 , 정혜민 님 같이 죽자고 별점 주는 인간들 진심 너무한다
#
# 234 개 , 마음이 님 진짜 오래간만에 이렇게 재미없는영화도 찾기 힘들듯
#
# 235 개 , cineguy 님 댓글 알바 너무 심하네요 최악입니다 지루하고 재미 없고... 티비에서 해줘도 보다 끌 것 같네요
#
# 236 개 , 김소연 님 이영화 꼬~~~~~옥 보내세요  정신사나운 영화들보다는 나아요 재밌고  간만에 실컷 웃었네요 ~~^^
#
# 237 개 , 이것들이진짜 님 이건아닌데.ㅠ
#
# 238 개 , 우린비 님 와 진심 영화관에서 본거맞냐.난 코엑스8관에서 밤타임봤는데 영화관 웃느라 정신못차리드만. 물론cg는 좀 아쉽고 후반에 좀 허무하게 끝나서 아쉽지만 중간까진 눈물나게 웃기드라 ㅋㅋㅋㅋ
#
# 239 개 , 한지은 님 재미나게 보고 왔어요... 아이들이랑 함께, 간만에 빵빵 터진 영화에요... 재미있어요~
#
# 240 개 , jung 님 생각보다 재미있었음 12세 관람가 영화입니다. 편히 보기 좋아요 웃음코드도 있구 나름 괜찮았습니다.
#
# 무난히 볼수 있는 영화걸음 님 재미도 있고 의미도 있고
#
# 이걸 영화라고 참내 ㅜㅜ입니다드는건지고서 처음으로 댓글답니다
#
# 243 개 , 피카부 님 빵터지는 장면 하나빼고 지루해서 숙면했네요..; 초딩용 영화같음.
#
# 244 개 , 누룽지 님 빵터지는 부분이 있긴해요..^^
#
# 245 개 , 목만치 님 전체적으로 별로네요...
#
# 246 개 , ----- 님 웃겨ㅋㅋㅋㅋㅋㅋ재밌음
#
# 247 개 , 아딸따리 님
#
# 248 개 , tigerlee 님 나름 재밌는 부분이 있고 나름 메세지가 있는 중박 정도의 영화였습니다~
#
# 249 개 , gunejy 님 기대 안 하고 봤는데 음...  좀 시시하다는 느낌입니다. 잘 만든 탈 잘 못  써먹는 느낌.
#
# 250 개 , switch 님 한국 코미디 영화와는 코드가 안 맞아서 코미디 장르는 패스하는 편임에도 재미있기를 바라면서 선택했는데.............무해하기는 합니다
#
# 온식구 관람해도 되겠군. 날라리 배우들이 안나오니, ,
#
# 어른끼리 와서 보기엔 부족할 수 있지만 충분히 재미있습니다.편하게 부담없이 보기에는 만점이고
#
# 253 개 , 이카루소77 님 진지하지 않고 가벼워 팦콘 무비로 적당한 영화~
#
# 254 개 , 물방울 님 애들이랑 같이 보기에는 넘 잼있어요~~^^
#
# 255 개 , 박종득 님
#
# 코미디면 확실하게 코미디로 갔어야...원작 >>>>>>>>>>넘사벽>>>>>>>>>영화
#
# 싫어하면 재미없는 영화인 님 정봉이식 개그를 좋아하면 재밌고
#
#  모처럼 돈 아까운 영화!!!님 뭐지? 다들 짰나?
#
# 259 개 , 레드배추 님 스타워즈 보고 기분 꿀꿀했는데 이 영화가 다 풀어줬어요!!
#
# 260 개 , 봄이네 님
#
# 아이들하고 보세요^^요~^^시 머리 식히고, 10번정도 웃고, 동물 학대하지
#
# 무겁지 않은 소재라 가벼운 마음으로 머리 식히고 왔습니다어요
#
# 263 개 , 늘푸른나무 님
#
# 만족 입니다, 황당 님 117분 가벼운 마음으로 아무생각 없이 보시길~~~웃고ㅋ 웃고ㅋㅋ 또 웃고 ㅋㅋㅋ웃고 싶으면 보세요 세로토닌 팍팍 면역력 강화 될꺼 같아요
#
# 265 개 , 맨위에 첫번째 베스트댓글 대박 님
#
# 방학 중이고 애들이(초5) 보겠다고 하여 스토리 잘 모르고 출연배우들 보고 그래 함 보자 하고 정말 아무 기대, 사전정보없이 갔는데..그런 영화라 치고도 넘 실망스러웠어요ㅠ 보통은 그런때 그 이상은 하던데..쩝  이건 개인적인 평입니다. 애들은 의외로 재미있었다고 하니 그래도 다행이었구요^^
#
# 267 개 , 신과의사랑 님 얘드랑 이런걸로 거짓말 하지망 진짜 재미 없더라
#
# 268 개 , 리리리 님 미안하다 거짓말은 못하겠다.
#
# 269 개 , 경민륌2001 님 CG가  쫌 거시기하지만  잼나요ㅋ
#
# 270 개 , 흔들go쓰리go 님 아이들과 함께 보기 정말 즐거운 영화
#
# 271 개 , 세렌디피티 님 더욱 더 코메디로 밀어붙였으면 하는 아쉬움이 진하게 남는다. 그런데,문제는 이 영화뿐만이아니라 우리나라 영화들의 고질적인 문제점인 웃움도 있어야 하고,메세지도 있어야 하며,감동도 당연히 들어가면서 지루하지 않게 만들려다 보니까,딱 이 정도 수준의 영화들이 남발하는 것이다. 조금 더 간결한 영화들이 더 호평을 받는다는 것을 모른다는 것이 답답할뿐이고, 이 영화를 보는 내내 떠올랐던 영화 "우리는 동물원을 샀다"라는 영화와 비교한다면 수준 차이가 어느 정도인지 간접적으로 비교가 될 것이다!
#
# 272 개 , lovelyjoo 님 재밌음. 아무생각없이 웃을수 있음
#
#  너무 뻔한 내용이라 기대 안하고 봤더니 볼만했습니다.땠을까 싶은 생각을 해봤습니다.력이 더해져 만들어진 영화라
#
# 274 개 , 하하핫 님 엄청 재미있진 않은데 기대하지 않고 보면 볼만해요 웃음 요소도 많고
#
# 275 개 , venus 님 아
#
# 276 개 , Edmond Dantes 님 착한 스토리에 예측 가능한...
#
# 277 개 , kkury 님 너무 웃겼어요. 내용이 뻔해도 정말 좋았어요. 아이들과 보세요~
#
#  대기업들이미지 관리도 딴게 필요없다 돈보다 사람이 먼저다 더 원한다삐까 5성급호텔 보다도
#
# 279 개 , Cadenza 님 ㅡ..ㅡ;;
#
# 280 개 , haffyend 님 엄청 웃기진 않았지만 말하고자 하는 내용이 좋았다 그래도 재밌었음
#
# 281 개 , 기린 님 어쨌든 재밌다 ㅋ.ㅋ.ㅋ 한방의 웃김
#
# 초등자녀들과 함께 보면 더더욱 좋을 영화의 평점
#
# 283 개 , 올소 님 아마 올해 보게될 영화중 최악이 아닐까..너무나 뻔희 예상되는 시나리오..감동도 없고, 재미도 없고...유치하기까지....같이 영화본 사람들중 빵빵터진 사람없었는데.....어디서 빵빵 터졌다는 건지....이 영화는 여기서 웃어줘야되라고 말하고 있지만, 그렇기 때문에 웃지 못하는 그런 영화다....
#
# 284 개 , cobi 님 너무 잼있어요~ㅋ 신랑이랑가서 빵빵터지고왔어요~강추~!
#
# 285 개 , 김동혁 님 요즘시기에 볼만한 힐링영화
#
# 286 개 , 김광석 님 빵빵 터지네요 결말이 다소 늘어지면서 허무하고 느닷없지만 웃을 일 없는 요즘 시기에 크게 한번 웃고 왔네요
#
# 여기 알바들때메 속음ㅡㅡ 이게 왜 재밌지
#
# 코믹류 라기보다는 가벼운마음으로 보면 재밌어요  재밌게 봤네요
#
# 289 개 , STGH 님 겨울방학특선초등학생용영화로 딱좋아요!!
#
# 돈이 좀 아까웠음 ㅡㅡ;;각보다 지루하고 임팩트가부족ㅋ  별로 웃기지도 않음
#
# 291 개 , 최소원 님 스토리만 보면 그렇게 재미있지는 않은데 웃긴 장면들이 꽤 있어서 볼만 했던 것 같아요ㅎㅎ
#
# 292 개 , 시작 님 애들하고 봤는데  정말  재미있게 봤어요. 애들이 다시보고  싶은 영화래요~~ㅋ
#
# 깔깔깔 웃음~~~겁게 보기에주 재미가 있네요.
#
# 294 개 , 이스크라 님 스토리상 최고의 훈훈한 결말을 이끌어낸 영화... 드라마티컬한 스토리를 기대하고 갔다면 실망하겠지만, 소소하고 훈훈함을 느끼고 싶은 사람들에겐 최고의 영화~^^
#
# 295 개 , 김현정 님
#
# 시간내서 같이 간 사람에게 좀 미안..가 실망하고 나왔습니다.
#
# 297 개 , 귀연다캉시 님 출연진은 개화려하네 보러가 말어 고민된다
#
# 298 개 , 윤자까 님 소소한 소동극이지만 웃긴다
#
# 299 개 , 알라 님 실망.노잼
#
# 한국영화 요즘 반성해야해. 너무 성의없이 대충 만들고 있는듯....
#
# 301 개 , 부산백곰 님 극한직업 이후로 최고의 코믹이었다
#
# 302 개 , ufo 님 가족과 꼭보세요~♡
#
# 303 개 , Jo여사 님 생각없이 보기 괜찮아요
#
# 304 개 , skyz 님 고생했어요.
#
# 305 개 , 로렐라이 님 나름의 장점과 매력이 있는 영화. 귀여운 유머 속에 애잔함이 묻어있는.. 이런 영화에 높은 작품성의 잣대를 들이댈 필요는 없을듯. 고생한 배우분들께 박수를~^^ 그리고 박영규 아저씨 오래간만에 뵈서 반가웠음~
#
# 306 개 , 뚜디 님 노잼........북극곰이 콜라먹는 장면빼곤 노잼.  배우들이 아까움 하품500만번
#
# 307 개 , 별빛바램 님 재밌어요 많이 웃었어요 근데 끝부분에 잠시 졸았다는 ㅠㅠ
#
# 308 개 , 이광수 님
#
# 309 개 , 영원하길 님
#
# 310 개 , 정기호 님 유치함..밑에 댓글 알바..
#
# 311 개 , I Will 님
#
# 312 개 , 하늘파파 님 약간 코믹한 드라마 정도 보는 수준  예고편에 조금 못미침
#
# 쓰레기 중에 쓰레기..... 돈이 넘쳐나도 시간이 아까우니 보지 말것...도 없고...
#
# 예고편이 열일한 영화 님 북극곰 콜라 먹은후로 김빠짐
#
# Cg 곰만 불쌍하더라고요.... 솔직하게
#
# 316 개 , 근묵자흑 님 우리딸이 웹툰 소재로 만들었다고 재밌겠다고 보러가자해서 가족이 모두 출동했다. 영화보는 중간에 나가자고 말하고싶었지만 우리 딸이 "엄마 미안해요. 아빠 미안해요" 해서 억지로 잠은 안자고 다봤다. 정말 내 인생 최악의 영화였다. 덕분에 하루종일 우리딸 놀려먹었네. 알바들아 양심이 있으면 평점테러하지마라. 니들이 별점 5점줘서 평점 조작하면 공짜로 보라해도 시간 아까운영화를 혹시나해서 보는 사람이 생긴다.니들 양심도 없냐???
#
# 317 개 , 오늘 님 참신한 소재, 적당한 유머, 평이한 내용, 두루뭉술한 해결, 뻔한 결말. 가볍게 보기에 좋다.
#
# 아이들과 함께 보기 좋아요~912 님 동물원에 사는 동물들 짠한마음 생깁니다.
#
# 319 개 , 소_나이스_맘 님 안재홍북극곰연기!인정!
#
# 320 개 , 7070 님 웃다가울다가무서웠던영화라정말재밌었던영화였습니다
#
# 321 개 , Korea Victory 님 5번 이상 웃긴 영화
#
# 322 개 , 재주소년 님 가볍게 볼수있는 가족영화로 추천!
#
# 323 개 , 여름향기 님 웃다가 울음
#
# 324 개 , 잿빛과비 님 빵 터졌네요 ㅎㅎ
#
# 325 개 , 하이루케이 님 간만에 빵 터지는 웃음내며 봤어요
#
# 326 개 , 안령은 님 .
#
# 327 개 , 안녕- 님
#
# 328 개 , YOON 님 예고편이 다 인느낌 .... 예고편에서 되게 웃겼던장면이 다에요 .... ㅠ ㅠ 킬링타임으로는 좋은
#
# 329 개 , 다니엘 님 영화가코믹과 슬픔이 섞어 있어서 좋은영화네요
#
# 330 개 , 인디 님 와우  웃음포인트2군데  있습니다  그게 다고  말이안되는설정  전반40분까지  정말  아무것도  없었다  돈아깝다  시동도  너무  아니더만  이것도  웹툰인가  다운로드용도  아니다
#
# 331 개 , 둥둥이 님
#
# 332 개 , 야시같은아지매 님 원작대로만  하지..
#
# 333 개 , 살다보면 님 다 알고 봐도 웃기네요.^^크게 재밌거나 하진 않지만, 소소하게 많이 웃었네요.아무 생각없이 그냥 보시면 좋을 듯..
#
# 334 개 , guajava 님 잼있어요 ㅎㅎㅎㅎㅎ일단 한국영화는 기본으로 욕설로 도배가 많은데 ㅋ 이 영화는 욕설이 채 10마디도 나오지않아서 좋았어요~ 흥하세요 ~~~~
#
# 335 개 , 파주 님 영화 감동적이고 재밌어요~ 17년동안 키우다 떠난 백구가 생각나서 슬프기도 했습니다
#
# 중간에 나가고싶어서 시계만 계속봄안되는 전개와구성은 그렇다치고 억지로 웃기려고 노력하는게 더욱 짜증유발함
#
# 337 개 , 고잉고잉 님 괜찮아 ㅋ
#
# 338 개 , 형솔 님 재미있어서 시간가는 줄 모르고 봤어요
#
# 339 개 , 난한국판양조위 님 원작은 둘째치고 그냥 별 부담없이 가족끼리 보기 좋은 영화 인거 같다.
#
# 340 개 , 외골선비 님
#
# 슬프다.짜 재미있게 봐서 기대 만땅하고 봤는데.
#
# 342 개 , kgs 님
#
# 아이들 즐겁게 영화보고 동물애대한 생각도 많이 틀려지게하는 교육적인 영화입니다.추운날 따뜻했습니다.강추!!!!다고 하네요.폭력적이고 우울한 영화보다는 이런 기분좋고 따뜻하고 웃음짓는 영화가 훨씬 좋습니다.세상이 따뜻하다고 느껴지게 하는 영화였어요.말이안되는거지만..말이 되는 영화가 뭐 얼마나 되겠습니까?
#
# 344 개 , 시공 님 ,.
#
# 그러나 황당한 이야기.y 님 흐뭇한 이야기.
#
# 346 개 , 민성 님 너무재미있어요
#
# 347 개 , 설레임 님 한국영화 사랑해주세요~
#
# 348 개 , ?해 님 방금보고왔습니다. 별 1개 드립니다
#
# 349 개 , 자우림 님
#
# 350 개 , 정종현 님 너무 재미있어요.
#
# 351 개 , 둘리사랑 님 영화를 보고 댓글 달아주세요. 이렇게 순수하고 사랑스러운데 유머도 대단해서 계속 웃으며 보는 국내 코믹영화가 전에 있었나..? 생각합니다. 메세지도 있고 우리나라도 이제 코믹영화 수준이 한단계 높아진걸까요.. 만족합니다.
#
# 352 개 , 특공인 님
#
# 353 개 , 미니 님
#
# 354 개 , 하이 님 별5개는 알바생인든  겁나재미없어요
#
# 아직  안봤지만  볼 예정 님 재밌어보이는  구만  0,1은  뭘까...
#
# 356 개 , 참평화 님 잔잔한 감동
#
# 357 개 , poseidon 님
#
# 배우분들 연기도 좋았고 메세지도 있는 좋은 영화라고 생각합니다~아서 좋았고 잔잔하게 미소지으며 재밌게 봤네요.
#
# 359 개 , 찬물 님 뭐..해치지는 않음.
#
# 360 개 , 수신자 님
#
# 361 개 , 판다 님 넘잼이써
#
# 362 개 , 김 상 영 님 영화 보고말해 ㄴ ㅃ ㄴ ㄷ 아
#
# 363 개 , in veil 님 아하 역시 그렇군. 모레 개봉하면 보려고 예매해놨는데, 역시 알바 평점 조작이군 또! 웬만큼만 나왔어도 이러진 않을텐데.. 예매취소!! 다행이다!
#
# 같이 죽자는건지..알바인지.. 보고 그러는건지..
#
# 365 개 , veronica 님 신박하게 웃기네요! 최근 본 코미디 영화 중 제일 재미있었어요!
#
# 366 개 , hannah 님 아 진짜 대박!! 시사회로 봤지만 개봉하면 또 볼 예정임다
#
# 367 개 , 박은지 님 시사회로 봤는데, 재밌기만한 영화가 아니라 한번쯤 고민해 봐야 할 이야기도 담고 있어서 더욱 좋았습니다.
#
# 368 개 , 슬이 님 컨셉 진짜 신박한듯ㅋㅋㅋㅋ기대됩니당ㅋㅋㅋ
#
# 369 개 , gasdgnkvkewa 님 완전 기대중!!
#
# 370 개 , 베이비5 님 가볍게 웃으면서 보기 좋은 영화였어요!!
#
# 371 개 , ㅇㅅㅁ 님 강추강추
#
# 372 개 , 정주원 님 다가오는 설연휴 가족과 함께 유쾌하게 볼 수 있는 영화!!
#
# 373 개 , 오고 님 아직도 눈물이 멈추질 않네요 ㅠㅠ
#
# 374 개 , 닉네임 님 고릴라가 ㅋㅋㅋㅋㅋㅋㅋ진짜 웃길거 같은데 ㅋㅋㅋㅋ나도 저렇게 옷입고 해보고 싶다
#
# 375 개 , 김유자 님 솔직히 너무 재밌당!!!!!!!!!!!
#
# 376 개 , abcdefilm 님 -
#
# 377 개 , 유은성 님
#
# 378 개 , 도모도모 님
#
# 379 개 , - 님 웃긴데 감동도 있고 생각할거도 던져주는 영화엿습니다~~
#
# 380 개 , 손서현 님 얼른 보구싶어용!!
#
# 웹툰 원작을 재미있게 봤는데 영화도 재밌네요!영화입니다.
#
# 382 개 , -경옥- 님
#
# 383 개 , 불켜보니 님 극한직업같은 털털하고 날리나는 코미디 기대해봅니다.
#
# 384 개 , Torres 님 시사회로 봤는데 감동도 있고, 빵빵터져서 설날에 가족에게 추천하기 좋아요~
#
# 385 개 , 다니 님 색다른 코미디라서 기대된다!!
#
# 386 개 , 나를찾아줘 님
#
# 387 개 , 강영진 님
#
# 388 개 , 깡마른 체구바라 님
#
# 389 개 , I LOVE KOREA 님
#
# 390 개 , 그건니생각이고 님
# 391 개 , 옥시시 님
#
# 392 개 , 안약 님
#
# 393 개 , Tucson 님 하루하루 힘들게 사는 직장인들에게 즐거운 만찬을 제공해준 영화
#
# 394 개 , 홍련의 비술 님 위기의 동물 파크를 구하기 위한 사투가 시작되는 영화라고 생각하며,  충무로를 대표하는 4명의 배우의 열연이 돋보인다고 생각합니다!!  이 영화는 꼭 봐야합니다!!
#
# 이 영화도 엄청 웃다 왔어요 ^^ 극한직업도 재미있게 봤었는데
#
# 396 개 , 박미영 님
#
# 397 개 , 이광복 님 재밌지만 그래도 조금은 아쉬웠던 영화..
#
# 재미있고 유쾌하면서도 자본주의에 대해서도 생각하게 됩니다
#
# 399 개 , 그린북 님 10점 평점 조작 하지마라.
#
# 400 개 , 쭈니 님 시사회봤는데 편하게 웃으면서 즐길수있는영화~
#
# 401 개 , white앙크림 님 재밌을거같아용
#
# 로펌이야기만 계속 쳐나와서 짜증만 났다.로만 만들었어도 1000만 각인데 왠 뜬금 웃기지도 않는
#
# 403 개 , 뽀글이 님
#
# 설마 이걸 실사 영화로 만들줄이야웹툰 기억 난다 ㅋㅋㅋㅋ
#
# 닥터 두리틀보다 재미있을 것을 기대합니다.? . 제발 좀~바랍니다.
#
# 406 개 , 태양의후배 님 억지 웃음이 아니고 정말루 현웃 터집니다ㅋㅋ 꼭 보세요.
#
# 407 개 , 다은 님 소라엉니 사랑행ㅇ용
#
# 곰CG가 좀 어설퍼서 아쉽기는 했지만 그래도 재밌었습니다.덕분에 실컷 웃고 나왔네요
#
# 409 개 , 김완수 님 시사회로 본 영화... 안그랬음 옆사람 해쳤을듯.
#
# 410 개 , bianchi kim 님 보고싶은영화1순위
#
# 영화보기전에 티저 안봤는데 메인티저에 나온 내용이 다 웃겼던장면이라 티저 안보는게 날거같기두함ㅋㅋ
#
# 대박납시다도하는 특이소재라 더 재밌게 봤습니다
#
# 413 개 , 김수영 님 시사회 당첨으로 봤는데 너무 재미있게 잘 봤습니다
#
# 414 개 , 최수진-ㅅ-마로 님 유쾌하게 재밌다! 좋아하지 않을 수 없는 영화!!
#
# 415 개 , 조한솔 님 올해의 영화가 1월되자마자 나왔네요
#
# 416 개 , 매치니코프 님 시사로 봤는데 진짜 꿀잼임!!
#
# 417 개 , Star 님 예고편을 보니 기대가 되네요.!
#
# 418 개 , 애니칸 님 오 ~ 신선한데 기대된다 !! ㅋㅋ
#
# 419 개 , 노정아 님
#
# 420 개 , 임현태 님
#
# 421 개 , 비류현 님 재미있을거 같아
#
# 422 개 , 윤치성 님 손재곤감독님 드디어 오셨군요ㅎㅎ 이층의악당 이후 10년만이라니~  천만기원합니다!!
#
# 423 개 , 최정우 님 아ㅋㅋㅋㅋㅋㅋ우울함을 싹 날려버린 명작ㅋㅋㅋ
#
# 424 개 , qwerty 님 소재 독특해서 재미있겠네요~^^
#
# 425 개 , 조승연 님 예고편 넘 웃긴듯ㅎㅎ 기대되는 영화라 빨리 개봉했으면!!
#
# 426 개 , 밍구 님
#
# 427 개 , 재은 님
#
# 428 개 , 뚜기뚜기 님
#
# 429 개 , 이자인 님 소라언냐쨩쨩 좋아유!!!!!!!!!
#
# 430 개 , hshs 님
#
# 431 개 , 도효예 님
#
# 432 개 , 얄루얄루 님 신선한 소재 기대됩니다
#
# 433 개 , 알레 님 유튜브 보고 옴 ㅋㅋㅋㅋㅋㅋㅋ 졸라 약빨았엌ㅋㅋㅋㅋㅋ
#
# 434 개 , 우당탕탕 님 제보회 짤 인스타에서 봤는데 넘 웃겨용!  영화도 빵빵 터질듯
#
# 435 개 , zoe 님 어제 제작보고회했던데 너무 기대되네요!
#
# 436 개 , 혀니혀니 님 소재 뭐얔ㅋㅋㅋ 제대로 약빨았네... 1월 기대작 중 하나입니다!
#
# 437 개 , 샤넬뷔똥 님 친구들 하고 예고편 봤는데 웃겨요
#
# 438 개 , 낭만쟁이 님 예고편 보고 기대지수가 팍팍 올라갔어요~ 얼른 보고 싶다!!
#
# 439 개 , ekfkawnl 님 강소라 연기력 많이떨어졌네
#
# 440 개 , 껄껄껄 님
#
# 441 개 , 닮닮 님 오랜만에 주말에 손재곤 감독님 영화를 봤는데 이번 작품도 기대됩니다
#
# 442 개 , ependymoma 님
#
# 코믹기대합니다 켑틴 님 간만에 제대로된
#
# 444 개 , 아카폴코 님 영화 기대됨   신선한것 같음   해외수출 많이 했으면함...
#
# 445 개 , wonmom 님 어 왜 등록이 안돼지?
#
# 446 개 , 글쎄 님 보고말거야..ㅋ
#
# 447 개 , q2014230 님 많이 웃길듯. 신선한 아이디어.  대박날듯 합니다
#
# 448 개 , ehdrka 님 참신한 소재는 좋네요. ㅋㅋㅋ  이런 시도가 흥행에 성공해야 다양한 장르 한국영화들이 많이 만들어질텐데.. 맨날 조폭아니면 재난소재, 북한 얘기.... 새로운 시도 박수를 ~~~~   오버연기 하지말고 정극처럼 자기들 끼리는 엄청 심각하고 진지한거지.. 이렇게 연기했음 참 재미겠다.. 억지웃음말고..
#
# 449 개 , 문꾸라지 문로남불 문마네기 님 일단 웃기긴 할 것 같다. ㅎ
#
# 450 개 , 사랑하리 님 요거 천만간다 100%
#
# 451 개 , dwK81 님 오 안재홍
#
# 452 개 , 이용희 님 개봉도 안했는데 뭔 평점이냐 대깨문들아 ㅡㅡ
#
# 453 개 , 찬돌팍 님 웹툰은 엄청 재미있었습니다. 주연분들을 보니 기다려집니다!
#
# 454 개 , 사랑이란이름 님 비슷한 웹툰을 봤던거 같은데 기대되네요^^
#
# 455 개 , 호랑이4065 님 ^,.^~~~~
#
# 456 개 , 최종욱9423 님 인생 이막이 오를듯, 신선한 파장을 주는 만화
#
# 기다려집니다. antonio 님 감독전작 이층의악당 완전좋았는데
